# %%
# !pip install kafka-python
# Out:
# Collecting kafka-python
#   Downloading kafka_python-2.0.2-py2.py3-none-any.whl.metadata (7.8 kB)
# Downloading kafka_python-2.0.2-py2.py3-none-any.whl (246 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.5/246.5 kB 2.7 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: kafka-python
# Successfully installed kafka-python-2.0.2

# %%
# !pip3 install minio
# Out:
# Collecting minio
#   Downloading minio-7.2.7-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from minio) (2023.7.22)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.11/site-packages (from minio) (2.0.7)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.11/site-packages (from minio) (23.1.0)
# Collecting pycryptodome (from minio)
#   Downloading pycryptodome-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.11/site-packages (from minio) (4.8.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.11/site-packages (from argon2-cffi->minio) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi->minio) (1.16.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->minio) (2.21)
# Downloading minio-7.2.7-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 kB 2.6 MB/s eta 0:00:0000:01
# Downloading pycryptodome-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 4.0 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pycryptodome, minio
# Successfully installed minio-7.2.7 pycryptodome-3.20.0

# %%
from minio import Minio

# %%
client = Minio("minio:9000",
    access_key="DImuDiaEs6bIJJBgCjXW",
    secret_key="HPCTwG5dobqO83MAoCz4hmpPMaJblP9RvondmMHJ",
    secure = False
)

# %%
client.make_bucket("bronze")

# %%
import json
from minio import Minio
from minio.error import S3Error
from io import BytesIO

# Nome do bucket e do objeto
bucket_name = "bronze"
object_name = "dados/clientes.json"  # Caminho e nome do arquivo no bucket

# Dados a serem gravados
dados = {
    "clientes": [
        {"nome": "João", "sobrenome": "Silva", "idade": 34, "email": "joao.silva@email.com", "data_cadastro": "2024-08-09"},
        {"nome": "Maria", "sobrenome": "Oliveira", "idade": 29, "email": "maria.oliveira@email.com", "data_cadastro": "2024-08-09"}
    ]
}

# Converter o dicionário Python em uma string JSON
json_data = json.dumps(dados)

# Converter a string JSON em bytes para poder enviar ao MinIO
json_bytes = BytesIO(json_data.encode('utf-8'))

# Fazendo upload do JSON para o MinIO
try:
    client.put_object(
        bucket_name,
        object_name,
        data=json_bytes,
        length=len(json_data),
        content_type="application/json"
    )
    print(f'JSON {object_name} enviado para o bucket {bucket_name} com sucesso!')
except S3Error as e:
    print(f'Erro ao enviar arquivo: {e}')
# Out:
# JSON dados/clientes.json enviado para o bucket bronze com sucesso!

# %%
len(datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# 19

# %%
from kafka import KafkaConsumer
TOPIC = 'teste'
BOOTSTRAP = 'kafka:9092'
ACCESS_KEY = "DImuDiaEs6bIJJBgCjXW"
SECRET_KEY = "HPCTwG5dobqO83MAoCz4hmpPMaJblP9RvondmMHJ"
from clickhouse_driver import Client
from minio import Minio
BUCKET_NAME = 'bronze-layer'

class KafkaConsumerTopic():
    def __init__(self, topic):
        self.topic = topic
        self.client = Client(
                host='clickhouse',       # Endereço do servidor ClickHouse
                port=9000,              # Porta padrão para conexões TCP
                user='default',         # Usuário (padrão é 'default')
                password='',            # Senha (por padrão, vazio)
                database='default',     # Nome do banco de dados (por padrão, 'default')
        )
        
    def get_offset(self):
        self.client.execute("""CREATE TABLE IF NOT EXISTS kafka_topics_offset_control (
                id UInt64,
                kafka_topic String,
                last_offset Int64,
                exec_date DateTime
                ) ENGINE = MergeTree()
                ORDER BY id """
        )
        offset = self.client.execute(f"SELECT max(last_offset) FROM kafka_topics_offset_control WHERE kafka_topic = '{self.topic}'")[0][0]
        return offset

    def insert_offset(self, offset):
        self.client.execute(f"""
        INSERT INTO kafka_topics_offset_control (kafka_topic, last_offset, exec_date) 
        VALUES ({self.topic,  {offset}})
        """)
    
def insert_bronze(data):
    client = Minio("minio:9000",
        access_key=ACCESS_KEY,
        secret_key=SECRET_KEY,
        secure = False
    )
    found = client.bucket_exists(BUCKET_NAME)
    if not found:
        client.make_bucket(BUCKET_NAME)
        print("Created bucket", BUCKET_NAME)
    json_data = json.dumps(dados)
    json_bytes = BytesIO(json_data.encode('utf-8'))
    now = datetime.now()
    object_name = f'KAFKA/topic={TOPIC}/year={now.year}/month={now.month}/day={now.day}/{now.strftime("%Y-%m-%d %H:%M:%S")}.json'
    try:
        client.put_object(
            BUCKET_NAME,
            object_name,
            data=json_bytes,
            length=len(json_data),
            content_type="application/json"
        )
        print(f'JSON {object_name} enviado para o bucket {bucket_name} com sucesso!')
    except S3Error as e:
        print(f'Erro ao enviar arquivo: {e}')    
# Configuração do consumidor Kafka
try:
    consumer = KafkaConsumer(
        bootstrap_servers=[BOOTSTRAP],  # Servidor Kafka
        enable_auto_commit=True,  # Para commit automático das mensagens
        consumer_timeout_ms=10000,  #fica aguardando topicos por 10 segundos
        value_deserializer=lambda x: x.decode('utf-8')  # Deserializa as mensagens para string
    )
    # Especificar a partição e o offset inicial
    partition = 0  # Partição que deseja consumir
    offset_inicial = get_offset(TOPIC)  # Offset a partir do qual deseja começar a ler
    
    # Atribuir a partição ao consumidor
    tp = TopicPartition(TOPIC, partition)
    consumer.assign([tp])
    
    # Definir o offset inicial manualmente
    consumer.seek(tp, offset_inicial)
    
    print("Aguardando mensagens...")
    last_message = None
    # Consome mensagens do tópico
    message_list = []
    for message in consumer:
        last_message = message
        print(f"Recebido: {message.value}")
        message_list.append(message.value)
        
    insert_bronze(message.value)
    insert_offset(message.offset)
    
except Exception as e:
    print(e)
    raise Exception(e)
    #create_log(status = 'failure', message = e)
# Out:
# Aguardando mensagens...
# Recebido: {"nome": "Raquel", "sobrenome": "Porto", "idade": 70, "email": "muriloazevedo@example.com", "data_cadastro": "2024-02-26"}
# Recebido: {"nome": "Augusto", "sobrenome": "Moura", "idade": 44, "email": "joao-lucasda-luz@example.org", "data_cadastro": "2024-05-22"}
# Recebido: {"nome": "Melissa", "sobrenome": "Barros", "idade": 68, "email": "kda-conceicao@example.net", "data_cadastro": "2024-04-17"}
# Recebido: {"nome": "Jo\u00e3o Pedro", "sobrenome": "Dias", "idade": 69, "email": "alveskaique@example.com", "data_cadastro": "2024-06-22"}
# Recebido: {"nome": "Nathan", "sobrenome": "Arag\u00e3o", "idade": 27, "email": "araujoemilly@example.org", "data_cadastro": "2024-06-28"}
# Recebido: {"nome": "Luna", "sobrenome": "Freitas", "idade": 33, "email": "qcaldeira@example.com", "data_cadastro": "2024-01-02"}
# Recebido: {"nome": "Luiz Ot\u00e1vio", "sobrenome": "Ara\u00fajo", "idade": 67, "email": "gabrielly22@example.org", "data_cadastro": "2024-05-28"}
# Recebido: {"nome": "Davi", "sobrenome": "Pereira", "idade": 63, "email": "isis71@example.com", "data_cadastro": "2024-06-14"}
# Recebido: {"nome": "Diego", "sobrenome": "Cunha", "idade": 43, "email": "samuelda-rosa@example.org", "data_cadastro": "2024-03-11"}
# Recebido: {"nome": "Sabrina", "sobrenome": "Viana", "idade": 37, "email": "joao-lucascastro@example.org", "data_cadastro": "2024-07-07"}
# Recebido: {"nome": "Igor", "sobrenome": "Cardoso", "idade": 67, "email": "ana-clara83@example.org", "data_cadastro": "2024-06-07"}
# Recebido: {"nome": "Lara", "sobrenome": "Oliveira", "idade": 49, "email": "stephanysales@example.net", "data_cadastro": "2024-01-17"}
# Recebido: {"nome": "Carlos Eduardo", "sobrenome": "Pereira", "idade": 20, "email": "duartemaria@example.net", "data_cadastro": "2024-07-22"}
# Recebido: {"nome": "Pedro Henrique", "sobrenome": "Sales", "idade": 34, "email": "oliveirapaulo@example.org", "data_cadastro": "2024-07-14"}
# Recebido: {"nome": "Esther", "sobrenome": "Ara\u00fajo", "idade": 22, "email": "eviana@example.org", "data_cadastro": "2024-07-28"}
# Recebido: {"nome": "Jo\u00e3o Gabriel", "sobrenome": "da Concei\u00e7\u00e3o", "idade": 28, "email": "lduarte@example.net", "data_cadastro": "2024-03-20"}
# Recebido: {"nome": "Nicole", "sobrenome": "Vieira", "idade": 37, "email": "ana-clara60@example.org", "data_cadastro": "2024-03-10"}
# Recebido: {"nome": "Maria Cec\u00edlia", "sobrenome": "Fernandes", "idade": 21, "email": "dalmeida@example.net", "data_cadastro": "2024-01-28"}
# Recebido: {"nome": "Maria Luiza", "sobrenome": "Peixoto", "idade": 19, "email": "isabelsouza@example.com", "data_cadastro": "2024-01-14"}
# Recebido: {"nome": "Thomas", "sobrenome": "Pereira", "idade": 56, "email": "gustavo-henriquenascimento@example.com", "data_cadastro": "2024-04-29"}
# Recebido: {"nome": "Enrico", "sobrenome": "Porto", "idade": 31, "email": "caldeiralaura@example.net", "data_cadastro": "2024-08-07"}
# Recebido: {"nome": "Beatriz", "sobrenome": "da Mota", "idade": 39, "email": "kda-luz@example.net", "data_cadastro": "2024-04-22"}
# Recebido: {"nome": "Isaac", "sobrenome": "Fernandes", "idade": 50, "email": "diasisis@example.com", "data_cadastro": "2024-01-06"}
# Recebido: {"nome": "Cec\u00edlia", "sobrenome": "Pires", "idade": 70, "email": "nsantos@example.net", "data_cadastro": "2024-01-25"}
# Recebido: {"nome": "Luiz Gustavo", "sobrenome": "Barros", "idade": 37, "email": "hmelo@example.net", "data_cadastro": "2024-05-13"}
# Recebido: {"nome": "Daniel", "sobrenome": "Rodrigues", "idade": 48, "email": "efogaca@example.org", "data_cadastro": "2024-08-02"}
# Recebido: {"nome": "Fernando", "sobrenome": "Barbosa", "idade": 44, "email": "peixotolucca@example.net", "data_cadastro": "2024-08-06"}
# Recebido: {"nome": "Ana Carolina", "sobrenome": "Campos", "idade": 22, "email": "ana-sophiarodrigues@example.org", "data_cadastro": "2024-07-10"}
# Recebido: {"nome": "Bryan", "sobrenome": "Nogueira", "idade": 35, "email": "milenacastro@example.com", "data_cadastro": "2024-03-29"}
# Recebido: {"nome": "Marcela", "sobrenome": "Mendes", "idade": 47, "email": "fernandesgustavo-henrique@example.org", "data_cadastro": "2024-01-12"}
# Recebido: {"nome": "Ana", "sobrenome": "Santos", "idade": 53, "email": "boliveira@example.net", "data_cadastro": "2024-06-12"}
# Recebido: {"nome": "Igor", "sobrenome": "Monteiro", "idade": 22, "email": "portorodrigo@example.org", "data_cadastro": "2024-04-05"}
# Recebido: {"nome": "Lucas Gabriel", "sobrenome": "Gon\u00e7alves", "idade": 68, "email": "levigoncalves@example.org", "data_cadastro": "2024-02-05"}
# Recebido: {"nome": "Fernando", "sobrenome": "Cardoso", "idade": 39, "email": "isaac22@example.net", "data_cadastro": "2024-06-21"}
# Recebido: {"nome": "Maria Cec\u00edlia", "sobrenome": "Caldeira", "idade": 53, "email": "luiz-fernando05@example.net", "data_cadastro": "2024-05-18"}
# Recebido: {"nome": "Ana Beatriz", "sobrenome": "Silva", "idade": 20, "email": "maria-fernanda54@example.org", "data_cadastro": "2024-03-10"}
# Recebido: {"nome": "Maria Sophia", "sobrenome": "Monteiro", "idade": 69, "email": "marcelo47@example.org", "data_cadastro": "2024-06-21"}
# Recebido: {"nome": "Pedro Henrique", "sobrenome": "Duarte", "idade": 23, "email": "stephany90@example.org", "data_cadastro": "2024-06-02"}
# Recebido: {"nome": "Ana Sophia", "sobrenome": "Freitas", "idade": 43, "email": "isabelly12@example.net", "data_cadastro": "2024-06-21"}
# Recebido: {"nome": "Jo\u00e3o Guilherme", "sobrenome": "Cunha", "idade": 50, "email": "lda-luz@example.net", "data_cadastro": "2024-07-17"}
# Recebido: {"nome": "Ana Beatriz", "sobrenome": "Nunes", "idade": 36, "email": "ninacaldeira@example.net", "data_cadastro": "2024-04-12"}
# Recebido: {"nome": "Isabella", "sobrenome": "Dias", "idade": 70, "email": "breno62@example.net", "data_cadastro": "2024-08-09"}
# Recebido: {"nome": "Maria Vit\u00f3ria", "sobrenome": "da Luz", "idade": 35, "email": "isabellapereira@example.org", "data_cadastro": "2024-03-19"}
# Recebido: {"nome": "Luiz Fernando", "sobrenome": "Melo", "idade": 46, "email": "isadorafarias@example.com", "data_cadastro": "2024-07-21"}
# Recebido: {"nome": "Al\u00edcia", "sobrenome": "da Costa", "idade": 60, "email": "ida-mota@example.net", "data_cadastro": "2024-03-26"}
# Recebido: {"nome": "Marcos Vinicius", "sobrenome": "da Rocha", "idade": 38, "email": "fbarros@example.net", "data_cadastro": "2024-02-10"}
# Recebido: {"nome": "Juliana", "sobrenome": "da Mata", "idade": 70, "email": "aalves@example.com", "data_cadastro": "2024-08-06"}
# Recebido: {"nome": "Joaquim", "sobrenome": "Viana", "idade": 33, "email": "luiz-fernandodas-neves@example.net", "data_cadastro": "2024-05-12"}
# Recebido: {"nome": "Rebeca", "sobrenome": "Porto", "idade": 29, "email": "yago02@example.net", "data_cadastro": "2024-02-23"}
# Recebido: {"nome": "Alexandre", "sobrenome": "Santos", "idade": 21, "email": "ferreirapedro-henrique@example.org", "data_cadastro": "2024-07-12"}
# Recebido: {"nome": "Leandro", "sobrenome": "Jesus", "idade": 55, "email": "lopesyago@example.com", "data_cadastro": "2024-02-23"}
# Recebido: {"nome": "Davi", "sobrenome": "Silveira", "idade": 52, "email": "egoncalves@example.com", "data_cadastro": "2024-02-10"}
# Recebido: {"nome": "Camila", "sobrenome": "Monteiro", "idade": 49, "email": "maria-ceciliaalves@example.com", "data_cadastro": "2024-04-06"}
# Recebido: {"nome": "Rodrigo", "sobrenome": "Moraes", "idade": 59, "email": "paulolopes@example.net", "data_cadastro": "2024-05-17"}
# Recebido: {"nome": "Carolina", "sobrenome": "Freitas", "idade": 70, "email": "luiz-felipecunha@example.com", "data_cadastro": "2024-02-04"}
# Recebido: {"nome": "Ana L\u00edvia", "sobrenome": "Viana", "idade": 64, "email": "livia06@example.com", "data_cadastro": "2024-04-18"}
# Recebido: {"nome": "Gustavo", "sobrenome": "da Cruz", "idade": 34, "email": "xnascimento@example.com", "data_cadastro": "2024-02-15"}
# Recebido: {"nome": "Ana J\u00falia", "sobrenome": "Cavalcanti", "idade": 48, "email": "lazevedo@example.org", "data_cadastro": "2024-01-24"}
# Recebido: {"nome": "Ben\u00edcio", "sobrenome": "Vieira", "idade": 54, "email": "fernandeseduardo@example.net", "data_cadastro": "2024-06-23"}
# Recebido: {"nome": "Lucas Gabriel", "sobrenome": "Costa", "idade": 63, "email": "zviana@example.org", "data_cadastro": "2024-07-15"}
# Recebido: {"nome": "Fernanda", "sobrenome": "Castro", "idade": 48, "email": "theo77@example.net", "data_cadastro": "2024-04-25"}
# Recebido: {"nome": "Emanuella", "sobrenome": "Almeida", "idade": 25, "email": "maria42@example.net", "data_cadastro": "2024-01-13"}
# Recebido: {"nome": "Pedro Miguel", "sobrenome": "Porto", "idade": 48, "email": "carlos-eduardo99@example.org", "data_cadastro": "2024-04-01"}
# Recebido: {"nome": "Evelyn", "sobrenome": "Castro", "idade": 31, "email": "oliviada-conceicao@example.net", "data_cadastro": "2024-02-27"}
# Recebido: {"nome": "Noah", "sobrenome": "da Cunha", "idade": 47, "email": "nfogaca@example.net", "data_cadastro": "2024-05-17"}
# Recebido: {"nome": "Vitor Hugo", "sobrenome": "Gon\u00e7alves", "idade": 57, "email": "da-rochastephany@example.com", "data_cadastro": "2024-05-10"}
# Recebido: {"nome": "Ana", "sobrenome": "Nogueira", "idade": 30, "email": "sarahda-cruz@example.org", "data_cadastro": "2024-05-13"}
# Recebido: {"nome": "Al\u00edcia", "sobrenome": "Moraes", "idade": 66, "email": "milenarodrigues@example.com", "data_cadastro": "2024-03-21"}
# Recebido: {"nome": "Isabel", "sobrenome": "da Paz", "idade": 37, "email": "rcostela@example.net", "data_cadastro": "2024-01-23"}
# Recebido: {"nome": "Enzo", "sobrenome": "Barros", "idade": 25, "email": "giovanna17@example.com", "data_cadastro": "2024-06-15"}
# Recebido: {"nome": "Ant\u00f4nio", "sobrenome": "Castro", "idade": 51, "email": "cpires@example.com", "data_cadastro": "2024-05-14"}
# Recebido: {"nome": "Renan", "sobrenome": "da Paz", "idade": 46, "email": "nteixeira@example.org", "data_cadastro": "2024-02-25"}
# Recebido: {"nome": "Maria Julia", "sobrenome": "da Concei\u00e7\u00e3o", "idade": 26, "email": "cardosoenzo-gabriel@example.org", "data_cadastro": "2024-06-23"}
# Recebido: {"nome": "Isabella", "sobrenome": "Oliveira", "idade": 41, "email": "elisa15@example.com", "data_cadastro": "2024-01-19"}
# Recebido: {"nome": "Luna", "sobrenome": "Pereira", "idade": 60, "email": "kbarbosa@example.net", "data_cadastro": "2024-02-01"}
# Recebido: {"nome": "Ana Luiza", "sobrenome": "Freitas", "idade": 63, "email": "peixotomaria-cecilia@example.org", "data_cadastro": "2024-02-02"}
# Recebido: {"nome": "Cau\u00e3", "sobrenome": "Barros", "idade": 56, "email": "oalves@example.org", "data_cadastro": "2024-01-05"}
# Recebido: {"nome": "Luiz Henrique", "sobrenome": "Moraes", "idade": 21, "email": "joao-lucas25@example.net", "data_cadastro": "2024-03-19"}
# Recebido: {"nome": "Yuri", "sobrenome": "Campos", "idade": 49, "email": "qmonteiro@example.com", "data_cadastro": "2024-02-14"}
# Recebido: {"nome": "Mait\u00ea", "sobrenome": "da Concei\u00e7\u00e3o", "idade": 57, "email": "ana-beatriz31@example.net", "data_cadastro": "2024-05-04"}
# Recebido: {"nome": "Pietra", "sobrenome": "Cardoso", "idade": 27, "email": "vianadavi-lucas@example.org", "data_cadastro": "2024-04-13"}
# Recebido: {"nome": "Enrico", "sobrenome": "Oliveira", "idade": 29, "email": "costelaguilherme@example.net", "data_cadastro": "2024-06-23"}
# Recebido: {"nome": "Evelyn", "sobrenome": "Gon\u00e7alves", "idade": 43, "email": "heitorrocha@example.com", "data_cadastro": "2024-03-25"}
# Recebido: {"nome": "Juliana", "sobrenome": "Gomes", "idade": 45, "email": "benjamin49@example.org", "data_cadastro": "2024-04-28"}
# Recebido: {"nome": "Alexandre", "sobrenome": "Moreira", "idade": 57, "email": "evelynfarias@example.com", "data_cadastro": "2024-05-08"}
# Recebido: {"nome": "Pedro Henrique", "sobrenome": "Duarte", "idade": 38, "email": "correiajoao-guilherme@example.com", "data_cadastro": "2024-02-03"}
# Recebido: {"nome": "Jo\u00e3o Vitor", "sobrenome": "da Mota", "idade": 59, "email": "joao-vitor12@example.com", "data_cadastro": "2024-03-14"}
# Recebido: {"nome": "Alexia", "sobrenome": "da Rocha", "idade": 56, "email": "milenarodrigues@example.net", "data_cadastro": "2024-01-01"}
# Recebido: {"nome": "Emilly", "sobrenome": "Rodrigues", "idade": 60, "email": "teixeirapedro-miguel@example.net", "data_cadastro": "2024-02-07"}
# Recebido: {"nome": "Kevin", "sobrenome": "Pereira", "idade": 36, "email": "camposdavi@example.com", "data_cadastro": "2024-04-08"}
# Recebido: {"nome": "Heitor", "sobrenome": "da Cunha", "idade": 61, "email": "gnunes@example.com", "data_cadastro": "2024-01-26"}
# Recebido: {"nome": "Miguel", "sobrenome": "da Costa", "idade": 39, "email": "bruno38@example.net", "data_cadastro": "2024-04-30"}
# Recebido: {"nome": "Enzo Gabriel", "sobrenome": "Castro", "idade": 51, "email": "portosabrina@example.com", "data_cadastro": "2024-07-17"}
# Recebido: {"nome": "Nat\u00e1lia", "sobrenome": "Pires", "idade": 29, "email": "uda-costa@example.org", "data_cadastro": "2024-07-16"}
# Recebido: {"nome": "Ana Beatriz", "sobrenome": "da Luz", "idade": 21, "email": "olivia71@example.com", "data_cadastro": "2024-04-19"}
# Recebido: {"nome": "Samuel", "sobrenome": "Cunha", "idade": 63, "email": "cardosoisadora@example.com", "data_cadastro": "2024-05-03"}
# Recebido: {"nome": "Lorena", "sobrenome": "Castro", "idade": 25, "email": "jrodrigues@example.com", "data_cadastro": "2024-05-20"}
# Recebido: {"nome": "Luiz Felipe", "sobrenome": "Ara\u00fajo", "idade": 25, "email": "gabriela43@example.com", "data_cadastro": "2024-05-14"}
# Recebido: {"nome": "Benjamin", "sobrenome": "Rezende", "idade": 41, "email": "pintolucas@example.net", "data_cadastro": "2024-06-18"}
# Recebido: {"nome": "Paulo", "sobrenome": "da Paz", "idade": 18, "email": "pedro-lucas47@example.org", "data_cadastro": "2024-07-29"}
# Recebido: {"nome": "Marcos Vinicius", "sobrenome": "da Mota", "idade": 37, "email": "freitaspedro-miguel@example.org", "data_cadastro": "2024-02-14"}
# Recebido: {"nome": "Bruno", "sobrenome": "Alves", "idade": 69, "email": "emanuellyalves@example.org", "data_cadastro": "2024-07-24"}
# Recebido: {"nome": "Nicolas", "sobrenome": "Martins", "idade": 64, "email": "henrique47@example.com", "data_cadastro": "2024-08-05"}
# Recebido: {"nome": "Ana J\u00falia", "sobrenome": "Barbosa", "idade": 55, "email": "danielada-mota@example.net", "data_cadastro": "2024-04-22"}
# Recebido: {"nome": "Vitor Hugo", "sobrenome": "Foga\u00e7a", "idade": 31, "email": "da-conceicaoluiz-henrique@example.com", "data_cadastro": "2024-07-08"}
# Recebido: {"nome": "Pedro Lucas", "sobrenome": "Pinto", "idade": 53, "email": "rezendeerick@example.com", "data_cadastro": "2024-03-14"}
# Recebido: {"nome": "Enrico", "sobrenome": "da Rosa", "idade": 62, "email": "ana-luiza83@example.net", "data_cadastro": "2024-01-11"}
# Recebido: {"nome": "Theo", "sobrenome": "Nascimento", "idade": 28, "email": "cardosoanthony@example.com", "data_cadastro": "2024-07-12"}
# Recebido: {"nome": "Alexia", "sobrenome": "Rezende", "idade": 56, "email": "da-costadavi-lucas@example.net", "data_cadastro": "2024-06-15"}
# Recebido: {"nome": "Raul", "sobrenome": "Correia", "idade": 19, "email": "arthur20@example.com", "data_cadastro": "2024-02-12"}
# Recebido: {"nome": "Danilo", "sobrenome": "Campos", "idade": 37, "email": "aragaoraul@example.com", "data_cadastro": "2024-07-09"}
# Recebido: {"nome": "Arthur", "sobrenome": "Oliveira", "idade": 58, "email": "luiz-henriquevieira@example.com", "data_cadastro": "2024-05-13"}
# Recebido: {"nome": "Paulo", "sobrenome": "Nunes", "idade": 60, "email": "costastephany@example.org", "data_cadastro": "2024-02-19"}
# Recebido: {"nome": "Raquel", "sobrenome": "Moura", "idade": 50, "email": "ana-vitoriasilva@example.net", "data_cadastro": "2024-02-03"}
# Recebido: {"nome": "Luigi", "sobrenome": "da Cunha", "idade": 50, "email": "miguelda-cunha@example.org", "data_cadastro": "2024-01-09"}
# Recebido: {"nome": "Noah", "sobrenome": "Castro", "idade": 27, "email": "luiz-miguelsantos@example.org", "data_cadastro": "2024-06-26"}
# Recebido: {"nome": "Luiz Fernando", "sobrenome": "Cardoso", "idade": 54, "email": "davi-luiz29@example.com", "data_cadastro": "2024-02-25"}
# Recebido: {"nome": "Yasmin", "sobrenome": "da Costa", "idade": 34, "email": "amandada-mata@example.net", "data_cadastro": "2024-07-12"}
# Recebido: {"nome": "Ant\u00f4nio", "sobrenome": "Cardoso", "idade": 38, "email": "almeidaaugusto@example.com", "data_cadastro": "2024-02-24"}
# Recebido: {"nome": "Joana", "sobrenome": "da Rocha", "idade": 18, "email": "csouza@example.org", "data_cadastro": "2024-05-30"}
# Recebido: {"nome": "Luiz Fernando", "sobrenome": "Correia", "idade": 58, "email": "moraesleticia@example.org", "data_cadastro": "2024-05-20"}
# Recebido: {"nome": "Esther", "sobrenome": "Teixeira", "idade": 44, "email": "costeladiogo@example.org", "data_cadastro": "2024-08-01"}
# Recebido: {"nome": "Carolina", "sobrenome": "Viana", "idade": 60, "email": "joao-felipe94@example.org", "data_cadastro": "2024-04-07"}
# Recebido: {"nome": "Maria Vit\u00f3ria", "sobrenome": "Barbosa", "idade": 26, "email": "henrique48@example.com", "data_cadastro": "2024-01-25"}
# Recebido: {"nome": "Anthony", "sobrenome": "Moura", "idade": 39, "email": "igorcampos@example.com", "data_cadastro": "2024-06-15"}
# Recebido: {"nome": "Melissa", "sobrenome": "Silveira", "idade": 50, "email": "pedrocorreia@example.net", "data_cadastro": "2024-04-03"}
# Recebido: {"nome": "Milena", "sobrenome": "das Neves", "idade": 20, "email": "livia45@example.org", "data_cadastro": "2024-03-18"}
# Recebido: {"nome": "Ana Clara", "sobrenome": "Jesus", "idade": 22, "email": "acardoso@example.org", "data_cadastro": "2024-02-13"}
# Recebido: {"nome": "Samuel", "sobrenome": "Monteiro", "idade": 37, "email": "ceciliada-mata@example.com", "data_cadastro": "2024-05-30"}
# Recebido: {"nome": "Ana L\u00edvia", "sobrenome": "Arag\u00e3o", "idade": 51, "email": "ecosta@example.com", "data_cadastro": "2024-07-20"}
# Recebido: {"nome": "Ana Sophia", "sobrenome": "Mendes", "idade": 55, "email": "marcelafarias@example.org", "data_cadastro": "2024-06-21"}
# Recebido: {"nome": "Davi", "sobrenome": "Costa", "idade": 58, "email": "benicio60@example.net", "data_cadastro": "2024-06-18"}
# Recebido: {"nome": "Alexandre", "sobrenome": "Azevedo", "idade": 58, "email": "caua54@example.net", "data_cadastro": "2024-05-11"}
# Recebido: {"nome": "Bianca", "sobrenome": "da Luz", "idade": 36, "email": "nicole19@example.com", "data_cadastro": "2024-04-26"}
# Recebido: {"nome": "Maria", "sobrenome": "Mendes", "idade": 43, "email": "portolais@example.com", "data_cadastro": "2024-06-10"}
# Recebido: {"nome": "Davi", "sobrenome": "Duarte", "idade": 23, "email": "da-luzlucas@example.org", "data_cadastro": "2024-01-07"}
# Recebido: {"nome": "Enzo Gabriel", "sobrenome": "Moraes", "idade": 67, "email": "cviana@example.net", "data_cadastro": "2024-02-12"}
# Recebido: {"nome": "Helo\u00edsa", "sobrenome": "Barbosa", "idade": 43, "email": "da-rosacaue@example.net", "data_cadastro": "2024-07-15"}
# Recebido: {"nome": "Mirella", "sobrenome": "da Cruz", "idade": 67, "email": "lorena32@example.com", "data_cadastro": "2024-04-03"}
# Recebido: {"nome": "Marcos Vinicius", "sobrenome": "Sales", "idade": 54, "email": "pietracorreia@example.com", "data_cadastro": "2024-01-15"}
# Recebido: {"nome": "Olivia", "sobrenome": "Oliveira", "idade": 68, "email": "paulocosta@example.com", "data_cadastro": "2024-02-21"}
# Recebido: {"nome": "Luiz Gustavo", "sobrenome": "das Neves", "idade": 27, "email": "marcelo04@example.net", "data_cadastro": "2024-04-10"}
# Recebido: {"nome": "Lav\u00ednia", "sobrenome": "Campos", "idade": 49, "email": "lorenzoda-mata@example.org", "data_cadastro": "2024-05-27"}
# Recebido: {"nome": "Larissa", "sobrenome": "Porto", "idade": 42, "email": "antonio75@example.com", "data_cadastro": "2024-03-12"}
# Recebido: {"nome": "Jo\u00e3o Felipe", "sobrenome": "Gon\u00e7alves", "idade": 63, "email": "kgoncalves@example.com", "data_cadastro": "2024-04-05"}
# Recebido: {"nome": "Sophie", "sobrenome": "Pinto", "idade": 20, "email": "souzaluiz-gustavo@example.org", "data_cadastro": "2024-05-11"}
# Recebido: {"nome": "Leandro", "sobrenome": "Ribeiro", "idade": 61, "email": "pedro-miguelrocha@example.net", "data_cadastro": "2024-01-07"}
# Recebido: {"nome": "Isis", "sobrenome": "Mendes", "idade": 45, "email": "moreirasofia@example.org", "data_cadastro": "2024-04-08"}
# Recebido: {"nome": "Kamilly", "sobrenome": "Moreira", "idade": 24, "email": "liviada-costa@example.org", "data_cadastro": "2024-06-06"}
# Recebido: {"nome": "Enzo", "sobrenome": "Campos", "idade": 36, "email": "lmartins@example.com", "data_cadastro": "2024-07-15"}
# Recebido: {"nome": "Calebe", "sobrenome": "Costa", "idade": 33, "email": "barroserick@example.com", "data_cadastro": "2024-04-27"}
# Recebido: {"nome": "Jo\u00e3o", "sobrenome": "Jesus", "idade": 30, "email": "rochadavi-luiz@example.com", "data_cadastro": "2024-06-08"}
# Recebido: {"nome": "Gustavo Henrique", "sobrenome": "Moraes", "idade": 67, "email": "beatriz81@example.org", "data_cadastro": "2024-02-05"}
# Recebido: {"nome": "Renan", "sobrenome": "da Cunha", "idade": 33, "email": "hda-cunha@example.com", "data_cadastro": "2024-07-16"}
# Recebido: {"nome": "Breno", "sobrenome": "Vieira", "idade": 45, "email": "joao-vitor14@example.org", "data_cadastro": "2024-06-02"}
# Recebido: {"nome": "Paulo", "sobrenome": "Caldeira", "idade": 28, "email": "maria-ceciliacardoso@example.org", "data_cadastro": "2024-04-21"}
# Recebido: {"nome": "Emilly", "sobrenome": "Mendes", "idade": 28, "email": "wcostela@example.org", "data_cadastro": "2024-03-28"}
# Recebido: {"nome": "Ana Vit\u00f3ria", "sobrenome": "da Cunha", "idade": 51, "email": "rafael01@example.com", "data_cadastro": "2024-06-18"}
# Recebido: {"nome": "Luiz Fernando", "sobrenome": "Martins", "idade": 48, "email": "sabrinavieira@example.org", "data_cadastro": "2024-05-28"}
# Recebido: {"nome": "Luana", "sobrenome": "da Cruz", "idade": 37, "email": "agathapinto@example.org", "data_cadastro": "2024-04-22"}
# Recebido: {"nome": "Clarice", "sobrenome": "da Rocha", "idade": 70, "email": "oliviaalves@example.net", "data_cadastro": "2024-07-26"}
# Recebido: {"nome": "Sabrina", "sobrenome": "da Rocha", "idade": 46, "email": "leticia90@example.org", "data_cadastro": "2024-06-02"}
# Recebido: {"nome": "Breno", "sobrenome": "Cardoso", "idade": 21, "email": "vicente26@example.org", "data_cadastro": "2024-04-04"}
# Recebido: {"nome": "Manuela", "sobrenome": "da Paz", "idade": 32, "email": "qsouza@example.org", "data_cadastro": "2024-06-01"}
# Recebido: {"nome": "Diego", "sobrenome": "Silva", "idade": 43, "email": "ribeirokaique@example.net", "data_cadastro": "2024-03-31"}
# Recebido: {"nome": "Yuri", "sobrenome": "Fernandes", "idade": 70, "email": "cavalcantielisa@example.com", "data_cadastro": "2024-06-17"}
# Recebido: {"nome": "Jo\u00e3o Guilherme", "sobrenome": "Lopes", "idade": 41, "email": "pcosta@example.org", "data_cadastro": "2024-04-11"}
# Recebido: {"nome": "Heitor", "sobrenome": "Barbosa", "idade": 34, "email": "mendesvitor-gabriel@example.org", "data_cadastro": "2024-05-22"}
# Recebido: {"nome": "J\u00falia", "sobrenome": "Moraes", "idade": 20, "email": "das-nevesana-julia@example.org", "data_cadastro": "2024-04-08"}
# Recebido: {"nome": "Gabrielly", "sobrenome": "Ramos", "idade": 70, "email": "evelyn84@example.net", "data_cadastro": "2024-06-07"}
# Recebido: {"nome": "Isabel", "sobrenome": "Arag\u00e3o", "idade": 56, "email": "noahpinto@example.com", "data_cadastro": "2024-03-24"}
# Recebido: {"nome": "Luiz Fernando", "sobrenome": "Cardoso", "idade": 57, "email": "martinssofia@example.org", "data_cadastro": "2024-01-25"}
# Recebido: {"nome": "Paulo", "sobrenome": "Oliveira", "idade": 63, "email": "augustocunha@example.org", "data_cadastro": "2024-03-05"}
# Recebido: {"nome": "Ana Clara", "sobrenome": "Ribeiro", "idade": 69, "email": "noahda-rosa@example.net", "data_cadastro": "2024-07-01"}
# Recebido: {"nome": "Laura", "sobrenome": "Viana", "idade": 55, "email": "maysa15@example.org", "data_cadastro": "2024-02-15"}
# Recebido: {"nome": "Ana Carolina", "sobrenome": "Monteiro", "idade": 55, "email": "alexiafarias@example.org", "data_cadastro": "2024-06-25"}
# Recebido: {"nome": "Pedro", "sobrenome": "Gon\u00e7alves", "idade": 61, "email": "rteixeira@example.net", "data_cadastro": "2024-07-05"}
# Recebido: {"nome": "Yasmin", "sobrenome": "Jesus", "idade": 41, "email": "sviana@example.com", "data_cadastro": "2024-01-27"}
# Recebido: {"nome": "Alana", "sobrenome": "Ramos", "idade": 54, "email": "beatrizmonteiro@example.org", "data_cadastro": "2024-06-10"}
# Recebido: {"nome": "Benjamin", "sobrenome": "Souza", "idade": 34, "email": "yduarte@example.org", "data_cadastro": "2024-03-27"}
# Recebido: {"nome": "Sophia", "sobrenome": "Nascimento", "idade": 43, "email": "umelo@example.net", "data_cadastro": "2024-01-15"}
# Recebido: {"nome": "Ana Beatriz", "sobrenome": "Jesus", "idade": 50, "email": "da-costaisabella@example.net", "data_cadastro": "2024-01-16"}
# Recebido: {"nome": "Luiz Henrique", "sobrenome": "Carvalho", "idade": 21, "email": "da-motagustavo-henrique@example.net", "data_cadastro": "2024-03-30"}
# Recebido: {"nome": "Mait\u00ea", "sobrenome": "Silveira", "idade": 28, "email": "gcorreia@example.org", "data_cadastro": "2024-01-25"}
# Recebido: {"nome": "Marcos Vinicius", "sobrenome": "Costa", "idade": 48, "email": "hnogueira@example.com", "data_cadastro": "2024-01-30"}
# Recebido: {"nome": "Helo\u00edsa", "sobrenome": "Ribeiro", "idade": 54, "email": "cda-paz@example.org", "data_cadastro": "2024-03-02"}
# Recebido: {"nome": "Ryan", "sobrenome": "Barros", "idade": 30, "email": "vitoria84@example.net", "data_cadastro": "2024-07-03"}
# Recebido: {"nome": "Maria Sophia", "sobrenome": "Rodrigues", "idade": 65, "email": "nmoura@example.com", "data_cadastro": "2024-04-15"}
# Recebido: {"nome": "Lucas", "sobrenome": "Sales", "idade": 35, "email": "fernandocavalcanti@example.org", "data_cadastro": "2024-07-20"}
# Recebido: {"nome": "Maria Alice", "sobrenome": "Foga\u00e7a", "idade": 68, "email": "bruna25@example.net", "data_cadastro": "2024-07-11"}
# Recebido: {"nome": "Elisa", "sobrenome": "Moraes", "idade": 41, "email": "enzo-gabrielrocha@example.com", "data_cadastro": "2024-04-01"}
# Recebido: {"nome": "Cec\u00edlia", "sobrenome": "Viana", "idade": 48, "email": "monteirorenan@example.org", "data_cadastro": "2024-05-16"}
# Recebido: {"nome": "Alexia", "sobrenome": "Gomes", "idade": 45, "email": "lunaramos@example.net", "data_cadastro": "2024-06-22"}
# Recebido: {"nome": "Renan", "sobrenome": "Rocha", "idade": 43, "email": "tnascimento@example.net", "data_cadastro": "2024-03-08"}
# Recebido: {"nome": "Lucas Gabriel", "sobrenome": "Correia", "idade": 28, "email": "pedro-lucas70@example.org", "data_cadastro": "2024-07-24"}
# Recebido: {"nome": "Ana Laura", "sobrenome": "Nunes", "idade": 37, "email": "mirella42@example.net", "data_cadastro": "2024-03-19"}
# Recebido: {"nome": "Amanda", "sobrenome": "Moreira", "idade": 47, "email": "gustavo-henrique70@example.org", "data_cadastro": "2024-01-14"}
# Recebido: {"nome": "Nicole", "sobrenome": "Monteiro", "idade": 31, "email": "zfreitas@example.org", "data_cadastro": "2024-01-08"}
# Recebido: {"nome": "Matheus", "sobrenome": "Cavalcanti", "idade": 20, "email": "melissa17@example.net", "data_cadastro": "2024-03-05"}
# Recebido: {"nome": "Carolina", "sobrenome": "Costela", "idade": 25, "email": "da-motafelipe@example.org", "data_cadastro": "2024-02-04"}
# Recebido: {"nome": "Leonardo", "sobrenome": "Nogueira", "idade": 27, "email": "luana09@example.org", "data_cadastro": "2024-04-28"}
# Recebido: {"nome": "J\u00falia", "sobrenome": "Nunes", "idade": 70, "email": "kamillysilveira@example.net", "data_cadastro": "2024-02-28"}
# Recebido: {"nome": "Leonardo", "sobrenome": "Carvalho", "idade": 37, "email": "vieiraraquel@example.com", "data_cadastro": "2024-03-04"}
# Recebido: {"nome": "Vitor", "sobrenome": "Melo", "idade": 56, "email": "wcampos@example.net", "data_cadastro": "2024-07-30"}
# Recebido: {"nome": "J\u00falia", "sobrenome": "Moraes", "idade": 54, "email": "carvalhojoao-gabriel@example.org", "data_cadastro": "2024-02-24"}
# Recebido: {"nome": "Catarina", "sobrenome": "Martins", "idade": 30, "email": "pcunha@example.com", "data_cadastro": "2024-03-31"}
# Recebido: {"nome": "Igor", "sobrenome": "Gomes", "idade": 68, "email": "xda-mata@example.com", "data_cadastro": "2024-06-18"}
# Recebido: {"nome": "Lara", "sobrenome": "Cardoso", "idade": 57, "email": "duarteamanda@example.org", "data_cadastro": "2024-03-13"}
# Recebido: {"nome": "Mirella", "sobrenome": "Nascimento", "idade": 37, "email": "vitor-gabrielda-cruz@example.org", "data_cadastro": "2024-07-20"}
# Recebido: {"nome": "Mirella", "sobrenome": "Farias", "idade": 23, "email": "rlopes@example.net", "data_cadastro": "2024-01-25"}
# Recebido: {"nome": "Ana", "sobrenome": "Correia", "idade": 59, "email": "maria-alice13@example.com", "data_cadastro": "2024-03-22"}
# Recebido: {"nome": "Fernando", "sobrenome": "Costela", "idade": 61, "email": "sda-luz@example.com", "data_cadastro": "2024-03-11"}
# Recebido: {"nome": "Mirella", "sobrenome": "Novaes", "idade": 51, "email": "cardosolorena@example.com", "data_cadastro": "2024-07-16"}
# Recebido: {"nome": "Theo", "sobrenome": "da Mata", "idade": 45, "email": "da-pazdaniel@example.net", "data_cadastro": "2024-06-25"}
# Recebido: {"nome": "Joana", "sobrenome": "Gomes", "idade": 44, "email": "vitorcardoso@example.net", "data_cadastro": "2024-04-08"}
# Recebido: {"nome": "Marcelo", "sobrenome": "Farias", "idade": 54, "email": "bnogueira@example.net", "data_cadastro": "2024-06-11"}
# Recebido: {"nome": "Leandro", "sobrenome": "Ribeiro", "idade": 50, "email": "iteixeira@example.net", "data_cadastro": "2024-04-21"}
# Recebido: {"nome": "Alexandre", "sobrenome": "Pires", "idade": 49, "email": "omoraes@example.net", "data_cadastro": "2024-06-06"}
# Recebido: {"nome": "Vitor", "sobrenome": "da Cruz", "idade": 37, "email": "alanapinto@example.net", "data_cadastro": "2024-06-02"}
# Recebido: {"nome": "Eloah", "sobrenome": "Nascimento", "idade": 67, "email": "marianerezende@example.org", "data_cadastro": "2024-01-12"}
# Recebido: {"nome": "Pedro", "sobrenome": "Martins", "idade": 24, "email": "thomas53@example.com", "data_cadastro": "2024-01-09"}
# Recebido: {"nome": "Gabriel", "sobrenome": "Fernandes", "idade": 26, "email": "noliveira@example.org", "data_cadastro": "2024-01-10"}
# Recebido: {"nome": "Leandro", "sobrenome": "Rezende", "idade": 54, "email": "fariasemanuel@example.net", "data_cadastro": "2024-06-15"}
# Recebido: {"nome": "Marcela", "sobrenome": "Souza", "idade": 21, "email": "limapaulo@example.com", "data_cadastro": "2024-04-20"}
# Recebido: {"nome": "Ben\u00edcio", "sobrenome": "Dias", "idade": 51, "email": "milena75@example.com", "data_cadastro": "2024-04-17"}
# Recebido: {"nome": "Emanuella", "sobrenome": "Barros", "idade": 31, "email": "npereira@example.net", "data_cadastro": "2024-06-08"}
# Recebido: {"nome": "Guilherme", "sobrenome": "Caldeira", "idade": 48, "email": "rafaela39@example.com", "data_cadastro": "2024-08-02"}
# Recebido: {"nome": "Maria Fernanda", "sobrenome": "da Rosa", "idade": 36, "email": "bryan39@example.com", "data_cadastro": "2024-01-14"}
# Recebido: {"nome": "Pietra", "sobrenome": "Freitas", "idade": 41, "email": "raul84@example.com", "data_cadastro": "2024-02-04"}
# Recebido: {"nome": "Augusto", "sobrenome": "Barros", "idade": 35, "email": "marina55@example.net", "data_cadastro": "2024-01-24"}
# Recebido: {"nome": "Ana", "sobrenome": "Jesus", "idade": 28, "email": "luigiaragao@example.org", "data_cadastro": "2024-06-09"}
# Recebido: {"nome": "Raquel", "sobrenome": "da Rosa", "idade": 24, "email": "erickda-cruz@example.com", "data_cadastro": "2024-02-06"}
# Recebido: {"nome": "Nat\u00e1lia", "sobrenome": "Rezende", "idade": 20, "email": "nascimentoguilherme@example.org", "data_cadastro": "2024-03-24"}
# Recebido: {"nome": "Maria Fernanda", "sobrenome": "Castro", "idade": 18, "email": "aliciapinto@example.net", "data_cadastro": "2024-05-21"}
# Recebido: {"nome": "Sophie", "sobrenome": "da Rosa", "idade": 28, "email": "sda-rosa@example.com", "data_cadastro": "2024-04-14"}
# Recebido: {"nome": "Caio", "sobrenome": "Campos", "idade": 50, "email": "fernandesryan@example.org", "data_cadastro": "2024-03-15"}
# Recebido: {"nome": "Nathan", "sobrenome": "Alves", "idade": 61, "email": "xviana@example.net", "data_cadastro": "2024-03-13"}
# Recebido: {"nome": "Maria Alice", "sobrenome": "da Costa", "idade": 32, "email": "lucasfernandes@example.com", "data_cadastro": "2024-06-16"}
# Recebido: {"nome": "Sophie", "sobrenome": "Nascimento", "idade": 43, "email": "maysateixeira@example.org", "data_cadastro": "2024-05-14"}
# Recebido: {"nome": "Ryan", "sobrenome": "Moura", "idade": 67, "email": "diegopeixoto@example.org", "data_cadastro": "2024-02-28"}
# Recebido: {"nome": "Ana Julia", "sobrenome": "Campos", "idade": 36, "email": "mirella44@example.com", "data_cadastro": "2024-05-02"}
# Recebido: {"nome": "Gabriela", "sobrenome": "Campos", "idade": 18, "email": "mariabarbosa@example.org", "data_cadastro": "2024-07-02"}
# Recebido: {"nome": "Henrique", "sobrenome": "Sales", "idade": 45, "email": "da-cruzcaue@example.com", "data_cadastro": "2024-02-04"}
# Recebido: {"nome": "Jo\u00e3o Miguel", "sobrenome": "Dias", "idade": 23, "email": "claramonteiro@example.org", "data_cadastro": "2024-07-31"}
# Recebido: {"nome": "Ana Julia", "sobrenome": "Melo", "idade": 26, "email": "xcardoso@example.net", "data_cadastro": "2024-03-12"}
# Recebido: {"nome": "Isaac", "sobrenome": "Moreira", "idade": 63, "email": "martinssofia@example.com", "data_cadastro": "2024-02-25"}
# Recebido: {"nome": "Melissa", "sobrenome": "Porto", "idade": 69, "email": "irezende@example.com", "data_cadastro": "2024-03-25"}
# Recebido: {"nome": "Emanuel", "sobrenome": "Porto", "idade": 43, "email": "andre38@example.net", "data_cadastro": "2024-02-12"}
# Recebido: {"nome": "Luiz Ot\u00e1vio", "sobrenome": "Teixeira", "idade": 38, "email": "andre31@example.net", "data_cadastro": "2024-03-31"}
# Recebido: {"nome": "Helena", "sobrenome": "Ferreira", "idade": 49, "email": "leonardo85@example.net", "data_cadastro": "2024-06-29"}
# Recebido: {"nome": "Bernardo", "sobrenome": "Freitas", "idade": 35, "email": "lramos@example.com", "data_cadastro": "2024-07-10"}
# Recebido: {"nome": "Al\u00edcia", "sobrenome": "Carvalho", "idade": 24, "email": "santosjoao-vitor@example.com", "data_cadastro": "2024-05-29"}
# Recebido: {"nome": "Lav\u00ednia", "sobrenome": "Cardoso", "idade": 58, "email": "luiz-henriqueda-rocha@example.net", "data_cadastro": "2024-05-19"}
# Recebido: {"nome": "Luana", "sobrenome": "Rezende", "idade": 30, "email": "da-conceicaomarcos-vinicius@example.net", "data_cadastro": "2024-05-19"}
# Recebido: {"nome": "Nina", "sobrenome": "Arag\u00e3o", "idade": 47, "email": "kaique30@example.org", "data_cadastro": "2024-05-09"}
# Recebido: {"nome": "Henrique", "sobrenome": "Pinto", "idade": 43, "email": "gustavo-henriquesouza@example.net", "data_cadastro": "2024-07-31"}
# Recebido: {"nome": "Pietro", "sobrenome": "Moreira", "idade": 21, "email": "clarice90@example.net", "data_cadastro": "2024-07-25"}
# Recebido: {"nome": "Maria Julia", "sobrenome": "Gon\u00e7alves", "idade": 53, "email": "luna52@example.com", "data_cadastro": "2024-03-20"}
# Recebido: {"nome": "Nicole", "sobrenome": "Cardoso", "idade": 37, "email": "da-conceicaoanthony@example.net", "data_cadastro": "2024-05-19"}
# Recebido: {"nome": "Jo\u00e3o Vitor", "sobrenome": "Arag\u00e3o", "idade": 35, "email": "vitoria30@example.com", "data_cadastro": "2024-01-12"}
# Recebido: {"nome": "Manuela", "sobrenome": "Silveira", "idade": 60, "email": "erickjesus@example.org", "data_cadastro": "2024-05-25"}
# Recebido: {"nome": "Nat\u00e1lia", "sobrenome": "Caldeira", "idade": 38, "email": "larissalopes@example.com", "data_cadastro": "2024-01-29"}
# Recebido: {"nome": "Lav\u00ednia", "sobrenome": "da Paz", "idade": 55, "email": "sabrinada-cruz@example.org", "data_cadastro": "2024-05-21"}
# Recebido: {"nome": "Milena", "sobrenome": "Souza", "idade": 23, "email": "davi-luiz46@example.net", "data_cadastro": "2024-04-30"}
# Recebido: {"nome": "Lorenzo", "sobrenome": "Mendes", "idade": 63, "email": "da-cruzsophia@example.com", "data_cadastro": "2024-06-13"}
# Recebido: {"nome": "Lara", "sobrenome": "Cavalcanti", "idade": 42, "email": "ucarvalho@example.com", "data_cadastro": "2024-06-24"}
# Recebido: {"nome": "Helena", "sobrenome": "Gon\u00e7alves", "idade": 66, "email": "caldeiraisabelly@example.net", "data_cadastro": "2024-06-28"}
# Recebido: {"nome": "Ben\u00edcio", "sobrenome": "da Rosa", "idade": 33, "email": "vitor-gabrielda-luz@example.net", "data_cadastro": "2024-08-08"}
# Recebido: {"nome": "Noah", "sobrenome": "da Cunha", "idade": 44, "email": "enzonogueira@example.com", "data_cadastro": "2024-01-05"}
# Recebido: {"nome": "Valentina", "sobrenome": "Ramos", "idade": 50, "email": "hribeiro@example.org", "data_cadastro": "2024-07-17"}
# Recebido: {"nome": "Bruna", "sobrenome": "Costa", "idade": 35, "email": "da-motaleonardo@example.com", "data_cadastro": "2024-01-26"}
# Recebido: {"nome": "Jo\u00e3o Gabriel", "sobrenome": "Cardoso", "idade": 23, "email": "lavinia75@example.com", "data_cadastro": "2024-02-25"}
# Recebido: {"nome": "Ana", "sobrenome": "Fernandes", "idade": 68, "email": "roliveira@example.com", "data_cadastro": "2024-03-14"}
# Recebido: {"nome": "Mait\u00ea", "sobrenome": "da Luz", "idade": 31, "email": "tmartins@example.net", "data_cadastro": "2024-05-04"}
# Recebido: {"nome": "Isabella", "sobrenome": "Lima", "idade": 68, "email": "moraesyasmin@example.com", "data_cadastro": "2024-06-20"}
# Recebido: {"nome": "Gustavo", "sobrenome": "Azevedo", "idade": 40, "email": "olima@example.net", "data_cadastro": "2024-07-23"}
# Recebido: {"nome": "Isabella", "sobrenome": "Foga\u00e7a", "idade": 43, "email": "teixeirajulia@example.com", "data_cadastro": "2024-01-30"}
# Recebido: {"nome": "Caroline", "sobrenome": "Sales", "idade": 34, "email": "eteixeira@example.net", "data_cadastro": "2024-01-07"}
# Recebido: {"nome": "Stephany", "sobrenome": "Barros", "idade": 32, "email": "lopesana-julia@example.net", "data_cadastro": "2024-01-27"}
# Recebido: {"nome": "Igor", "sobrenome": "Rocha", "idade": 65, "email": "duarteenzo@example.org", "data_cadastro": "2024-02-19"}
# Recebido: {"nome": "Mariana", "sobrenome": "Vieira", "idade": 57, "email": "zcastro@example.org", "data_cadastro": "2024-05-18"}
# Recebido: {"nome": "Pietra", "sobrenome": "Lopes", "idade": 54, "email": "zda-cruz@example.net", "data_cadastro": "2024-07-13"}
# Recebido: {"nome": "Sophie", "sobrenome": "Nascimento", "idade": 24, "email": "ribeiroana-luiza@example.org", "data_cadastro": "2024-02-11"}
# Recebido: {"nome": "Jo\u00e3o Guilherme", "sobrenome": "Ramos", "idade": 37, "email": "diego80@example.net", "data_cadastro": "2024-02-29"}
# Recebido: {"nome": "Kaique", "sobrenome": "das Neves", "idade": 31, "email": "xmartins@example.net", "data_cadastro": "2024-04-30"}
# Recebido: {"nome": "Benjamin", "sobrenome": "Pereira", "idade": 42, "email": "costamarcos-vinicius@example.org", "data_cadastro": "2024-04-14"}
# Recebido: {"nome": "Danilo", "sobrenome": "Porto", "idade": 26, "email": "lopesisabel@example.net", "data_cadastro": "2024-06-01"}
# Recebido: {"nome": "Emanuelly", "sobrenome": "das Neves", "idade": 50, "email": "leticiasilva@example.net", "data_cadastro": "2024-06-19"}
# Recebido: {"nome": "Jo\u00e3o Felipe", "sobrenome": "Monteiro", "idade": 28, "email": "teixeirasofia@example.org", "data_cadastro": "2024-01-03"}
# Recebido: {"nome": "Ana Julia", "sobrenome": "da Rosa", "idade": 57, "email": "fogacaluiz-fernando@example.org", "data_cadastro": "2024-08-05"}
# Recebido: {"nome": "Ana", "sobrenome": "Viana", "idade": 19, "email": "joliveira@example.net", "data_cadastro": "2024-05-26"}
# Recebido: {"nome": "Ana Vit\u00f3ria", "sobrenome": "Ribeiro", "idade": 66, "email": "joaobarbosa@example.net", "data_cadastro": "2024-03-09"}
# Recebido: {"nome": "Manuela", "sobrenome": "Carvalho", "idade": 64, "email": "znascimento@example.net", "data_cadastro": "2024-07-08"}
# Recebido: {"nome": "Olivia", "sobrenome": "Viana", "idade": 63, "email": "snunes@example.org", "data_cadastro": "2024-03-28"}
# Recebido: {"nome": "Leonardo", "sobrenome": "Foga\u00e7a", "idade": 50, "email": "vicentecorreia@example.net", "data_cadastro": "2024-03-05"}
# Recebido: {"nome": "Nina", "sobrenome": "Moura", "idade": 36, "email": "diogo60@example.org", "data_cadastro": "2024-07-19"}
# Recebido: {"nome": "Isabel", "sobrenome": "Arag\u00e3o", "idade": 19, "email": "yda-costa@example.net", "data_cadastro": "2024-06-03"}
# Recebido: {"nome": "Marina", "sobrenome": "Viana", "idade": 50, "email": "eda-rosa@example.org", "data_cadastro": "2024-01-20"}
# Recebido: {"nome": "Davi Lucca", "sobrenome": "Novaes", "idade": 36, "email": "davi-luiz06@example.org", "data_cadastro": "2024-06-19"}
# Recebido: {"nome": "Esther", "sobrenome": "Silveira", "idade": 29, "email": "carlos-eduardo15@example.net", "data_cadastro": "2024-04-24"}
# Recebido: {"nome": "Nat\u00e1lia", "sobrenome": "Correia", "idade": 38, "email": "carolina58@example.com", "data_cadastro": "2024-04-20"}
# Recebido: {"nome": "Vinicius", "sobrenome": "Farias", "idade": 69, "email": "fernando29@example.net", "data_cadastro": "2024-05-05"}
# Recebido: {"nome": "Maria Julia", "sobrenome": "Moraes", "idade": 50, "email": "camposana-carolina@example.com", "data_cadastro": "2024-03-06"}
# Recebido: {"nome": "Matheus", "sobrenome": "Dias", "idade": 29, "email": "dpereira@example.net", "data_cadastro": "2024-06-10"}
# Recebido: {"nome": "Nina", "sobrenome": "Nunes", "idade": 66, "email": "ana-luiza28@example.com", "data_cadastro": "2024-07-09"}
# Recebido: {"nome": "Andr\u00e9", "sobrenome": "Caldeira", "idade": 51, "email": "evelyncarvalho@example.com", "data_cadastro": "2024-04-10"}
# Recebido: {"nome": "Maysa", "sobrenome": "Pinto", "idade": 40, "email": "almeidarafael@example.com", "data_cadastro": "2024-05-05"}
# Recebido: {"nome": "Thomas", "sobrenome": "Freitas", "idade": 34, "email": "da-pazluiz-fernando@example.org", "data_cadastro": "2024-04-15"}
# Recebido: {"nome": "Ana L\u00edvia", "sobrenome": "Pereira", "idade": 38, "email": "gviana@example.org", "data_cadastro": "2024-06-21"}
# Recebido: {"nome": "Ana Clara", "sobrenome": "Lima", "idade": 30, "email": "davi-luiz18@example.net", "data_cadastro": "2024-06-10"}
# Recebido: {"nome": "Cec\u00edlia", "sobrenome": "Melo", "idade": 62, "email": "hda-paz@example.org", "data_cadastro": "2024-01-05"}
# Recebido: {"nome": "Manuela", "sobrenome": "Correia", "idade": 63, "email": "hnogueira@example.org", "data_cadastro": "2024-05-18"}
# Recebido: {"nome": "Theo", "sobrenome": "Martins", "idade": 55, "email": "beniciocampos@example.net", "data_cadastro": "2024-04-03"}
# Recebido: {"nome": "Calebe", "sobrenome": "Martins", "idade": 55, "email": "marcos-viniciusgomes@example.org", "data_cadastro": "2024-04-19"}
# Recebido: {"nome": "Paulo", "sobrenome": "Freitas", "idade": 67, "email": "ateixeira@example.net", "data_cadastro": "2024-07-08"}
# Recebido: {"nome": "Vitor", "sobrenome": "Correia", "idade": 26, "email": "clarice38@example.org", "data_cadastro": "2024-01-15"}
# Recebido: {"nome": "Luiz Henrique", "sobrenome": "Azevedo", "idade": 59, "email": "moreiraana-carolina@example.net", "data_cadastro": "2024-05-20"}
# Recebido: {"nome": "Laura", "sobrenome": "Azevedo", "idade": 61, "email": "vianalara@example.org", "data_cadastro": "2024-06-05"}
# Recebido: {"nome": "Maria Vit\u00f3ria", "sobrenome": "Arag\u00e3o", "idade": 27, "email": "maria-fernandaramos@example.net", "data_cadastro": "2024-03-22"}
# Recebido: {"nome": "Isis", "sobrenome": "Almeida", "idade": 26, "email": "da-rochamarcela@example.net", "data_cadastro": "2024-03-28"}
# Recebido: {"nome": "Pedro Lucas", "sobrenome": "Nogueira", "idade": 40, "email": "holiveira@example.com", "data_cadastro": "2024-02-22"}
# Recebido: {"nome": "Enzo Gabriel", "sobrenome": "Cavalcanti", "idade": 36, "email": "lucas-gabrielsilveira@example.org", "data_cadastro": "2024-02-04"}
# Recebido: {"nome": "Pietro", "sobrenome": "Ramos", "idade": 44, "email": "kfarias@example.org", "data_cadastro": "2024-06-22"}
# Recebido: {"nome": "Luiz Ot\u00e1vio", "sobrenome": "Costa", "idade": 53, "email": "maria-clarada-cunha@example.net", "data_cadastro": "2024-07-30"}
# Recebido: {"nome": "Fernanda", "sobrenome": "Nascimento", "idade": 43, "email": "lnovaes@example.org", "data_cadastro": "2024-02-14"}
# Recebido: {"nome": "Gustavo Henrique", "sobrenome": "Freitas", "idade": 70, "email": "kpinto@example.com", "data_cadastro": "2024-02-23"}
# Recebido: {"nome": "Pietra", "sobrenome": "Correia", "idade": 67, "email": "oliviaferreira@example.com", "data_cadastro": "2024-05-20"}
# Recebido: {"nome": "Lucas", "sobrenome": "da Costa", "idade": 53, "email": "sophie34@example.org", "data_cadastro": "2024-01-19"}
# Recebido: {"nome": "Jo\u00e3o Miguel", "sobrenome": "Gon\u00e7alves", "idade": 60, "email": "eduarda60@example.com", "data_cadastro": "2024-06-18"}
# Recebido: {"nome": "Nicole", "sobrenome": "Martins", "idade": 67, "email": "emanuellada-cruz@example.com", "data_cadastro": "2024-02-28"}
# Recebido: {"nome": "Mirella", "sobrenome": "Novaes", "idade": 50, "email": "camilasantos@example.net", "data_cadastro": "2024-01-30"}
# Recebido: {"nome": "Stella", "sobrenome": "Porto", "idade": 64, "email": "xpeixoto@example.com", "data_cadastro": "2024-02-13"}
# Recebido: {"nome": "Raul", "sobrenome": "Moura", "idade": 43, "email": "zsilveira@example.net", "data_cadastro": "2024-06-12"}
# Recebido: {"nome": "Fernando", "sobrenome": "da Rocha", "idade": 26, "email": "bporto@example.org", "data_cadastro": "2024-03-15"}
# Recebido: {"nome": "Jo\u00e3o Pedro", "sobrenome": "Costa", "idade": 30, "email": "gabriela65@example.net", "data_cadastro": "2024-04-23"}
# Recebido: {"nome": "Lucca", "sobrenome": "Campos", "idade": 31, "email": "portoenzo-gabriel@example.net", "data_cadastro": "2024-07-15"}
# Recebido: {"nome": "Isabella", "sobrenome": "Lima", "idade": 19, "email": "pedromartins@example.org", "data_cadastro": "2024-07-11"}
# Recebido: {"nome": "Helena", "sobrenome": "Duarte", "idade": 58, "email": "uvieira@example.net", "data_cadastro": "2024-03-19"}
# Recebido: {"nome": "Fernando", "sobrenome": "Teixeira", "idade": 26, "email": "davi89@example.org", "data_cadastro": "2024-04-04"}
# Recebido: {"nome": "Diogo", "sobrenome": "Lima", "idade": 20, "email": "leonardo78@example.org", "data_cadastro": "2024-06-14"}
# Recebido: {"nome": "Maysa", "sobrenome": "Souza", "idade": 28, "email": "da-matacaua@example.com", "data_cadastro": "2024-05-08"}
# Recebido: {"nome": "Mariana", "sobrenome": "Lopes", "idade": 44, "email": "almeidalucca@example.com", "data_cadastro": "2024-03-10"}
# Recebido: {"nome": "Lucas Gabriel", "sobrenome": "da Cruz", "idade": 27, "email": "da-luzpedro-lucas@example.org", "data_cadastro": "2024-05-16"}
# Recebido: {"nome": "La\u00eds", "sobrenome": "Sales", "idade": 44, "email": "da-cruzana-sophia@example.net", "data_cadastro": "2024-06-09"}
# Recebido: {"nome": "Jo\u00e3o Pedro", "sobrenome": "Lopes", "idade": 41, "email": "fda-cunha@example.net", "data_cadastro": "2024-03-23"}
# Recebido: {"nome": "Lucas Gabriel", "sobrenome": "Silva", "idade": 30, "email": "joaquimda-cruz@example.net", "data_cadastro": "2024-07-15"}
# Recebido: {"nome": "Raquel", "sobrenome": "Teixeira", "idade": 35, "email": "maria-luiza05@example.org", "data_cadastro": "2024-01-03"}
# Recebido: {"nome": "Enzo Gabriel", "sobrenome": "Rezende", "idade": 41, "email": "cardosorodrigo@example.com", "data_cadastro": "2024-03-30"}
# Recebido: {"nome": "Ant\u00f4nio", "sobrenome": "Ramos", "idade": 68, "email": "rpeixoto@example.com", "data_cadastro": "2024-04-08"}
# Recebido: {"nome": "Eduarda", "sobrenome": "Rodrigues", "idade": 51, "email": "heitor49@example.net", "data_cadastro": "2024-03-25"}
# Recebido: {"nome": "Maria Eduarda", "sobrenome": "Campos", "idade": 60, "email": "valentinaramos@example.net", "data_cadastro": "2024-07-12"}
# Recebido: {"nome": "Guilherme", "sobrenome": "Costela", "idade": 41, "email": "isales@example.org", "data_cadastro": "2024-02-09"}
# Recebido: {"nome": "Sarah", "sobrenome": "Novaes", "idade": 20, "email": "beatrizda-mota@example.com", "data_cadastro": "2024-02-24"}
# ...
# Recebido: {"nome": "Ant\u00f4nio", "sobrenome": "Nunes", "idade": 60, "email": "lopesvitor@example.org", "data_cadastro": "2024-05-13"}
# Recebido: {"nome": "Davi", "sobrenome": "da Luz", "idade": 37, "email": "stellacavalcanti@example.com", "data_cadastro": "2024-02-01"}
# Recebido: {"nome": "L\u00edvia", "sobrenome": "Moraes", "idade": 59, "email": "julianaferreira@example.org", "data_cadastro": "2024-08-07"}
# Recebido: {"nome": "Maria Eduarda", "sobrenome": "Souza", "idade": 19, "email": "osantos@example.com", "data_cadastro": "2024-06-24"}
# Recebido: {"nome": "Maria Julia", "sobrenome": "Teixeira", "idade": 31, "email": "fariasanthony@example.net", "data_cadastro": "2024-06-12"}
# Recebido: {"nome": "Davi", "sobrenome": "Correia", "idade": 47, "email": "carolina97@example.net", "data_cadastro": "2024-06-10"}
# Recebido: {"nome": "Eduarda", "sobrenome": "Castro", "idade": 44, "email": "sarah40@example.com", "data_cadastro": "2024-03-21"}
# Recebido: {"nome": "Valentina", "sobrenome": "da Cunha", "idade": 65, "email": "flopes@example.org", "data_cadastro": "2024-06-23"}
# Recebido: {"nome": "Heitor", "sobrenome": "Caldeira", "idade": 57, "email": "vitoria15@example.com", "data_cadastro": "2024-03-07"}
# Recebido: {"nome": "Maria Alice", "sobrenome": "Souza", "idade": 52, "email": "novaesbenicio@example.org", "data_cadastro": "2024-03-19"}
# Recebido: {"nome": "Carlos Eduardo", "sobrenome": "Peixoto", "idade": 60, "email": "nsouza@example.com", "data_cadastro": "2024-06-27"}
# Recebido: {"nome": "Luigi", "sobrenome": "Ara\u00fajo", "idade": 22, "email": "mendesnicolas@example.com", "data_cadastro": "2024-06-27"}
# Recebido: {"nome": "Leandro", "sobrenome": "Peixoto", "idade": 70, "email": "yagocorreia@example.org", "data_cadastro": "2024-04-01"}
# Recebido: {"nome": "Lucca", "sobrenome": "Novaes", "idade": 66, "email": "leonardomoura@example.com", "data_cadastro": "2024-04-20"}
# Recebido: {"nome": "Sophia", "sobrenome": "Mendes", "idade": 68, "email": "xda-conceicao@example.net", "data_cadastro": "2024-02-25"}
# Recebido: {"nome": "Esther", "sobrenome": "Nascimento", "idade": 45, "email": "ncampos@example.com", "data_cadastro": "2024-05-23"}
# Recebido: {"nome": "Davi Lucas", "sobrenome": "Foga\u00e7a", "idade": 65, "email": "da-costaluigi@example.com", "data_cadastro": "2024-04-17"}
# Recebido: {"nome": "Juan", "sobrenome": "Cunha", "idade": 69, "email": "enzo-gabriel15@example.net", "data_cadastro": "2024-02-04"}
# Recebido: {"nome": "Murilo", "sobrenome": "Pereira", "idade": 62, "email": "vitor-gabriel46@example.com", "data_cadastro": "2024-04-20"}
# Recebido: {"nome": "Luiz Henrique", "sobrenome": "da Mota", "idade": 68, "email": "fernandabarros@example.com", "data_cadastro": "2024-07-17"}
# Recebido: {"nome": "Anthony", "sobrenome": "Lima", "idade": 59, "email": "yuriazevedo@example.org", "data_cadastro": "2024-06-18"}
# Recebido: {"nome": "Sarah", "sobrenome": "da Mota", "idade": 25, "email": "psilveira@example.org", "data_cadastro": "2024-05-20"}
# Recebido: {"nome": "Caio", "sobrenome": "Costela", "idade": 24, "email": "luana76@example.net", "data_cadastro": "2024-03-02"}
# Recebido: {"nome": "Paulo", "sobrenome": "Santos", "idade": 54, "email": "giovanna39@example.com", "data_cadastro": "2024-06-24"}
# Recebido: {"nome": "Vitor Hugo", "sobrenome": "Alves", "idade": 70, "email": "lorena07@example.org", "data_cadastro": "2024-03-03"}
# Recebido: {"nome": "Gustavo Henrique", "sobrenome": "da Rosa", "idade": 21, "email": "limaluiza@example.org", "data_cadastro": "2024-06-13"}
# Recebido: {"nome": "Al\u00edcia", "sobrenome": "Costa", "idade": 24, "email": "da-rosayasmin@example.net", "data_cadastro": "2024-03-30"}
# Recebido: {"nome": "Vit\u00f3ria", "sobrenome": "Vieira", "idade": 30, "email": "das-nevesnathan@example.com", "data_cadastro": "2024-04-15"}
# Recebido: {"nome": "Cec\u00edlia", "sobrenome": "Pinto", "idade": 55, "email": "luccafreitas@example.net", "data_cadastro": "2024-04-06"}
# Recebido: {"nome": "Jo\u00e3o", "sobrenome": "Novaes", "idade": 61, "email": "esther49@example.com", "data_cadastro": "2024-05-04"}
# Recebido: {"nome": "Pedro Henrique", "sobrenome": "Costa", "idade": 44, "email": "tcunha@example.com", "data_cadastro": "2024-06-01"}
# Recebido: {"nome": "Alana", "sobrenome": "Freitas", "idade": 55, "email": "murilosilveira@example.com", "data_cadastro": "2024-01-13"}
# Recebido: {"nome": "Marcos Vinicius", "sobrenome": "Barros", "idade": 53, "email": "gabrielly41@example.net", "data_cadastro": "2024-07-27"}
# Recebido: {"nome": "Alice", "sobrenome": "Rodrigues", "idade": 48, "email": "luiz-henrique27@example.net", "data_cadastro": "2024-06-28"}
# Recebido: {"nome": "Jo\u00e3o Miguel", "sobrenome": "Pires", "idade": 37, "email": "caue71@example.com", "data_cadastro": "2024-03-10"}
# Recebido: {"nome": "Theo", "sobrenome": "Foga\u00e7a", "idade": 60, "email": "thiagobarbosa@example.net", "data_cadastro": "2024-01-09"}
# Recebido: {"nome": "Vitor Hugo", "sobrenome": "da Rosa", "idade": 25, "email": "gribeiro@example.com", "data_cadastro": "2024-02-02"}
# Recebido: {"nome": "Ana Clara", "sobrenome": "Lima", "idade": 40, "email": "mcavalcanti@example.org", "data_cadastro": "2024-01-05"}
# Recebido: {"nome": "Luiza", "sobrenome": "Azevedo", "idade": 33, "email": "costelasophie@example.net", "data_cadastro": "2024-03-28"}
# Recebido: {"nome": "Jo\u00e3o Guilherme", "sobrenome": "Fernandes", "idade": 68, "email": "xda-mota@example.org", "data_cadastro": "2024-04-19"}
# Recebido: {"nome": "Lorena", "sobrenome": "Pires", "idade": 47, "email": "alopes@example.org", "data_cadastro": "2024-01-08"}
# Recebido: {"nome": "J\u00falia", "sobrenome": "da Paz", "idade": 48, "email": "freitasvinicius@example.net", "data_cadastro": "2024-01-16"}
# Recebido: {"nome": "Eloah", "sobrenome": "da Cruz", "idade": 34, "email": "raquelrocha@example.com", "data_cadastro": "2024-05-14"}
# Recebido: {"nome": "Ben\u00edcio", "sobrenome": "Dias", "idade": 30, "email": "martinsbreno@example.org", "data_cadastro": "2024-04-04"}
# Recebido: {"nome": "Marina", "sobrenome": "Pereira", "idade": 53, "email": "sarahda-luz@example.com", "data_cadastro": "2024-06-26"}
# Recebido: {"nome": "Fernando", "sobrenome": "da Concei\u00e7\u00e3o", "idade": 60, "email": "luiz-gustavocunha@example.org", "data_cadastro": "2024-03-10"}
# Recebido: {"nome": "Yasmin", "sobrenome": "Dias", "idade": 21, "email": "portolucca@example.net", "data_cadastro": "2024-04-06"}
# Recebido: {"nome": "La\u00eds", "sobrenome": "Oliveira", "idade": 19, "email": "luiz-otaviocosta@example.org", "data_cadastro": "2024-08-03"}
# Recebido: {"nome": "L\u00edvia", "sobrenome": "Fernandes", "idade": 59, "email": "ryan99@example.com", "data_cadastro": "2024-04-12"}
# Recebido: {"nome": "Pietro", "sobrenome": "Ribeiro", "idade": 38, "email": "mendesthales@example.com", "data_cadastro": "2024-07-26"}
# Recebido: {"nome": "Valentina", "sobrenome": "Carvalho", "idade": 51, "email": "evelyn43@example.org", "data_cadastro": "2024-01-20"}
# Recebido: {"nome": "Milena", "sobrenome": "Alves", "idade": 50, "email": "aragaomilena@example.com", "data_cadastro": "2024-01-31"}
# Recebido: {"nome": "Mirella", "sobrenome": "Martins", "idade": 43, "email": "helenaazevedo@example.net", "data_cadastro": "2024-01-07"}
# Recebido: {"nome": "Vitor", "sobrenome": "Pinto", "idade": 40, "email": "otavio42@example.org", "data_cadastro": "2024-02-21"}
# Recebido: {"nome": "Maria Julia", "sobrenome": "Rocha", "idade": 64, "email": "marcela90@example.com", "data_cadastro": "2024-03-23"}
# Recebido: {"nome": "Guilherme", "sobrenome": "Vieira", "idade": 68, "email": "joana19@example.com", "data_cadastro": "2024-06-09"}
# Recebido: {"nome": "Nina", "sobrenome": "Teixeira", "idade": 48, "email": "bianca36@example.org", "data_cadastro": "2024-03-03"}
# Recebido: {"nome": "Sophie", "sobrenome": "Barbosa", "idade": 18, "email": "tda-mata@example.org", "data_cadastro": "2024-05-08"}
# Recebido: {"nome": "Esther", "sobrenome": "Nunes", "idade": 50, "email": "martinsenrico@example.net", "data_cadastro": "2024-06-07"}
# Recebido: {"nome": "Ana Carolina", "sobrenome": "Costela", "idade": 53, "email": "ldas-neves@example.net", "data_cadastro": "2024-01-09"}
# Recebido: {"nome": "Lara", "sobrenome": "Silveira", "idade": 34, "email": "manuelamelo@example.org", "data_cadastro": "2024-04-04"}
# Recebido: {"nome": "Emanuel", "sobrenome": "Foga\u00e7a", "idade": 46, "email": "enzoribeiro@example.org", "data_cadastro": "2024-03-18"}
# Recebido: {"nome": "Enzo Gabriel", "sobrenome": "Teixeira", "idade": 48, "email": "pedro-henrique40@example.net", "data_cadastro": "2024-01-08"}
# Recebido: {"nome": "Miguel", "sobrenome": "Ramos", "idade": 39, "email": "da-motacalebe@example.org", "data_cadastro": "2024-07-07"}
# Recebido: {"nome": "Ana Sophia", "sobrenome": "Alves", "idade": 40, "email": "ana-lauranunes@example.org", "data_cadastro": "2024-05-15"}
# Recebido: {"nome": "Levi", "sobrenome": "Foga\u00e7a", "idade": 25, "email": "luccada-cruz@example.net", "data_cadastro": "2024-06-08"}
# Recebido: {"nome": "Luiz Felipe", "sobrenome": "Costa", "idade": 48, "email": "marcela61@example.com", "data_cadastro": "2024-02-19"}
# Recebido: {"nome": "Clarice", "sobrenome": "da Cunha", "idade": 62, "email": "stellacostela@example.org", "data_cadastro": "2024-05-12"}
# Recebido: {"nome": "Samuel", "sobrenome": "Lima", "idade": 50, "email": "ana-carolinada-paz@example.com", "data_cadastro": "2024-06-15"}
# Recebido: {"nome": "Isadora", "sobrenome": "da Cruz", "idade": 62, "email": "agatha61@example.org", "data_cadastro": "2024-02-03"}
# Recebido: {"nome": "Maria Luiza", "sobrenome": "Silveira", "idade": 50, "email": "gabriela31@example.net", "data_cadastro": "2024-02-11"}
# Recebido: {"nome": "Gustavo Henrique", "sobrenome": "Gon\u00e7alves", "idade": 53, "email": "ccaldeira@example.com", "data_cadastro": "2024-04-20"}
# Recebido: {"nome": "Rafael", "sobrenome": "Ramos", "idade": 51, "email": "melosarah@example.org", "data_cadastro": "2024-01-13"}
# Recebido: {"nome": "Jo\u00e3o", "sobrenome": "Cardoso", "idade": 51, "email": "isabella37@example.com", "data_cadastro": "2024-06-20"}
# Recebido: {"nome": "Caio", "sobrenome": "Alves", "idade": 34, "email": "barrosian@example.net", "data_cadastro": "2024-03-11"}
# Recebido: {"nome": "Julia", "sobrenome": "Silva", "idade": 19, "email": "pmonteiro@example.org", "data_cadastro": "2024-01-24"}
# Recebido: {"nome": "Emanuella", "sobrenome": "Pinto", "idade": 19, "email": "vitoria05@example.net", "data_cadastro": "2024-08-04"}
# Recebido: {"nome": "Ana Carolina", "sobrenome": "Ramos", "idade": 52, "email": "jcunha@example.com", "data_cadastro": "2024-07-13"}
# Recebido: {"nome": "Beatriz", "sobrenome": "Almeida", "idade": 22, "email": "augusto37@example.org", "data_cadastro": "2024-06-07"}
# Recebido: {"nome": "Ana Julia", "sobrenome": "Lima", "idade": 50, "email": "davi-lucas24@example.com", "data_cadastro": "2024-05-20"}
# Recebido: {"nome": "Jo\u00e3o Guilherme", "sobrenome": "Jesus", "idade": 49, "email": "isadoracardoso@example.net", "data_cadastro": "2024-07-13"}
# Recebido: {"nome": "Erick", "sobrenome": "Martins", "idade": 68, "email": "yasminpinto@example.org", "data_cadastro": "2024-02-17"}
# Recebido: {"nome": "Luiz Felipe", "sobrenome": "da Rocha", "idade": 53, "email": "luccada-paz@example.com", "data_cadastro": "2024-07-06"}
# Recebido: {"nome": "Sophie", "sobrenome": "da Cunha", "idade": 26, "email": "ryanribeiro@example.com", "data_cadastro": "2024-05-06"}
# Recebido: {"nome": "Gabriel", "sobrenome": "Fernandes", "idade": 55, "email": "fernanda84@example.net", "data_cadastro": "2024-04-18"}
# Recebido: {"nome": "Esther", "sobrenome": "Sales", "idade": 23, "email": "da-luzmarcela@example.net", "data_cadastro": "2024-04-12"}
# Recebido: {"nome": "Theo", "sobrenome": "Pires", "idade": 30, "email": "kda-conceicao@example.org", "data_cadastro": "2024-02-21"}
# Recebido: {"nome": "Jo\u00e3o Vitor", "sobrenome": "Ara\u00fajo", "idade": 44, "email": "ucosta@example.net", "data_cadastro": "2024-07-06"}
# Recebido: {"nome": "Gabrielly", "sobrenome": "Azevedo", "idade": 25, "email": "maria-vitoria51@example.com", "data_cadastro": "2024-02-26"}
# Recebido: {"nome": "Pedro Lucas", "sobrenome": "Alves", "idade": 34, "email": "sofiaviana@example.com", "data_cadastro": "2024-02-12"}
# Recebido: {"nome": "Brenda", "sobrenome": "Cardoso", "idade": 47, "email": "salescarlos-eduardo@example.org", "data_cadastro": "2024-06-16"}
# Recebido: {"nome": "Erick", "sobrenome": "Farias", "idade": 24, "email": "maria-fernanda79@example.org", "data_cadastro": "2024-06-11"}
# Recebido: {"nome": "Lara", "sobrenome": "da Mata", "idade": 36, "email": "icavalcanti@example.net", "data_cadastro": "2024-04-22"}
# Recebido: {"nome": "Theo", "sobrenome": "Martins", "idade": 66, "email": "dcampos@example.org", "data_cadastro": "2024-07-17"}
# Recebido: {"nome": "Maria", "sobrenome": "Arag\u00e3o", "idade": 63, "email": "diegosouza@example.com", "data_cadastro": "2024-03-27"}
# Recebido: {"nome": "Sofia", "sobrenome": "Moraes", "idade": 19, "email": "oalmeida@example.net", "data_cadastro": "2024-07-24"}
# Recebido: {"nome": "Catarina", "sobrenome": "Campos", "idade": 25, "email": "daniloda-mota@example.net", "data_cadastro": "2024-04-02"}
# Recebido: {"nome": "Juliana", "sobrenome": "Costa", "idade": 22, "email": "ana-sophiaoliveira@example.net", "data_cadastro": "2024-02-20"}
# Recebido: {"nome": "Stephany", "sobrenome": "Cunha", "idade": 24, "email": "luigi77@example.org", "data_cadastro": "2024-03-04"}
# Recebido: {"nome": "Diego", "sobrenome": "Carvalho", "idade": 35, "email": "juliagomes@example.org", "data_cadastro": "2024-04-12"}
# Recebido: {"nome": "Emanuella", "sobrenome": "Porto", "idade": 56, "email": "isabelnascimento@example.net", "data_cadastro": "2024-02-11"}
# Recebido: {"nome": "Ot\u00e1vio", "sobrenome": "Peixoto", "idade": 69, "email": "teixeiraagatha@example.net", "data_cadastro": "2024-01-30"}
# Recebido: {"nome": "Alice", "sobrenome": "Barros", "idade": 41, "email": "lrodrigues@example.net", "data_cadastro": "2024-06-03"}
# Recebido: {"nome": "Nicole", "sobrenome": "Barros", "idade": 37, "email": "gsales@example.org", "data_cadastro": "2024-04-18"}
# Recebido: {"nome": "Clarice", "sobrenome": "Nunes", "idade": 37, "email": "ccavalcanti@example.com", "data_cadastro": "2024-06-17"}
# Recebido: {"nome": "Renan", "sobrenome": "Ramos", "idade": 38, "email": "da-cunhaclarice@example.org", "data_cadastro": "2024-06-10"}
# Recebido: {"nome": "Emanuella", "sobrenome": "da Mota", "idade": 53, "email": "gcardoso@example.com", "data_cadastro": "2024-06-26"}
# Recebido: {"nome": "La\u00eds", "sobrenome": "Carvalho", "idade": 59, "email": "raquel93@example.net", "data_cadastro": "2024-06-16"}
# Recebido: {"nome": "Fernanda", "sobrenome": "Pereira", "idade": 20, "email": "aferreira@example.com", "data_cadastro": "2024-07-08"}
# Recebido: {"nome": "Kevin", "sobrenome": "Oliveira", "idade": 68, "email": "monteiroraquel@example.net", "data_cadastro": "2024-04-30"}
# Recebido: {"nome": "Diego", "sobrenome": "da Rocha", "idade": 67, "email": "qcarvalho@example.net", "data_cadastro": "2024-06-26"}
# Recebido: {"nome": "Lucas", "sobrenome": "Martins", "idade": 55, "email": "luiza31@example.org", "data_cadastro": "2024-08-09"}
# Recebido: {"nome": "L\u00edvia", "sobrenome": "Rezende", "idade": 65, "email": "qdias@example.org", "data_cadastro": "2024-03-17"}
# Recebido: {"nome": "Lucas Gabriel", "sobrenome": "Teixeira", "idade": 22, "email": "almeidaemanuelly@example.net", "data_cadastro": "2024-04-19"}
# Recebido: {"nome": "Kevin", "sobrenome": "Moura", "idade": 33, "email": "yuri94@example.org", "data_cadastro": "2024-07-07"}
# Recebido: {"nome": "Julia", "sobrenome": "Gomes", "idade": 52, "email": "caiofreitas@example.com", "data_cadastro": "2024-06-21"}
# Recebido: {"nome": "Raquel", "sobrenome": "Ribeiro", "idade": 26, "email": "freitasryan@example.net", "data_cadastro": "2024-03-19"}
# JSON KAFKA/topic=teste/year=2024/month=8/day=10/2024-08-10 20:40:02.json enviado para o bucket bronze com sucesso!

# %%
from datetime import datetime

# %%
from kafka import KafkaConsumer, TopicPartition

# Criar o consumidor sem especificar o tópico
consumer = KafkaConsumer(
    bootstrap_servers=[BOOTSTRAP],  # Servidor Kafka
    enable_auto_commit=True,  # Para commit automático das mensagens
    consumer_timeout_ms=10000, 
    value_deserializer=lambda x: x.decode('utf-8')  # Deserializa as mensagens para string
)

# Especificar a partição e o offset inicial
partition = 0  # Partição que deseja consumir
offset_inicial = 1567  # Offset a partir do qual deseja começar a ler

# Atribuir a partição ao consumidor
tp = TopicPartition(TOPIC, partition)
consumer.assign([tp])

# Definir o offset inicial manualmente
consumer.seek(tp, offset_inicial)

# Consumir as mensagens a partir do offset específico
for message in consumer:
    print(f"Offset: {message.offset}, Key: {message.key}, Value: {message.value}")
# Out:
# Offset: 1567, Key: None, Value: {"nome": "Enzo Gabriel", "sobrenome": "Lima", "idade": 43, "email": "pietra91@example.net", "data_cadastro": "2024-06-13"}
# Offset: 1568, Key: None, Value: {"nome": "Theo", "sobrenome": "Gon\u00e7alves", "idade": 55, "email": "rafaelbarros@example.net", "data_cadastro": "2024-04-14"}
# Offset: 1569, Key: None, Value: {"nome": "Bryan", "sobrenome": "Rodrigues", "idade": 47, "email": "valentinaviana@example.net", "data_cadastro": "2024-03-05"}

# %%
# !pip install clickhouse_driver
# Out:
# Collecting clickhouse_driver
#   Downloading clickhouse_driver-0.2.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.11/site-packages (from clickhouse_driver) (2023.3.post1)
# Collecting tzlocal (from clickhouse_driver)
#   Downloading tzlocal-5.2-py3-none-any.whl.metadata (7.8 kB)
# Downloading clickhouse_driver-0.2.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 1.6 MB/s eta 0:00:0000:0100:01
# Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Installing collected packages: tzlocal, clickhouse_driver
# Successfully installed clickhouse_driver-0.2.8 tzlocal-5.2

# %%
from clickhouse_driver import Client

# Conexão ao servidor ClickHouse
client = Client(
    host='clickhouse',       # Endereço do servidor ClickHouse
    port=9000,              # Porta padrão para conexões TCP
    user='default',         # Usuário (padrão é 'default')
    password='',            # Senha (por padrão, vazio)
    database='default',     # Nome do banco de dados (por padrão, 'default')
)

# %%
# Out:
# []

# %%
client.execute("""INSERT INTO kafka_topics_offset_control (id, kafka_topic, last_offset, exec_date) VALUES 
(1, 'topic1', 12345, '2024-08-10'),
(2, 'topic2', 67890, '2024-08-10'),
(3, 'topic1', 12350, '2024-08-11'),
(4, 'topic3', 54321, '2024-08-11'),
(5, 'topic2', 67895, '2024-08-12');""")
# Out:
# []

# %%
client.execute(f"SELECT * FROM  kafka_topics_offset_control")
# Out:
# [(1, 'topic1', 12345, datetime.date(2024, 8, 10)),
#  (2, 'topic2', 67890, datetime.date(2024, 8, 10)),
#  (3, 'topic1', 12350, datetime.date(2024, 8, 11)),
#  (4, 'topic3', 54321, datetime.date(2024, 8, 11)),
#  (5, 'topic2', 67895, datetime.date(2024, 8, 12))]

# %%
0
# Executando uma consulta

result = client.execute('SELECT * FROM minha_tabela LIMIT 10')
for row in result:
    print(row)
# Out:
# (1, 'leo', 24, datetime.date(1970, 1, 1))
