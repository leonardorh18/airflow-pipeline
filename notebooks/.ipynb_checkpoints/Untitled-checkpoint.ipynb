# %%
# !pip install kafka-python
# Out:
# Requirement already satisfied: kafka-python in /opt/conda/lib/python3.11/site-packages (2.0.2)

# %%
# !pip3 install minio
# Out:
# Requirement already satisfied: minio in /opt/conda/lib/python3.11/site-packages (7.2.7)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from minio) (2023.7.22)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.11/site-packages (from minio) (2.0.7)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.11/site-packages (from minio) (23.1.0)
# Requirement already satisfied: pycryptodome in /opt/conda/lib/python3.11/site-packages (from minio) (3.20.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.11/site-packages (from minio) (4.8.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.11/site-packages (from argon2-cffi->minio) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi->minio) (1.16.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->minio) (2.21)

# %%
from minio import Minio

# %%
client = Minio("minio:9000",
    access_key="DImuDiaEs6bIJJBgCjXW",
    secret_key="HPCTwG5dobqO83MAoCz4hmpPMaJblP9RvondmMHJ",
    secure = False
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 client = Minio("minio:9000",
#       2     access_key="DImuDiaEs6bIJJBgCjXW",
#       3     secret_key="HPCTwG5dobqO83MAoCz4hmpPMaJblP9RvondmMHJ",
#       4     secure = False
#       5 )
#
# NameError: name 'Minio' is not defined

# %%
client.make_bucket("bronze")

# %%
import json
from minio import Minio
from minio.error import S3Error
from io import BytesIO
from datetime import datetime
from kafka import KafkaConsumer, TopicPartition
from clickhouse_driver import Client
from minio import Minio
from minio.error import S3Error
import json
from io import BytesIO
import os

from kafka import KafkaConsumer

# Nome do bucket e do objeto
bucket_name = "bronze"
object_name = "dados/clientes.json"  # Caminho e nome do arquivo no bucket

# Dados a serem gravados
dados = {
    "clientes": [
        {"nome": "João", "sobrenome": "Silva", "idade": 34, "email": "joao.silva@email.com", "data_cadastro": "2024-08-09"},
        {"nome": "Maria", "sobrenome": "Oliveira", "idade": 29, "email": "maria.oliveira@email.com", "data_cadastro": "2024-08-09"}
    ]
}

# Converter o dicionário Python em uma string JSON
json_data = json.dumps(dados)

# Converter a string JSON em bytes para poder enviar ao MinIO
json_bytes = BytesIO(json_data.encode('utf-8'))

# Fazendo upload do JSON para o MinIO
try:
    client.put_object(
        bucket_name,
        object_name,
        data=json_bytes,
        length=len(json_data),
        content_type="application/json"
    )
    print(f'JSON {object_name} enviado para o bucket {bucket_name} com sucesso!')
except S3Error as e:
    print(f'Erro ao enviar arquivo: {e}')
# Out:
# JSON dados/clientes.json enviado para o bucket bronze com sucesso!

# %%
from kafka import KafkaConsumer, TopicPartition
TOPIC = 'clients_kafka'
BOOTSTRAP = 'kafka:9092'
ACCESS_KEY = "minioadmin"
SECRET_KEY = "minioadmin"
from clickhouse_driver import Client
import json
from minio import Minio
from minio.error import S3Error
from io import BytesIO
from datetime import datetime
from kafka import KafkaConsumer, TopicPartition
from clickhouse_driver import Client
from minio import Minio
from minio.error import S3Error
import json
from io import BytesIO
import os
from minio import Minio
from datetime import datetime
from io import BytesIO
BUCKET_NAME = 'bronze-layer'
import json
class TopicOffsetControll():
    def __init__(self, topic):
        self.topic = topic
        self.client = Client(
                host='clickhouse',       # Endereço do servidor ClickHouse
                port=9000,              # Porta padrão para conexões TCP
                user='default',         # Usuário (padrão é 'default')
                password='',            # Senha (por padrão, vazio)
                database='default',     # Nome do banco de dados (por padrão, 'default')
        )
        
    def get_offset(self):
        self.client.execute("""CREATE TABLE IF NOT EXISTS kafka_topics_offset_control (
                kafka_topic String,
                last_offset Int64,
                exec_date DEFAULT now() 
                ) ENGINE = MergeTree()
                ORDER BY exec_date """)
        offset = self.client.execute(f"SELECT max(last_offset) FROM kafka_topics_offset_control WHERE kafka_topic = '{self.topic}'")[0][0]
        return offset

    def insert_offset(self, offset):
        print(f"OFFSET {offset} ")
        self.client.execute(f"""
        INSERT INTO kafka_topics_offset_control (kafka_topic, last_offset) 
        VALUES ('{self.topic}',  {offset})
        """)
    
def insert_bronze(data):
    client = Minio("minio:9000",
        access_key=ACCESS_KEY,
        secret_key=SECRET_KEY,
        secure = False
    )
    found = client.bucket_exists(BUCKET_NAME)
    if not found:
        client.make_bucket(BUCKET_NAME)
        print("Created bucket", BUCKET_NAME)
    json_data = json.dumps(data)
    json_bytes = BytesIO(json_data.encode('utf-8'))
    now = datetime.now()
    object_name = f'KAFKA/topic={TOPIC}/year={now.year}/month={now.month}/day={now.day}/{now.strftime("%Y-%m-%d %H:%M:%S")}.json'
    try:
        client.put_object(
            BUCKET_NAME,
            object_name,
            data=json_bytes,
            length=len(json_data),
            content_type="application/json"
        )
        print(f'JSON {object_name} enviado para o bucket {BUCKET_NAME} com sucesso!')
    except S3Error as e:
        print(f'Erro ao enviar arquivo: {e}')    
# Configuração do consumidor Kafka
try:
    consumer = KafkaConsumer(
        bootstrap_servers=[BOOTSTRAP],  # Servidor Kafka
        enable_auto_commit=True,  # Para commit automático das mensagens
        consumer_timeout_ms=10000,  #fica aguardando topicos por 10 segundos
        value_deserializer=lambda x: x.decode('utf-8')  # Deserializa as mensagens para string
    )
    # Especificar a partição e o offset inicial
    topic_controll = TopicOffsetControll(TOPIC)
    partition = 0  # Partição que deseja consumir
    offset_inicial = topic_controll.get_offset()  # Offset a partir do qual deseja começar a ler
    
    # Atribuir a partição ao consumidor
    tp = TopicPartition(TOPIC, partition)
    consumer.assign([tp])
    
    # Definir o offset inicial manualmente
    consumer.seek(tp, offset_inicial)
    
    print("Aguardando mensagens...")
    last_message = None
    # Consome mensagens do tópico
    message_list = []
    for message in consumer:
        last_message = message
        print(f"Recebido: {json.loads(message.value)}")
        message_list.append(json.loads(message.value))
        
    insert_bronze(message.value)
    topic_controll.insert_offset(message.offset)
    
except Exception as e:
    print(e)
    raise Exception(e)
    #create_log(status = 'failure', message = e)
# Out:
# Aguardando mensagens...
# Recebido: {'nome': 'Camila', 'sobrenome': 'Rezende', 'idade': 53, 'email': 'ana-sophiacorreia@example.net', 'data_cadastro': '2024-02-24'}
# Recebido: {'nome': 'Alice', 'sobrenome': 'Nunes', 'idade': 43, 'email': 'matheusmartins@example.com', 'data_cadastro': '2024-05-08'}
# Recebido: {'nome': 'Emilly', 'sobrenome': 'da Rosa', 'idade': 33, 'email': 'lorenzo62@example.net', 'data_cadastro': '2024-01-05'}
# Recebido: {'nome': 'Pedro Henrique', 'sobrenome': 'Souza', 'idade': 67, 'email': 'nogueiradanilo@example.net', 'data_cadastro': '2024-02-02'}
# Recebido: {'nome': 'Kevin', 'sobrenome': 'Novaes', 'idade': 60, 'email': 'ada-conceicao@example.org', 'data_cadastro': '2024-04-22'}
# Recebido: {'nome': 'Letícia', 'sobrenome': 'Caldeira', 'idade': 51, 'email': 'cardosoalexandre@example.org', 'data_cadastro': '2024-01-28'}
# Recebido: {'nome': 'Heitor', 'sobrenome': 'Jesus', 'idade': 53, 'email': 'rafaelda-rocha@example.net', 'data_cadastro': '2024-04-26'}
# Recebido: {'nome': 'Emanuel', 'sobrenome': 'Lima', 'idade': 41, 'email': 'araujolara@example.org', 'data_cadastro': '2024-03-05'}
# Recebido: {'nome': 'Manuela', 'sobrenome': 'Fogaça', 'idade': 26, 'email': 'anthonyfogaca@example.com', 'data_cadastro': '2024-03-13'}
# Recebido: {'nome': 'Clarice', 'sobrenome': 'Freitas', 'idade': 43, 'email': 'luiz-henriquebarbosa@example.com', 'data_cadastro': '2024-01-07'}
# Recebido: {'nome': 'Alícia', 'sobrenome': 'Pereira', 'idade': 36, 'email': 'kamilly42@example.org', 'data_cadastro': '2024-02-10'}
# Recebido: {'nome': 'Laís', 'sobrenome': 'Castro', 'idade': 27, 'email': 'wsales@example.com', 'data_cadastro': '2024-04-15'}
# Recebido: {'nome': 'Carlos Eduardo', 'sobrenome': 'da Costa', 'idade': 52, 'email': 'moreiramarcelo@example.com', 'data_cadastro': '2024-07-15'}
# Recebido: {'nome': 'Lucas', 'sobrenome': 'da Conceição', 'idade': 36, 'email': 'danilo39@example.com', 'data_cadastro': '2024-05-04'}
# Recebido: {'nome': 'Diego', 'sobrenome': 'Azevedo', 'idade': 67, 'email': 'gjesus@example.com', 'data_cadastro': '2024-05-11'}
# Recebido: {'nome': 'Davi Lucca', 'sobrenome': 'Cardoso', 'idade': 56, 'email': 'helenacardoso@example.org', 'data_cadastro': '2024-04-07'}
# Recebido: {'nome': 'Júlia', 'sobrenome': 'Dias', 'idade': 40, 'email': 'joao-felipecorreia@example.org', 'data_cadastro': '2024-05-31'}
# Recebido: {'nome': 'Brenda', 'sobrenome': 'Gonçalves', 'idade': 57, 'email': 'pereiraeloah@example.net', 'data_cadastro': '2024-03-15'}
# Recebido: {'nome': 'Pedro Lucas', 'sobrenome': 'Rezende', 'idade': 30, 'email': 'cdias@example.net', 'data_cadastro': '2024-05-07'}
# Recebido: {'nome': 'Emilly', 'sobrenome': 'Moreira', 'idade': 25, 'email': 'das-nevesmariane@example.com', 'data_cadastro': '2024-03-29'}
# Recebido: {'nome': 'Carlos Eduardo', 'sobrenome': 'Nunes', 'idade': 67, 'email': 'matheuscavalcanti@example.com', 'data_cadastro': '2024-04-05'}
# Recebido: {'nome': 'Luna', 'sobrenome': 'Duarte', 'idade': 67, 'email': 'joao-miguelrodrigues@example.com', 'data_cadastro': '2024-06-29'}
# Recebido: {'nome': 'Mirella', 'sobrenome': 'Jesus', 'idade': 62, 'email': 'monteirosophia@example.net', 'data_cadastro': '2024-07-31'}
# Recebido: {'nome': 'Isabel', 'sobrenome': 'da Cunha', 'idade': 20, 'email': 'beatriz21@example.org', 'data_cadastro': '2024-07-09'}
# Recebido: {'nome': 'Maria Fernanda', 'sobrenome': 'Aragão', 'idade': 64, 'email': 'araujomilena@example.com', 'data_cadastro': '2024-08-05'}
# Recebido: {'nome': 'João Gabriel', 'sobrenome': 'Ferreira', 'idade': 42, 'email': 'mda-paz@example.net', 'data_cadastro': '2024-03-01'}
# Recebido: {'nome': 'Raul', 'sobrenome': 'Sales', 'idade': 43, 'email': 'bbarbosa@example.net', 'data_cadastro': '2024-04-27'}
# Recebido: {'nome': 'Laís', 'sobrenome': 'Campos', 'idade': 31, 'email': 'leandroda-paz@example.org', 'data_cadastro': '2024-05-13'}
# Recebido: {'nome': 'Luna', 'sobrenome': 'Ribeiro', 'idade': 26, 'email': 'ana-laura91@example.org', 'data_cadastro': '2024-04-24'}
# Recebido: {'nome': 'Sophia', 'sobrenome': 'Jesus', 'idade': 36, 'email': 'stephanycosta@example.com', 'data_cadastro': '2024-02-08'}
# Recebido: {'nome': 'Raul', 'sobrenome': 'Costa', 'idade': 39, 'email': 'araujobenjamin@example.net', 'data_cadastro': '2024-05-23'}
# Recebido: {'nome': 'Ian', 'sobrenome': 'Ribeiro', 'idade': 55, 'email': 'gabriellyduarte@example.com', 'data_cadastro': '2024-07-26'}
# Recebido: {'nome': 'Alexandre', 'sobrenome': 'Mendes', 'idade': 19, 'email': 'bramos@example.net', 'data_cadastro': '2024-04-29'}
# Recebido: {'nome': 'Julia', 'sobrenome': 'Pires', 'idade': 43, 'email': 'eloahda-cruz@example.com', 'data_cadastro': '2024-07-16'}
# Recebido: {'nome': 'Bruna', 'sobrenome': 'Alves', 'idade': 66, 'email': 'lucas49@example.org', 'data_cadastro': '2024-03-23'}
# Recebido: {'nome': 'Sophia', 'sobrenome': 'das Neves', 'idade': 62, 'email': 'miguelteixeira@example.org', 'data_cadastro': '2024-02-16'}
# Recebido: {'nome': 'Pedro Henrique', 'sobrenome': 'Dias', 'idade': 22, 'email': 'joao-miguel83@example.net', 'data_cadastro': '2024-05-11'}
# Recebido: {'nome': 'Lavínia', 'sobrenome': 'da Paz', 'idade': 52, 'email': 'jlopes@example.com', 'data_cadastro': '2024-02-15'}
# Recebido: {'nome': 'Cauê', 'sobrenome': 'Ribeiro', 'idade': 46, 'email': 'thalescorreia@example.org', 'data_cadastro': '2024-06-01'}
# Recebido: {'nome': 'Pedro Lucas', 'sobrenome': 'Cunha', 'idade': 40, 'email': 'vinicius65@example.net', 'data_cadastro': '2024-03-20'}
# Recebido: {'nome': 'Bryan', 'sobrenome': 'Porto', 'idade': 69, 'email': 'kcampos@example.org', 'data_cadastro': '2024-07-13'}
# Recebido: {'nome': 'Isabelly', 'sobrenome': 'Cardoso', 'idade': 42, 'email': 'oliveirapaulo@example.org', 'data_cadastro': '2024-06-22'}
# Recebido: {'nome': 'Heitor', 'sobrenome': 'Ramos', 'idade': 22, 'email': 'da-motadaniela@example.org', 'data_cadastro': '2024-06-08'}
# Recebido: {'nome': 'Isis', 'sobrenome': 'Castro', 'idade': 24, 'email': 'fernanda69@example.org', 'data_cadastro': '2024-05-25'}
# Recebido: {'nome': 'Melissa', 'sobrenome': 'Nunes', 'idade': 49, 'email': 'lferreira@example.com', 'data_cadastro': '2024-05-14'}
# Recebido: {'nome': 'Eloah', 'sobrenome': 'Duarte', 'idade': 37, 'email': 'da-matarenan@example.net', 'data_cadastro': '2024-02-25'}
# Recebido: {'nome': 'Laís', 'sobrenome': 'Cardoso', 'idade': 23, 'email': 'joao-lucas39@example.net', 'data_cadastro': '2024-07-05'}
# Recebido: {'nome': 'Luiz Gustavo', 'sobrenome': 'Cardoso', 'idade': 24, 'email': 'lorenzo93@example.org', 'data_cadastro': '2024-01-16'}
# Recebido: {'nome': 'João', 'sobrenome': 'Ribeiro', 'idade': 23, 'email': 'luccadias@example.com', 'data_cadastro': '2024-04-13'}
# Recebido: {'nome': 'Marcos Vinicius', 'sobrenome': 'Farias', 'idade': 47, 'email': 'danilojesus@example.com', 'data_cadastro': '2024-02-09'}
# Recebido: {'nome': 'Clarice', 'sobrenome': 'Lopes', 'idade': 70, 'email': 'jda-paz@example.org', 'data_cadastro': '2024-03-07'}
# Recebido: {'nome': 'Caroline', 'sobrenome': 'Rocha', 'idade': 30, 'email': 'rodriguesfelipe@example.org', 'data_cadastro': '2024-01-09'}
# Recebido: {'nome': 'Pedro Miguel', 'sobrenome': 'Araújo', 'idade': 36, 'email': 'maria-clara33@example.org', 'data_cadastro': '2024-05-28'}
# Recebido: {'nome': 'Yago', 'sobrenome': 'Pinto', 'idade': 27, 'email': 'samuelribeiro@example.com', 'data_cadastro': '2024-02-23'}
# Recebido: {'nome': 'Thiago', 'sobrenome': 'Caldeira', 'idade': 38, 'email': 'apinto@example.com', 'data_cadastro': '2024-04-26'}
# Recebido: {'nome': 'Joana', 'sobrenome': 'da Mata', 'idade': 47, 'email': 'cardosovitor-gabriel@example.org', 'data_cadastro': '2024-07-25'}
# Recebido: {'nome': 'Emanuelly', 'sobrenome': 'da Costa', 'idade': 60, 'email': 'bda-costa@example.net', 'data_cadastro': '2024-04-27'}
# Recebido: {'nome': 'Pietro', 'sobrenome': 'Rezende', 'idade': 41, 'email': 'rdias@example.net', 'data_cadastro': '2024-05-05'}
# Recebido: {'nome': 'Diogo', 'sobrenome': 'das Neves', 'idade': 51, 'email': 'antonio26@example.com', 'data_cadastro': '2024-07-21'}
# Recebido: {'nome': 'Letícia', 'sobrenome': 'Souza', 'idade': 69, 'email': 'vitorpeixoto@example.net', 'data_cadastro': '2024-01-17'}
# Recebido: {'nome': 'Maria Julia', 'sobrenome': 'Moraes', 'idade': 57, 'email': 'levi03@example.org', 'data_cadastro': '2024-07-04'}
# Recebido: {'nome': 'Leandro', 'sobrenome': 'Sales', 'idade': 34, 'email': 'monteirojoana@example.com', 'data_cadastro': '2024-07-31'}
# Recebido: {'nome': 'Francisco', 'sobrenome': 'da Rosa', 'idade': 42, 'email': 'livia99@example.net', 'data_cadastro': '2024-03-21'}
# Recebido: {'nome': 'Igor', 'sobrenome': 'da Conceição', 'idade': 68, 'email': 'rodrigomelo@example.net', 'data_cadastro': '2024-03-31'}
# Recebido: {'nome': 'Cauã', 'sobrenome': 'Rodrigues', 'idade': 23, 'email': 'mribeiro@example.net', 'data_cadastro': '2024-02-25'}
# Recebido: {'nome': 'Stella', 'sobrenome': 'Mendes', 'idade': 38, 'email': 'alicia04@example.org', 'data_cadastro': '2024-08-03'}
# Recebido: {'nome': 'Rafael', 'sobrenome': 'da Cunha', 'idade': 21, 'email': 'laraalves@example.net', 'data_cadastro': '2024-02-11'}
# Recebido: {'nome': 'Heloísa', 'sobrenome': 'Peixoto', 'idade': 28, 'email': 'ada-costa@example.net', 'data_cadastro': '2024-07-15'}
# Recebido: {'nome': 'Ian', 'sobrenome': 'da Rosa', 'idade': 37, 'email': 'da-conceicaosofia@example.org', 'data_cadastro': '2024-07-10'}
# Recebido: {'nome': 'Raquel', 'sobrenome': 'Rezende', 'idade': 55, 'email': 'pereirasarah@example.net', 'data_cadastro': '2024-02-04'}
# Recebido: {'nome': 'Alexandre', 'sobrenome': 'da Conceição', 'idade': 52, 'email': 'larissacorreia@example.net', 'data_cadastro': '2024-05-23'}
# Recebido: {'nome': 'Kamilly', 'sobrenome': 'Correia', 'idade': 58, 'email': 'emanuellymelo@example.com', 'data_cadastro': '2024-03-09'}
# Recebido: {'nome': 'Ana Laura', 'sobrenome': 'Pereira', 'idade': 55, 'email': 'flopes@example.com', 'data_cadastro': '2024-05-16'}
# Recebido: {'nome': 'Theo', 'sobrenome': 'Campos', 'idade': 27, 'email': 'vicente66@example.com', 'data_cadastro': '2024-03-20'}
# Recebido: {'nome': 'Stella', 'sobrenome': 'Nogueira', 'idade': 53, 'email': 'sofia63@example.org', 'data_cadastro': '2024-02-19'}
# Recebido: {'nome': 'João Felipe', 'sobrenome': 'Araújo', 'idade': 66, 'email': 'joaonovaes@example.org', 'data_cadastro': '2024-04-09'}
# Recebido: {'nome': 'Olivia', 'sobrenome': 'da Costa', 'idade': 66, 'email': 'ana-beatrizribeiro@example.net', 'data_cadastro': '2024-04-27'}
# Recebido: {'nome': 'Gustavo', 'sobrenome': 'Moreira', 'idade': 50, 'email': 'noahlima@example.net', 'data_cadastro': '2024-01-31'}
# Recebido: {'nome': 'Francisco', 'sobrenome': 'Moreira', 'idade': 51, 'email': 'tcosta@example.com', 'data_cadastro': '2024-06-12'}
# Recebido: {'nome': 'Ana Beatriz', 'sobrenome': 'Azevedo', 'idade': 21, 'email': 'luccacampos@example.net', 'data_cadastro': '2024-06-13'}
# Recebido: {'nome': 'Otávio', 'sobrenome': 'Pinto', 'idade': 42, 'email': 'pcardoso@example.com', 'data_cadastro': '2024-04-21'}
# Recebido: {'nome': 'Luiza', 'sobrenome': 'Moreira', 'idade': 39, 'email': 'vitor-gabriel38@example.net', 'data_cadastro': '2024-04-25'}
# Recebido: {'nome': 'Maria Vitória', 'sobrenome': 'da Conceição', 'idade': 29, 'email': 'lavinia75@example.net', 'data_cadastro': '2024-05-28'}
# Recebido: {'nome': 'Pedro Miguel', 'sobrenome': 'Moreira', 'idade': 39, 'email': 'rezendececilia@example.net', 'data_cadastro': '2024-03-08'}
# Recebido: {'nome': 'Mariana', 'sobrenome': 'Freitas', 'idade': 42, 'email': 'ymendes@example.com', 'data_cadastro': '2024-03-15'}
# Recebido: {'nome': 'Emanuel', 'sobrenome': 'Nascimento', 'idade': 43, 'email': 'melomaria-alice@example.com', 'data_cadastro': '2024-07-17'}
# Recebido: {'nome': 'Helena', 'sobrenome': 'Rodrigues', 'idade': 40, 'email': 'joao-pedroalves@example.org', 'data_cadastro': '2024-02-09'}
# Recebido: {'nome': 'Raquel', 'sobrenome': 'Rezende', 'idade': 49, 'email': 'sarahcorreia@example.net', 'data_cadastro': '2024-05-29'}
# Recebido: {'nome': 'Marcelo', 'sobrenome': 'Rezende', 'idade': 48, 'email': 'benjamin15@example.org', 'data_cadastro': '2024-03-30'}
# Recebido: {'nome': 'Ana Julia', 'sobrenome': 'Dias', 'idade': 42, 'email': 'yurisilva@example.com', 'data_cadastro': '2024-01-01'}
# Recebido: {'nome': 'Stephany', 'sobrenome': 'Gomes', 'idade': 54, 'email': 'samuelcosta@example.net', 'data_cadastro': '2024-03-29'}
# Recebido: {'nome': 'Joaquim', 'sobrenome': 'da Rocha', 'idade': 66, 'email': 'yurida-luz@example.com', 'data_cadastro': '2024-02-29'}
# Recebido: {'nome': 'Marcelo', 'sobrenome': 'Silveira', 'idade': 68, 'email': 'tporto@example.com', 'data_cadastro': '2024-04-20'}
# Recebido: {'nome': 'Bianca', 'sobrenome': 'Lopes', 'idade': 65, 'email': 'mda-cunha@example.net', 'data_cadastro': '2024-06-01'}
# Recebido: {'nome': 'Sarah', 'sobrenome': 'Monteiro', 'idade': 52, 'email': 'natalia74@example.net', 'data_cadastro': '2024-03-19'}
# Recebido: {'nome': 'Valentina', 'sobrenome': 'Costela', 'idade': 37, 'email': 'zlima@example.net', 'data_cadastro': '2024-08-04'}
# Recebido: {'nome': 'Emanuel', 'sobrenome': 'Ribeiro', 'idade': 46, 'email': 'luna50@example.net', 'data_cadastro': '2024-04-25'}
# Recebido: {'nome': 'Ana Carolina', 'sobrenome': 'Lopes', 'idade': 70, 'email': 'luiz-felipecastro@example.org', 'data_cadastro': '2024-01-07'}
# Recebido: {'nome': 'Daniel', 'sobrenome': 'Rocha', 'idade': 29, 'email': 'goncalvesgabriela@example.org', 'data_cadastro': '2024-05-29'}
# Recebido: {'nome': 'Mariane', 'sobrenome': 'Fernandes', 'idade': 26, 'email': 'afernandes@example.com', 'data_cadastro': '2024-02-25'}
# Recebido: {'nome': 'Davi', 'sobrenome': 'Novaes', 'idade': 47, 'email': 'mouramaria-julia@example.org', 'data_cadastro': '2024-04-02'}
# Recebido: {'nome': 'Alice', 'sobrenome': 'Silveira', 'idade': 59, 'email': 'msilveira@example.com', 'data_cadastro': '2024-06-13'}
# Recebido: {'nome': 'Raquel', 'sobrenome': 'Barbosa', 'idade': 66, 'email': 'pda-cruz@example.com', 'data_cadastro': '2024-02-21'}
# Recebido: {'nome': 'Sophie', 'sobrenome': 'da Rocha', 'idade': 67, 'email': 'lunaduarte@example.com', 'data_cadastro': '2024-06-29'}
# Recebido: {'nome': 'Yuri', 'sobrenome': 'Freitas', 'idade': 26, 'email': 'ana-luizasouza@example.com', 'data_cadastro': '2024-02-14'}
# Recebido: {'nome': 'Marcos Vinicius', 'sobrenome': 'Gomes', 'idade': 52, 'email': 'lcarvalho@example.net', 'data_cadastro': '2024-05-08'}
# Recebido: {'nome': 'Ana Julia', 'sobrenome': 'Peixoto', 'idade': 41, 'email': 'ana-vitoria46@example.org', 'data_cadastro': '2024-05-19'}
# Recebido: {'nome': 'Julia', 'sobrenome': 'Ribeiro', 'idade': 53, 'email': 'gcostela@example.net', 'data_cadastro': '2024-04-27'}
# Recebido: {'nome': 'Ana Carolina', 'sobrenome': 'Viana', 'idade': 23, 'email': 'barbosavicente@example.org', 'data_cadastro': '2024-05-29'}
# Recebido: {'nome': 'Bruna', 'sobrenome': 'Porto', 'idade': 30, 'email': 'brendapires@example.com', 'data_cadastro': '2024-06-29'}
# Recebido: {'nome': 'Thomas', 'sobrenome': 'Lopes', 'idade': 31, 'email': 'baragao@example.com', 'data_cadastro': '2024-06-29'}
# Recebido: {'nome': 'Bárbara', 'sobrenome': 'Duarte', 'idade': 60, 'email': 'joao-guilherme71@example.net', 'data_cadastro': '2024-06-18'}
# Recebido: {'nome': 'Vinicius', 'sobrenome': 'Almeida', 'idade': 47, 'email': 'elisa97@example.org', 'data_cadastro': '2024-08-02'}
# Recebido: {'nome': 'André', 'sobrenome': 'da Conceição', 'idade': 47, 'email': 'luizaribeiro@example.com', 'data_cadastro': '2024-04-12'}
# Recebido: {'nome': 'Guilherme', 'sobrenome': 'Rezende', 'idade': 38, 'email': 'da-rosabeatriz@example.com', 'data_cadastro': '2024-02-22'}
# Recebido: {'nome': 'Heloísa', 'sobrenome': 'Barbosa', 'idade': 37, 'email': 'ufarias@example.com', 'data_cadastro': '2024-02-16'}
# Recebido: {'nome': 'Joaquim', 'sobrenome': 'Nogueira', 'idade': 27, 'email': 'fda-mota@example.com', 'data_cadastro': '2024-07-04'}
# Recebido: {'nome': 'João', 'sobrenome': 'Teixeira', 'idade': 18, 'email': 'pintomaria-fernanda@example.com', 'data_cadastro': '2024-01-04'}
# Recebido: {'nome': 'André', 'sobrenome': 'Azevedo', 'idade': 31, 'email': 'laispeixoto@example.org', 'data_cadastro': '2024-01-17'}
# Recebido: {'nome': 'Davi Lucca', 'sobrenome': 'Monteiro', 'idade': 39, 'email': 'kevin03@example.org', 'data_cadastro': '2024-05-11'}
# Recebido: {'nome': 'Vitor Hugo', 'sobrenome': 'Azevedo', 'idade': 59, 'email': 'unogueira@example.org', 'data_cadastro': '2024-05-29'}
# Recebido: {'nome': 'Diego', 'sobrenome': 'Campos', 'idade': 46, 'email': 'icorreia@example.net', 'data_cadastro': '2024-03-10'}
# Recebido: {'nome': 'Lavínia', 'sobrenome': 'Nogueira', 'idade': 32, 'email': 'thomasbarbosa@example.org', 'data_cadastro': '2024-06-03'}
# Recebido: {'nome': 'Pedro', 'sobrenome': 'da Costa', 'idade': 70, 'email': 'francisco95@example.org', 'data_cadastro': '2024-05-27'}
# Recebido: {'nome': 'Bryan', 'sobrenome': 'Barros', 'idade': 36, 'email': 'joao-miguel69@example.net', 'data_cadastro': '2024-02-18'}
# Recebido: {'nome': 'João', 'sobrenome': 'da Mota', 'idade': 52, 'email': 'alexiagomes@example.com', 'data_cadastro': '2024-08-09'}
# Recebido: {'nome': 'Pedro', 'sobrenome': 'Silveira', 'idade': 32, 'email': 'nogueiraana-livia@example.net', 'data_cadastro': '2024-06-26'}
# Recebido: {'nome': 'Isaac', 'sobrenome': 'Ferreira', 'idade': 63, 'email': 'sofia28@example.org', 'data_cadastro': '2024-05-18'}
# Recebido: {'nome': 'Alexia', 'sobrenome': 'Duarte', 'idade': 26, 'email': 'ana-clara31@example.com', 'data_cadastro': '2024-02-02'}
# Recebido: {'nome': 'Brenda', 'sobrenome': 'Castro', 'idade': 38, 'email': 'xfarias@example.com', 'data_cadastro': '2024-06-07'}
# Recebido: {'nome': 'Danilo', 'sobrenome': 'Sales', 'idade': 20, 'email': 'vramos@example.net', 'data_cadastro': '2024-04-04'}
# Recebido: {'nome': 'Bruna', 'sobrenome': 'Carvalho', 'idade': 59, 'email': 'joao-pedroalmeida@example.com', 'data_cadastro': '2024-06-12'}
# Recebido: {'nome': 'Luiz Otávio', 'sobrenome': 'Souza', 'idade': 37, 'email': 'mendespietro@example.net', 'data_cadastro': '2024-06-28'}
# Recebido: {'nome': 'Yago', 'sobrenome': 'Silveira', 'idade': 18, 'email': 'agatha52@example.com', 'data_cadastro': '2024-01-10'}
# Recebido: {'nome': 'Maitê', 'sobrenome': 'Porto', 'idade': 36, 'email': 'alveslarissa@example.net', 'data_cadastro': '2024-06-06'}
# Recebido: {'nome': 'Erick', 'sobrenome': 'Moreira', 'idade': 23, 'email': 'mda-costa@example.com', 'data_cadastro': '2024-06-06'}
# Recebido: {'nome': 'Ana Vitória', 'sobrenome': 'Rodrigues', 'idade': 21, 'email': 'freitasluiz-fernando@example.com', 'data_cadastro': '2024-05-19'}
# Recebido: {'nome': 'Eloah', 'sobrenome': 'Barros', 'idade': 25, 'email': 'thomas53@example.net', 'data_cadastro': '2024-06-23'}
# Recebido: {'nome': 'Renan', 'sobrenome': 'Peixoto', 'idade': 37, 'email': 'joao-vitor32@example.org', 'data_cadastro': '2024-02-02'}
# Recebido: {'nome': 'Maria Fernanda', 'sobrenome': 'Rocha', 'idade': 58, 'email': 'maysa04@example.com', 'data_cadastro': '2024-05-13'}
# Recebido: {'nome': 'Carolina', 'sobrenome': 'da Conceição', 'idade': 24, 'email': 'theo71@example.org', 'data_cadastro': '2024-04-22'}
# Recebido: {'nome': 'Henrique', 'sobrenome': 'Gomes', 'idade': 49, 'email': 'rodriguescaroline@example.com', 'data_cadastro': '2024-04-16'}
# Recebido: {'nome': 'Carlos Eduardo', 'sobrenome': 'Ferreira', 'idade': 33, 'email': 'fariasmarcela@example.net', 'data_cadastro': '2024-02-26'}
# Recebido: {'nome': 'Milena', 'sobrenome': 'Freitas', 'idade': 57, 'email': 'anthonynogueira@example.com', 'data_cadastro': '2024-04-02'}
# Recebido: {'nome': 'Maysa', 'sobrenome': 'Teixeira', 'idade': 23, 'email': 'alvesrebeca@example.net', 'data_cadastro': '2024-01-10'}
# Recebido: {'nome': 'Alexia', 'sobrenome': 'Carvalho', 'idade': 37, 'email': 'xoliveira@example.com', 'data_cadastro': '2024-03-27'}
# Recebido: {'nome': 'Luiz Miguel', 'sobrenome': 'Alves', 'idade': 28, 'email': 'joao-gabriel82@example.org', 'data_cadastro': '2024-05-03'}
# Recebido: {'nome': 'Marina', 'sobrenome': 'Cardoso', 'idade': 67, 'email': 'mcampos@example.com', 'data_cadastro': '2024-07-22'}
# Recebido: {'nome': 'Enzo', 'sobrenome': 'Freitas', 'idade': 62, 'email': 'agatha97@example.com', 'data_cadastro': '2024-02-04'}
# Recebido: {'nome': 'Danilo', 'sobrenome': 'Sales', 'idade': 54, 'email': 'wnovaes@example.org', 'data_cadastro': '2024-07-04'}
# Recebido: {'nome': 'Daniela', 'sobrenome': 'Rocha', 'idade': 70, 'email': 'joao-gabriel26@example.org', 'data_cadastro': '2024-06-24'}
# Recebido: {'nome': 'Alana', 'sobrenome': 'Cunha', 'idade': 33, 'email': 'valentina58@example.org', 'data_cadastro': '2024-05-15'}
# Recebido: {'nome': 'Helena', 'sobrenome': 'Carvalho', 'idade': 51, 'email': 'hcosta@example.net', 'data_cadastro': '2024-03-29'}
# Recebido: {'nome': 'Noah', 'sobrenome': 'Cardoso', 'idade': 18, 'email': 'jda-mata@example.org', 'data_cadastro': '2024-03-19'}
# Recebido: {'nome': 'Ana Julia', 'sobrenome': 'Alves', 'idade': 25, 'email': 'maria-alice71@example.org', 'data_cadastro': '2024-08-08'}
# Recebido: {'nome': 'Davi', 'sobrenome': 'Carvalho', 'idade': 36, 'email': 'eduardo50@example.com', 'data_cadastro': '2024-05-02'}
# Recebido: {'nome': 'Catarina', 'sobrenome': 'Sales', 'idade': 51, 'email': 'antoniosilveira@example.org', 'data_cadastro': '2024-01-25'}
# Recebido: {'nome': 'Vitória', 'sobrenome': 'Alves', 'idade': 44, 'email': 'lopespietro@example.net', 'data_cadastro': '2024-02-13'}
# Recebido: {'nome': 'Davi Luiz', 'sobrenome': 'Rocha', 'idade': 45, 'email': 'agathacardoso@example.org', 'data_cadastro': '2024-01-13'}
# Recebido: {'nome': 'Otávio', 'sobrenome': 'Cardoso', 'idade': 34, 'email': 'fariaslara@example.org', 'data_cadastro': '2024-05-24'}
# Recebido: {'nome': 'Mariana', 'sobrenome': 'Souza', 'idade': 38, 'email': 'lucas06@example.org', 'data_cadastro': '2024-04-15'}
# Recebido: {'nome': 'Lucca', 'sobrenome': 'Duarte', 'idade': 61, 'email': 'eduardasantos@example.com', 'data_cadastro': '2024-01-08'}
# Recebido: {'nome': 'Ana Laura', 'sobrenome': 'Moura', 'idade': 62, 'email': 'rodriguesalexia@example.net', 'data_cadastro': '2024-05-21'}
# Recebido: {'nome': 'João Miguel', 'sobrenome': 'Carvalho', 'idade': 34, 'email': 'beniciosilveira@example.net', 'data_cadastro': '2024-01-18'}
# Recebido: {'nome': 'Luiza', 'sobrenome': 'Gonçalves', 'idade': 24, 'email': 'moreiraluana@example.org', 'data_cadastro': '2024-02-29'}
# Recebido: {'nome': 'Amanda', 'sobrenome': 'Castro', 'idade': 21, 'email': 'da-conceicaomarina@example.com', 'data_cadastro': '2024-02-10'}
# Recebido: {'nome': 'Rodrigo', 'sobrenome': 'Sales', 'idade': 24, 'email': 'plima@example.org', 'data_cadastro': '2024-07-12'}
# Recebido: {'nome': 'Isabel', 'sobrenome': 'Barbosa', 'idade': 37, 'email': 'ffogaca@example.org', 'data_cadastro': '2024-01-05'}
# Recebido: {'nome': 'Joaquim', 'sobrenome': 'da Costa', 'idade': 50, 'email': 'liviacaldeira@example.net', 'data_cadastro': '2024-01-27'}
# Recebido: {'nome': 'Maysa', 'sobrenome': 'Novaes', 'idade': 42, 'email': 'fernandesolivia@example.net', 'data_cadastro': '2024-02-14'}
# Recebido: {'nome': 'Thiago', 'sobrenome': 'Monteiro', 'idade': 55, 'email': 'tmoreira@example.com', 'data_cadastro': '2024-07-06'}
# Recebido: {'nome': 'Clara', 'sobrenome': 'Monteiro', 'idade': 55, 'email': 'luiz-gustavo59@example.com', 'data_cadastro': '2024-02-28'}
# Recebido: {'nome': 'Augusto', 'sobrenome': 'Gonçalves', 'idade': 42, 'email': 'igorcaldeira@example.com', 'data_cadastro': '2024-05-03'}
# Recebido: {'nome': 'Fernanda', 'sobrenome': 'da Rocha', 'idade': 32, 'email': 'lorenzo94@example.net', 'data_cadastro': '2024-03-27'}
# Recebido: {'nome': 'Matheus', 'sobrenome': 'Cunha', 'idade': 67, 'email': 'brodrigues@example.org', 'data_cadastro': '2024-07-04'}
# Recebido: {'nome': 'Esther', 'sobrenome': 'Moura', 'idade': 57, 'email': 'lcastro@example.net', 'data_cadastro': '2024-07-17'}
# Recebido: {'nome': 'Davi Lucca', 'sobrenome': 'Campos', 'idade': 47, 'email': 'fogacaluana@example.org', 'data_cadastro': '2024-06-27'}
# Recebido: {'nome': 'Maitê', 'sobrenome': 'Alves', 'idade': 61, 'email': 'rochaotavio@example.com', 'data_cadastro': '2024-05-25'}
# Recebido: {'nome': 'Maysa', 'sobrenome': 'Moreira', 'idade': 24, 'email': 'isabellyda-rosa@example.com', 'data_cadastro': '2024-01-21'}
# Recebido: {'nome': 'Emilly', 'sobrenome': 'Melo', 'idade': 18, 'email': 'zcaldeira@example.com', 'data_cadastro': '2024-07-30'}
# Recebido: {'nome': 'Maria', 'sobrenome': 'Barros', 'idade': 27, 'email': 'bfarias@example.net', 'data_cadastro': '2024-04-09'}
# Recebido: {'nome': 'Eduarda', 'sobrenome': 'Aragão', 'idade': 52, 'email': 'isabelly97@example.com', 'data_cadastro': '2024-06-29'}
# Recebido: {'nome': 'Arthur', 'sobrenome': 'Carvalho', 'idade': 44, 'email': 'ana-carolinamoraes@example.com', 'data_cadastro': '2024-02-21'}
# Recebido: {'nome': 'Eduardo', 'sobrenome': 'Castro', 'idade': 69, 'email': 'cfarias@example.com', 'data_cadastro': '2024-06-06'}
# Recebido: {'nome': 'Heitor', 'sobrenome': 'Silveira', 'idade': 54, 'email': 'moraesjuliana@example.net', 'data_cadastro': '2024-01-25'}
# Recebido: {'nome': 'Rebeca', 'sobrenome': 'da Costa', 'idade': 68, 'email': 'davi-luccacastro@example.org', 'data_cadastro': '2024-05-08'}
# Recebido: {'nome': 'Bárbara', 'sobrenome': 'da Rosa', 'idade': 30, 'email': 'davi-luiz90@example.com', 'data_cadastro': '2024-02-23'}
# Recebido: {'nome': 'Francisco', 'sobrenome': 'Ferreira', 'idade': 41, 'email': 'oda-conceicao@example.net', 'data_cadastro': '2024-07-25'}
# Recebido: {'nome': 'Gustavo', 'sobrenome': 'Dias', 'idade': 55, 'email': 'hsilva@example.com', 'data_cadastro': '2024-05-25'}
# Recebido: {'nome': 'Beatriz', 'sobrenome': 'Silveira', 'idade': 28, 'email': 'fariassarah@example.com', 'data_cadastro': '2024-06-18'}
# Recebido: {'nome': 'Raquel', 'sobrenome': 'Duarte', 'idade': 30, 'email': 'hnogueira@example.net', 'data_cadastro': '2024-04-27'}
# Recebido: {'nome': 'Gustavo', 'sobrenome': 'Castro', 'idade': 31, 'email': 'bryanteixeira@example.org', 'data_cadastro': '2024-02-26'}
# Recebido: {'nome': 'Lucas Gabriel', 'sobrenome': 'Costela', 'idade': 36, 'email': 'lucasda-cruz@example.net', 'data_cadastro': '2024-01-16'}
# Recebido: {'nome': 'Clara', 'sobrenome': 'Ramos', 'idade': 67, 'email': 'marinaoliveira@example.org', 'data_cadastro': '2024-03-10'}
# Recebido: {'nome': 'João Lucas', 'sobrenome': 'Nascimento', 'idade': 47, 'email': 'clarice81@example.com', 'data_cadastro': '2024-07-06'}
# Recebido: {'nome': 'Nicole', 'sobrenome': 'Duarte', 'idade': 39, 'email': 'milenacastro@example.org', 'data_cadastro': '2024-07-26'}
# Recebido: {'nome': 'Arthur', 'sobrenome': 'Silveira', 'idade': 52, 'email': 'igorteixeira@example.org', 'data_cadastro': '2024-05-29'}
# Recebido: {'nome': 'Vitória', 'sobrenome': 'Rezende', 'idade': 27, 'email': 'msales@example.net', 'data_cadastro': '2024-08-07'}
# Recebido: {'nome': 'João Lucas', 'sobrenome': 'Silva', 'idade': 66, 'email': 'nicolas03@example.com', 'data_cadastro': '2024-07-21'}
# Recebido: {'nome': 'Lívia', 'sobrenome': 'Cardoso', 'idade': 46, 'email': 'jlima@example.net', 'data_cadastro': '2024-08-09'}
# Recebido: {'nome': 'Lara', 'sobrenome': 'Teixeira', 'idade': 51, 'email': 'eloahviana@example.net', 'data_cadastro': '2024-02-15'}
# Recebido: {'nome': 'Mirella', 'sobrenome': 'da Mota', 'idade': 41, 'email': 'goncalvesantonio@example.com', 'data_cadastro': '2024-07-26'}
# Recebido: {'nome': 'Yago', 'sobrenome': 'Freitas', 'idade': 54, 'email': 'luigimendes@example.net', 'data_cadastro': '2024-06-03'}
# Recebido: {'nome': 'Sofia', 'sobrenome': 'Azevedo', 'idade': 18, 'email': 'ipeixoto@example.org', 'data_cadastro': '2024-02-29'}
# Recebido: {'nome': 'Ana Vitória', 'sobrenome': 'Almeida', 'idade': 56, 'email': 'vnascimento@example.org', 'data_cadastro': '2024-02-25'}
# Recebido: {'nome': 'Leonardo', 'sobrenome': 'da Rocha', 'idade': 40, 'email': 'gabrielacarvalho@example.org', 'data_cadastro': '2024-03-28'}
# Recebido: {'nome': 'Yago', 'sobrenome': 'Cardoso', 'idade': 43, 'email': 'luiz-felipe28@example.net', 'data_cadastro': '2024-02-18'}
# Recebido: {'nome': 'Isadora', 'sobrenome': 'Correia', 'idade': 44, 'email': 'barbara77@example.org', 'data_cadastro': '2024-07-29'}
# Recebido: {'nome': 'Thomas', 'sobrenome': 'Barbosa', 'idade': 20, 'email': 'maria-fernanda32@example.net', 'data_cadastro': '2024-01-19'}
# Recebido: {'nome': 'Sofia', 'sobrenome': 'Peixoto', 'idade': 25, 'email': 'fogacaemilly@example.com', 'data_cadastro': '2024-06-21'}
# Recebido: {'nome': 'Alice', 'sobrenome': 'da Mata', 'idade': 58, 'email': 'maysacarvalho@example.org', 'data_cadastro': '2024-06-28'}
# Recebido: {'nome': 'Bruno', 'sobrenome': 'Peixoto', 'idade': 43, 'email': 'clarada-mata@example.org', 'data_cadastro': '2024-05-03'}
# Recebido: {'nome': 'Cauê', 'sobrenome': 'Nogueira', 'idade': 23, 'email': 'thales42@example.org', 'data_cadastro': '2024-02-01'}
# Recebido: {'nome': 'Raul', 'sobrenome': 'Cavalcanti', 'idade': 60, 'email': 'marianefreitas@example.org', 'data_cadastro': '2024-02-28'}
# Recebido: {'nome': 'André', 'sobrenome': 'Pinto', 'idade': 28, 'email': 'limacaue@example.net', 'data_cadastro': '2024-07-15'}
# Recebido: {'nome': 'Anthony', 'sobrenome': 'Lima', 'idade': 18, 'email': 'luana67@example.net', 'data_cadastro': '2024-08-07'}
# Recebido: {'nome': 'Vinicius', 'sobrenome': 'Almeida', 'idade': 31, 'email': 'yfernandes@example.net', 'data_cadastro': '2024-05-04'}
# Recebido: {'nome': 'Maitê', 'sobrenome': 'Cardoso', 'idade': 29, 'email': 'sophiecarvalho@example.net', 'data_cadastro': '2024-01-19'}
# Recebido: {'nome': 'Laís', 'sobrenome': 'da Conceição', 'idade': 70, 'email': 'carvalhonicole@example.com', 'data_cadastro': '2024-01-09'}
# Recebido: {'nome': 'Valentina', 'sobrenome': 'Vieira', 'idade': 44, 'email': 'bmelo@example.org', 'data_cadastro': '2024-06-29'}
# Recebido: {'nome': 'Calebe', 'sobrenome': 'Fogaça', 'idade': 37, 'email': 'cauada-cunha@example.com', 'data_cadastro': '2024-01-26'}
# Recebido: {'nome': 'Isadora', 'sobrenome': 'Oliveira', 'idade': 23, 'email': 'da-costalara@example.com', 'data_cadastro': '2024-06-30'}
# Recebido: {'nome': 'Thomas', 'sobrenome': 'Farias', 'idade': 20, 'email': 'maitemoreira@example.net', 'data_cadastro': '2024-02-07'}
# Recebido: {'nome': 'Enzo', 'sobrenome': 'Rezende', 'idade': 23, 'email': 'rezendelorena@example.org', 'data_cadastro': '2024-06-10'}
# Recebido: {'nome': 'Nicolas', 'sobrenome': 'da Costa', 'idade': 55, 'email': 'ebarbosa@example.net', 'data_cadastro': '2024-02-09'}
# Recebido: {'nome': 'Cauê', 'sobrenome': 'Campos', 'idade': 56, 'email': 'samuel92@example.net', 'data_cadastro': '2024-06-21'}
# Recebido: {'nome': 'Luiz Gustavo', 'sobrenome': 'Azevedo', 'idade': 25, 'email': 'dcardoso@example.org', 'data_cadastro': '2024-03-15'}
# Recebido: {'nome': 'Vitor', 'sobrenome': 'da Costa', 'idade': 52, 'email': 'rezendeheloisa@example.com', 'data_cadastro': '2024-02-10'}
# Recebido: {'nome': 'Luiz Fernando', 'sobrenome': 'Santos', 'idade': 69, 'email': 'maria-alice92@example.org', 'data_cadastro': '2024-01-09'}
# Recebido: {'nome': 'Lucas Gabriel', 'sobrenome': 'Rodrigues', 'idade': 24, 'email': 'xporto@example.net', 'data_cadastro': '2024-01-23'}
# Recebido: {'nome': 'Matheus', 'sobrenome': 'Aragão', 'idade': 21, 'email': 'julia71@example.org', 'data_cadastro': '2024-08-07'}
# Recebido: {'nome': 'Lucca', 'sobrenome': 'Lima', 'idade': 38, 'email': 'vda-paz@example.com', 'data_cadastro': '2024-06-04'}
# Recebido: {'nome': 'Guilherme', 'sobrenome': 'Caldeira', 'idade': 65, 'email': 'luanacardoso@example.net', 'data_cadastro': '2024-04-18'}
# Recebido: {'nome': 'Vicente', 'sobrenome': 'Moraes', 'idade': 45, 'email': 'vianasamuel@example.net', 'data_cadastro': '2024-07-14'}
# Recebido: {'nome': 'Alexia', 'sobrenome': 'Oliveira', 'idade': 36, 'email': 'rochadavi-luiz@example.net', 'data_cadastro': '2024-06-01'}
# Recebido: {'nome': 'Diego', 'sobrenome': 'da Cruz', 'idade': 31, 'email': 'almeidajoao-vitor@example.org', 'data_cadastro': '2024-06-02'}
# Recebido: {'nome': 'Lucas Gabriel', 'sobrenome': 'Porto', 'idade': 27, 'email': 'gfarias@example.com', 'data_cadastro': '2024-04-04'}
# Recebido: {'nome': 'Gabriela', 'sobrenome': 'Peixoto', 'idade': 37, 'email': 'piresana-julia@example.net', 'data_cadastro': '2024-02-16'}
# Recebido: {'nome': 'Benjamin', 'sobrenome': 'Vieira', 'idade': 56, 'email': 'costaluiza@example.com', 'data_cadastro': '2024-04-16'}
# Recebido: {'nome': 'Fernando', 'sobrenome': 'Gomes', 'idade': 66, 'email': 'ana-sophiavieira@example.com', 'data_cadastro': '2024-05-12'}
# Recebido: {'nome': 'Luiz Otávio', 'sobrenome': 'Pinto', 'idade': 40, 'email': 'ana11@example.net', 'data_cadastro': '2024-03-21'}
# Recebido: {'nome': 'Vitor Gabriel', 'sobrenome': 'Rodrigues', 'idade': 52, 'email': 'vitoriarodrigues@example.org', 'data_cadastro': '2024-06-01'}
# Recebido: {'nome': 'Luigi', 'sobrenome': 'Barros', 'idade': 19, 'email': 'almeidahelena@example.org', 'data_cadastro': '2024-01-07'}
# Recebido: {'nome': 'Bryan', 'sobrenome': 'Novaes', 'idade': 55, 'email': 'caue02@example.org', 'data_cadastro': '2024-02-05'}
# Recebido: {'nome': 'Valentina', 'sobrenome': 'da Cruz', 'idade': 57, 'email': 'fogacatheo@example.com', 'data_cadastro': '2024-05-17'}
# Recebido: {'nome': 'Sarah', 'sobrenome': 'Teixeira', 'idade': 21, 'email': 'renanpinto@example.com', 'data_cadastro': '2024-08-09'}
# Recebido: {'nome': 'Kevin', 'sobrenome': 'Rezende', 'idade': 26, 'email': 'abarros@example.org', 'data_cadastro': '2024-05-13'}
# Recebido: {'nome': 'Emilly', 'sobrenome': 'Freitas', 'idade': 56, 'email': 'otaviomoraes@example.org', 'data_cadastro': '2024-05-09'}
# Recebido: {'nome': 'Cauê', 'sobrenome': 'das Neves', 'idade': 52, 'email': 'ffogaca@example.net', 'data_cadastro': '2024-02-20'}
# Recebido: {'nome': 'Cauê', 'sobrenome': 'da Costa', 'idade': 54, 'email': 'enzo-gabrielsantos@example.net', 'data_cadastro': '2024-01-19'}
# Recebido: {'nome': 'Pedro Lucas', 'sobrenome': 'da Mata', 'idade': 59, 'email': 'xcaldeira@example.com', 'data_cadastro': '2024-01-21'}
# Recebido: {'nome': 'Daniel', 'sobrenome': 'Teixeira', 'idade': 36, 'email': 'marcos-viniciusda-rosa@example.com', 'data_cadastro': '2024-03-11'}
# Recebido: {'nome': 'Joana', 'sobrenome': 'Rodrigues', 'idade': 24, 'email': 'sophiebarros@example.org', 'data_cadastro': '2024-07-30'}
# Recebido: {'nome': 'Ana', 'sobrenome': 'Dias', 'idade': 19, 'email': 'isabelladas-neves@example.org', 'data_cadastro': '2024-06-25'}
# Recebido: {'nome': 'Yago', 'sobrenome': 'Rodrigues', 'idade': 43, 'email': 'nrezende@example.org', 'data_cadastro': '2024-03-15'}
# Recebido: {'nome': 'Calebe', 'sobrenome': 'Lima', 'idade': 51, 'email': 'leandrolopes@example.net', 'data_cadastro': '2024-01-14'}
# Recebido: {'nome': 'Juliana', 'sobrenome': 'Pinto', 'idade': 21, 'email': 'joao-pedro97@example.com', 'data_cadastro': '2024-02-25'}
# Recebido: {'nome': 'Brenda', 'sobrenome': 'Viana', 'idade': 25, 'email': 'rodriguesgiovanna@example.com', 'data_cadastro': '2024-04-13'}
# Recebido: {'nome': 'Gustavo Henrique', 'sobrenome': 'Cardoso', 'idade': 35, 'email': 'evelynda-conceicao@example.com', 'data_cadastro': '2024-06-10'}
# Recebido: {'nome': 'Clara', 'sobrenome': 'Gonçalves', 'idade': 63, 'email': 'liviafogaca@example.net', 'data_cadastro': '2024-03-07'}
# Recebido: {'nome': 'Henrique', 'sobrenome': 'Melo', 'idade': 59, 'email': 'duartegabrielly@example.com', 'data_cadastro': '2024-03-08'}
# Recebido: {'nome': 'Catarina', 'sobrenome': 'Moreira', 'idade': 49, 'email': 'diogovieira@example.net', 'data_cadastro': '2024-07-24'}
# Recebido: {'nome': 'Vitor', 'sobrenome': 'Ramos', 'idade': 24, 'email': 'maria-julia21@example.net', 'data_cadastro': '2024-03-31'}
# Recebido: {'nome': 'Bruno', 'sobrenome': 'Farias', 'idade': 56, 'email': 'davimoraes@example.org', 'data_cadastro': '2024-01-20'}
# Recebido: {'nome': 'João Lucas', 'sobrenome': 'Lopes', 'idade': 58, 'email': 'joao-miguel88@example.net', 'data_cadastro': '2024-03-17'}
# Recebido: {'nome': 'Ana Júlia', 'sobrenome': 'Freitas', 'idade': 21, 'email': 'duarteisis@example.com', 'data_cadastro': '2024-08-02'}
# Recebido: {'nome': 'Guilherme', 'sobrenome': 'Oliveira', 'idade': 20, 'email': 'enrico24@example.com', 'data_cadastro': '2024-05-12'}
# Recebido: {'nome': 'Isaac', 'sobrenome': 'Monteiro', 'idade': 23, 'email': 'nsilveira@example.com', 'data_cadastro': '2024-04-20'}
# Recebido: {'nome': 'Valentina', 'sobrenome': 'Gomes', 'idade': 39, 'email': 'pintovitoria@example.com', 'data_cadastro': '2024-04-04'}
# Recebido: {'nome': 'Maysa', 'sobrenome': 'Farias', 'idade': 24, 'email': 'nunesdiogo@example.net', 'data_cadastro': '2024-01-23'}
# Recebido: {'nome': 'Ana Lívia', 'sobrenome': 'Peixoto', 'idade': 44, 'email': 'isisda-mota@example.com', 'data_cadastro': '2024-04-05'}
# Recebido: {'nome': 'Natália', 'sobrenome': 'Cardoso', 'idade': 27, 'email': 'almeidathomas@example.net', 'data_cadastro': '2024-07-24'}
# Recebido: {'nome': 'Marcelo', 'sobrenome': 'Moura', 'idade': 60, 'email': 'da-rosatheo@example.com', 'data_cadastro': '2024-07-13'}
# Recebido: {'nome': 'Ana Júlia', 'sobrenome': 'Cunha', 'idade': 27, 'email': 'kporto@example.org', 'data_cadastro': '2024-01-12'}
# Recebido: {'nome': 'Henrique', 'sobrenome': 'Oliveira', 'idade': 64, 'email': 'davi00@example.org', 'data_cadastro': '2024-07-18'}
# Recebido: {'nome': 'Luiz Miguel', 'sobrenome': 'Cunha', 'idade': 31, 'email': 'camilateixeira@example.org', 'data_cadastro': '2024-01-15'}
# Recebido: {'nome': 'Marina', 'sobrenome': 'da Mata', 'idade': 21, 'email': 'pramos@example.net', 'data_cadastro': '2024-01-04'}
# Recebido: {'nome': 'Isis', 'sobrenome': 'da Costa', 'idade': 19, 'email': 'peixotolaura@example.net', 'data_cadastro': '2024-04-28'}
# Recebido: {'nome': 'Pietro', 'sobrenome': 'Ferreira', 'idade': 24, 'email': 'anamoreira@example.com', 'data_cadastro': '2024-03-12'}
# Recebido: {'nome': 'Noah', 'sobrenome': 'Moraes', 'idade': 37, 'email': 'tcampos@example.org', 'data_cadastro': '2024-06-22'}
# Recebido: {'nome': 'Theo', 'sobrenome': 'Costa', 'idade': 36, 'email': 'costelaaugusto@example.org', 'data_cadastro': '2024-05-04'}
# Recebido: {'nome': 'Ana', 'sobrenome': 'Martins', 'idade': 41, 'email': 'igor15@example.net', 'data_cadastro': '2024-07-01'}
# Recebido: {'nome': 'Vicente', 'sobrenome': 'da Cruz', 'idade': 49, 'email': 'moreiravicente@example.net', 'data_cadastro': '2024-05-17'}
# Recebido: {'nome': 'Ana Laura', 'sobrenome': 'Cavalcanti', 'idade': 57, 'email': 'pazevedo@example.org', 'data_cadastro': '2024-06-16'}
# Recebido: {'nome': 'Breno', 'sobrenome': 'Duarte', 'idade': 18, 'email': 'bmoraes@example.net', 'data_cadastro': '2024-01-06'}
# Recebido: {'nome': 'João Vitor', 'sobrenome': 'Teixeira', 'idade': 67, 'email': 'fernando18@example.net', 'data_cadastro': '2024-05-01'}
# Recebido: {'nome': 'Davi Lucas', 'sobrenome': 'Moraes', 'idade': 59, 'email': 'teixeiraluiz-felipe@example.com', 'data_cadastro': '2024-08-07'}
# Recebido: {'nome': 'Letícia', 'sobrenome': 'Costela', 'idade': 53, 'email': 'thomaspires@example.org', 'data_cadastro': '2024-04-11'}
# Recebido: {'nome': 'Eduardo', 'sobrenome': 'Rodrigues', 'idade': 44, 'email': 'da-costaluiz-henrique@example.com', 'data_cadastro': '2024-05-16'}
# Recebido: {'nome': 'Lavínia', 'sobrenome': 'Cunha', 'idade': 45, 'email': 'sda-rocha@example.org', 'data_cadastro': '2024-06-20'}
# Recebido: {'nome': 'Lorena', 'sobrenome': 'Lopes', 'idade': 21, 'email': 'goncalvesesther@example.com', 'data_cadastro': '2024-03-18'}
# Recebido: {'nome': 'Ana Laura', 'sobrenome': 'Silveira', 'idade': 57, 'email': 'ocastro@example.net', 'data_cadastro': '2024-03-05'}
# Recebido: {'nome': 'Emilly', 'sobrenome': 'da Mota', 'idade': 27, 'email': 'uda-mota@example.com', 'data_cadastro': '2024-05-23'}
# Recebido: {'nome': 'Emanuella', 'sobrenome': 'Rodrigues', 'idade': 28, 'email': 'cardosokaique@example.org', 'data_cadastro': '2024-07-01'}
# Recebido: {'nome': 'Maria Alice', 'sobrenome': 'Costela', 'idade': 33, 'email': 'barbosalara@example.com', 'data_cadastro': '2024-02-10'}
# Recebido: {'nome': 'Thales', 'sobrenome': 'Ferreira', 'idade': 57, 'email': 'rrodrigues@example.org', 'data_cadastro': '2024-07-17'}
# Recebido: {'nome': 'Maria Alice', 'sobrenome': 'Moreira', 'idade': 56, 'email': 'azevedoisabel@example.net', 'data_cadastro': '2024-03-15'}
# Recebido: {'nome': 'Maria Fernanda', 'sobrenome': 'Ferreira', 'idade': 27, 'email': 'camilalima@example.org', 'data_cadastro': '2024-04-09'}
# Recebido: {'nome': 'Emilly', 'sobrenome': 'Jesus', 'idade': 39, 'email': 'esouza@example.net', 'data_cadastro': '2024-06-03'}
# Recebido: {'nome': 'Ana Clara', 'sobrenome': 'Ramos', 'idade': 26, 'email': 'wda-cruz@example.com', 'data_cadastro': '2024-03-09'}
# Recebido: {'nome': 'Lucas', 'sobrenome': 'Mendes', 'idade': 28, 'email': 'ferreirapedro-lucas@example.com', 'data_cadastro': '2024-01-21'}
# Recebido: {'nome': 'Lorena', 'sobrenome': 'Jesus', 'idade': 43, 'email': 'marianalima@example.org', 'data_cadastro': '2024-06-05'}
# Recebido: {'nome': 'Rafael', 'sobrenome': 'Farias', 'idade': 24, 'email': 'isispeixoto@example.com', 'data_cadastro': '2024-01-01'}
# Recebido: {'nome': 'Emanuella', 'sobrenome': 'Moraes', 'idade': 28, 'email': 'joliveira@example.com', 'data_cadastro': '2024-04-16'}
# Recebido: {'nome': 'Luigi', 'sobrenome': 'Ribeiro', 'idade': 42, 'email': 'gmartins@example.com', 'data_cadastro': '2024-04-02'}
# Recebido: {'nome': 'Ana Luiza', 'sobrenome': 'Pinto', 'idade': 69, 'email': 'isabella15@example.org', 'data_cadastro': '2024-05-07'}
# Recebido: {'nome': 'Lucca', 'sobrenome': 'da Luz', 'idade': 31, 'email': 'vieiragustavo-henrique@example.org', 'data_cadastro': '2024-05-02'}
# Recebido: {'nome': 'Eduarda', 'sobrenome': 'Dias', 'idade': 21, 'email': 'santossophia@example.com', 'data_cadastro': '2024-01-18'}
# Recebido: {'nome': 'Luiz Gustavo', 'sobrenome': 'Peixoto', 'idade': 19, 'email': 'maysasilveira@example.org', 'data_cadastro': '2024-01-14'}
# Recebido: {'nome': 'Vitor Hugo', 'sobrenome': 'Fernandes', 'idade': 68, 'email': 'nicolaslima@example.org', 'data_cadastro': '2024-03-21'}
# Recebido: {'nome': 'Augusto', 'sobrenome': 'Carvalho', 'idade': 55, 'email': 'nathan56@example.com', 'data_cadastro': '2024-03-07'}
# Recebido: {'nome': 'Francisco', 'sobrenome': 'Teixeira', 'idade': 66, 'email': 'da-costapedro-lucas@example.org', 'data_cadastro': '2024-07-17'}
# Recebido: {'nome': 'Fernando', 'sobrenome': 'Viana', 'idade': 64, 'email': 'barbarada-cunha@example.org', 'data_cadastro': '2024-04-04'}
# Recebido: {'nome': 'Maria Julia', 'sobrenome': 'Costela', 'idade': 30, 'email': 'laura02@example.net', 'data_cadastro': '2024-05-22'}
# Recebido: {'nome': 'Vicente', 'sobrenome': 'Mendes', 'idade': 39, 'email': 'ssouza@example.net', 'data_cadastro': '2024-05-04'}
# Recebido: {'nome': 'Emanuelly', 'sobrenome': 'Ferreira', 'idade': 50, 'email': 'fcunha@example.org', 'data_cadastro': '2024-07-01'}
# Recebido: {'nome': 'Henrique', 'sobrenome': 'Ferreira', 'idade': 50, 'email': 'yda-cruz@example.com', 'data_cadastro': '2024-07-13'}
# Recebido: {'nome': 'Antônio', 'sobrenome': 'Araújo', 'idade': 31, 'email': 'gustavo-henrique67@example.net', 'data_cadastro': '2024-06-25'}
# Recebido: {'nome': 'Isabella', 'sobrenome': 'Freitas', 'idade': 36, 'email': 'pereiraguilherme@example.org', 'data_cadastro': '2024-04-22'}
# Recebido: {'nome': 'Davi Lucca', 'sobrenome': 'da Mota', 'idade': 63, 'email': 'pedro-miguelalmeida@example.com', 'data_cadastro': '2024-05-13'}
# Recebido: {'nome': 'Lucas', 'sobrenome': 'Alves', 'idade': 60, 'email': 'beatriz85@example.com', 'data_cadastro': '2024-03-09'}
# Recebido: {'nome': 'Eloah', 'sobrenome': 'Barros', 'idade': 35, 'email': 'fariasjoao-gabriel@example.org', 'data_cadastro': '2024-01-18'}
# Recebido: {'nome': 'Ana Lívia', 'sobrenome': 'Nogueira', 'idade': 36, 'email': 'esther32@example.net', 'data_cadastro': '2024-06-13'}
# Recebido: {'nome': 'Vitor Gabriel', 'sobrenome': 'Dias', 'idade': 36, 'email': 'lorenzo27@example.org', 'data_cadastro': '2024-04-28'}
# Recebido: {'nome': 'Arthur', 'sobrenome': 'Melo', 'idade': 43, 'email': 'felipejesus@example.com', 'data_cadastro': '2024-07-06'}
# Recebido: {'nome': 'Matheus', 'sobrenome': 'Teixeira', 'idade': 60, 'email': 'juan23@example.net', 'data_cadastro': '2024-04-02'}
# Recebido: {'nome': 'Camila', 'sobrenome': 'Cavalcanti', 'idade': 50, 'email': 'kmoraes@example.net', 'data_cadastro': '2024-07-19'}
# Recebido: {'nome': 'Clarice', 'sobrenome': 'Cavalcanti', 'idade': 50, 'email': 'kcampos@example.com', 'data_cadastro': '2024-01-24'}
# Recebido: {'nome': 'Arthur', 'sobrenome': 'Santos', 'idade': 69, 'email': 'joao-migueldas-neves@example.org', 'data_cadastro': '2024-01-05'}
# Recebido: {'nome': 'Eloah', 'sobrenome': 'da Luz', 'idade': 29, 'email': 'ulima@example.org', 'data_cadastro': '2024-08-08'}
# Recebido: {'nome': 'Mariana', 'sobrenome': 'Nunes', 'idade': 58, 'email': 'larissa26@example.com', 'data_cadastro': '2024-03-12'}
# Recebido: {'nome': 'Stella', 'sobrenome': 'Silveira', 'idade': 65, 'email': 'qribeiro@example.com', 'data_cadastro': '2024-02-29'}
# Recebido: {'nome': 'Ana Clara', 'sobrenome': 'Cunha', 'idade': 26, 'email': 'uda-paz@example.org', 'data_cadastro': '2024-07-05'}
# Recebido: {'nome': 'Joaquim', 'sobrenome': 'Pires', 'idade': 31, 'email': 'paulo79@example.com', 'data_cadastro': '2024-02-26'}
# Recebido: {'nome': 'Valentina', 'sobrenome': 'Moura', 'idade': 69, 'email': 'matheuspires@example.com', 'data_cadastro': '2024-05-08'}
# Recebido: {'nome': 'Luiz Otávio', 'sobrenome': 'Pereira', 'idade': 38, 'email': 'gduarte@example.com', 'data_cadastro': '2024-07-22'}
# Recebido: {'nome': 'Isabella', 'sobrenome': 'Novaes', 'idade': 19, 'email': 'barbara07@example.org', 'data_cadastro': '2024-06-07'}
# Recebido: {'nome': 'Emilly', 'sobrenome': 'Barbosa', 'idade': 31, 'email': 'alvesbernardo@example.org', 'data_cadastro': '2024-04-04'}
# Recebido: {'nome': 'Maysa', 'sobrenome': 'Melo', 'idade': 51, 'email': 'gdas-neves@example.com', 'data_cadastro': '2024-01-17'}
# Recebido: {'nome': 'Ana Laura', 'sobrenome': 'Fogaça', 'idade': 59, 'email': 'fariasjoao-felipe@example.com', 'data_cadastro': '2024-07-03'}
# Recebido: {'nome': 'Pedro Miguel', 'sobrenome': 'Sales', 'idade': 39, 'email': 'lcampos@example.org', 'data_cadastro': '2024-06-10'}
# Recebido: {'nome': 'Murilo', 'sobrenome': 'Nascimento', 'idade': 47, 'email': 'eduardo35@example.org', 'data_cadastro': '2024-05-29'}
# Recebido: {'nome': 'Alana', 'sobrenome': 'Cavalcanti', 'idade': 51, 'email': 'lara20@example.org', 'data_cadastro': '2024-06-07'}
# Recebido: {'nome': 'Vinicius', 'sobrenome': 'Ferreira', 'idade': 47, 'email': 'wcaldeira@example.com', 'data_cadastro': '2024-02-04'}
# Recebido: {'nome': 'Lucca', 'sobrenome': 'Barbosa', 'idade': 19, 'email': 'limabarbara@example.net', 'data_cadastro': '2024-03-10'}
# Recebido: {'nome': 'Luiz Otávio', 'sobrenome': 'Nunes', 'idade': 54, 'email': 'benicio26@example.net', 'data_cadastro': '2024-01-15'}
# Recebido: {'nome': 'Maria Sophia', 'sobrenome': 'Moreira', 'idade': 63, 'email': 'elisa86@example.net', 'data_cadastro': '2024-05-18'}
# Recebido: {'nome': 'Anthony', 'sobrenome': 'da Cruz', 'idade': 42, 'email': 'maria-vitoria68@example.org', 'data_cadastro': '2024-07-14'}
# Recebido: {'nome': 'Larissa', 'sobrenome': 'da Mata', 'idade': 24, 'email': 'pereiracaua@example.net', 'data_cadastro': '2024-02-29'}
# Recebido: {'nome': 'Luiz Miguel', 'sobrenome': 'Moraes', 'idade': 18, 'email': 'esther69@example.com', 'data_cadastro': '2024-06-27'}
# Recebido: {'nome': 'Enzo Gabriel', 'sobrenome': 'Nascimento', 'idade': 48, 'email': 'lucas-gabriel55@example.com', 'data_cadastro': '2024-04-08'}
# Recebido: {'nome': 'Luiz Fernando', 'sobrenome': 'Rodrigues', 'idade': 18, 'email': 'da-cruzantonio@example.net', 'data_cadastro': '2024-04-15'}
# Recebido: {'nome': 'Miguel', 'sobrenome': 'Barros', 'idade': 42, 'email': 'tsantos@example.net', 'data_cadastro': '2024-05-02'}
# Recebido: {'nome': 'Gabriela', 'sobrenome': 'Alves', 'idade': 70, 'email': 'ocarvalho@example.net', 'data_cadastro': '2024-08-07'}
# Recebido: {'nome': 'Manuela', 'sobrenome': 'Mendes', 'idade': 70, 'email': 'laiscaldeira@example.org', 'data_cadastro': '2024-05-11'}
# Recebido: {'nome': 'Noah', 'sobrenome': 'Pires', 'idade': 37, 'email': 'sophiaporto@example.net', 'data_cadastro': '2024-06-12'}
# Recebido: {'nome': 'Valentina', 'sobrenome': 'Sales', 'idade': 57, 'email': 'nascimentomaria-cecilia@example.net', 'data_cadastro': '2024-02-01'}
# Recebido: {'nome': 'Otávio', 'sobrenome': 'Costela', 'idade': 46, 'email': 'zcastro@example.com', 'data_cadastro': '2024-03-23'}
# ...
# Recebido: {'nome': 'Anthony', 'sobrenome': 'Cardoso', 'idade': 65, 'email': 'emanuel83@example.net', 'data_cadastro': '2024-05-13'}
# Recebido: {'nome': 'Leandro', 'sobrenome': 'Lima', 'idade': 57, 'email': 'cduarte@example.net', 'data_cadastro': '2024-03-16'}
# Recebido: {'nome': 'Vicente', 'sobrenome': 'Dias', 'idade': 33, 'email': 'luizalima@example.net', 'data_cadastro': '2024-01-31'}
# Recebido: {'nome': 'Eduarda', 'sobrenome': 'Nogueira', 'idade': 39, 'email': 'inunes@example.net', 'data_cadastro': '2024-01-18'}
# Recebido: {'nome': 'Ana Laura', 'sobrenome': 'Alves', 'idade': 48, 'email': 'sbarbosa@example.org', 'data_cadastro': '2024-05-10'}
# Recebido: {'nome': 'Emanuella', 'sobrenome': 'Correia', 'idade': 32, 'email': 'nascimentoaugusto@example.com', 'data_cadastro': '2024-05-05'}
# Recebido: {'nome': 'Fernando', 'sobrenome': 'Cardoso', 'idade': 18, 'email': 'asantos@example.org', 'data_cadastro': '2024-07-19'}
# Recebido: {'nome': 'Catarina', 'sobrenome': 'da Mota', 'idade': 35, 'email': 'valentina44@example.com', 'data_cadastro': '2024-03-11'}
# Recebido: {'nome': 'Laís', 'sobrenome': 'Rodrigues', 'idade': 42, 'email': 'cramos@example.net', 'data_cadastro': '2024-04-11'}
# Recebido: {'nome': 'João Pedro', 'sobrenome': 'Moura', 'idade': 47, 'email': 'nataliacarvalho@example.org', 'data_cadastro': '2024-03-29'}
# Recebido: {'nome': 'Alice', 'sobrenome': 'Carvalho', 'idade': 26, 'email': 'leandrosouza@example.org', 'data_cadastro': '2024-06-24'}
# Recebido: {'nome': 'Elisa', 'sobrenome': 'Barros', 'idade': 22, 'email': 'clarice34@example.com', 'data_cadastro': '2024-04-29'}
# Recebido: {'nome': 'Kamilly', 'sobrenome': 'Barbosa', 'idade': 55, 'email': 'caioda-cruz@example.com', 'data_cadastro': '2024-05-29'}
# Recebido: {'nome': 'Alexia', 'sobrenome': 'Cunha', 'idade': 48, 'email': 'esther49@example.org', 'data_cadastro': '2024-06-10'}
# Recebido: {'nome': 'Ana Lívia', 'sobrenome': 'Novaes', 'idade': 47, 'email': 'isabel88@example.com', 'data_cadastro': '2024-01-12'}
# Recebido: {'nome': 'Ana', 'sobrenome': 'da Conceição', 'idade': 53, 'email': 'lopesdavi-lucas@example.net', 'data_cadastro': '2024-07-29'}
# Recebido: {'nome': 'Maria Eduarda', 'sobrenome': 'Cavalcanti', 'idade': 28, 'email': 'tporto@example.com', 'data_cadastro': '2024-01-29'}
# Recebido: {'nome': 'Bryan', 'sobrenome': 'Martins', 'idade': 24, 'email': 'noah06@example.com', 'data_cadastro': '2024-08-05'}
# Recebido: {'nome': 'Guilherme', 'sobrenome': 'Moura', 'idade': 40, 'email': 'maria-alicearaujo@example.com', 'data_cadastro': '2024-04-11'}
# Recebido: {'nome': 'Lívia', 'sobrenome': 'Ferreira', 'idade': 57, 'email': 'luiz-henriqueda-mota@example.com', 'data_cadastro': '2024-01-04'}
# Recebido: {'nome': 'Bernardo', 'sobrenome': 'Silva', 'idade': 33, 'email': 'gabrielsantos@example.org', 'data_cadastro': '2024-06-18'}
# Recebido: {'nome': 'Davi', 'sobrenome': 'Ramos', 'idade': 23, 'email': 'freitasstephany@example.org', 'data_cadastro': '2024-05-20'}
# Recebido: {'nome': 'Carlos Eduardo', 'sobrenome': 'Gonçalves', 'idade': 27, 'email': 'yagoda-cunha@example.net', 'data_cadastro': '2024-02-26'}
# Recebido: {'nome': 'Letícia', 'sobrenome': 'Gomes', 'idade': 44, 'email': 'helenacardoso@example.org', 'data_cadastro': '2024-04-28'}
# Recebido: {'nome': 'Esther', 'sobrenome': 'Novaes', 'idade': 58, 'email': 'costelalara@example.org', 'data_cadastro': '2024-07-31'}
# Recebido: {'nome': 'Guilherme', 'sobrenome': 'Castro', 'idade': 66, 'email': 'maria-luiza71@example.com', 'data_cadastro': '2024-08-08'}
# Recebido: {'nome': 'Gustavo', 'sobrenome': 'Nogueira', 'idade': 56, 'email': 'salesnina@example.com', 'data_cadastro': '2024-07-29'}
# Recebido: {'nome': 'Camila', 'sobrenome': 'da Luz', 'idade': 60, 'email': 'noah94@example.org', 'data_cadastro': '2024-02-25'}
# Recebido: {'nome': 'Arthur', 'sobrenome': 'Pereira', 'idade': 31, 'email': 'matheusjesus@example.org', 'data_cadastro': '2024-05-21'}
# Recebido: {'nome': 'Maria', 'sobrenome': 'da Luz', 'idade': 30, 'email': 'leticiaviana@example.com', 'data_cadastro': '2024-02-10'}
# Recebido: {'nome': 'Larissa', 'sobrenome': 'Gomes', 'idade': 70, 'email': 'djesus@example.org', 'data_cadastro': '2024-05-17'}
# Recebido: {'nome': 'Ana Vitória', 'sobrenome': 'da Cruz', 'idade': 62, 'email': 'lnunes@example.org', 'data_cadastro': '2024-07-07'}
# Recebido: {'nome': 'Ana Beatriz', 'sobrenome': 'da Rosa', 'idade': 25, 'email': 'wazevedo@example.org', 'data_cadastro': '2024-05-31'}
# Recebido: {'nome': 'Nina', 'sobrenome': 'Souza', 'idade': 68, 'email': 'rda-luz@example.net', 'data_cadastro': '2024-06-18'}
# Recebido: {'nome': 'Ian', 'sobrenome': 'da Costa', 'idade': 43, 'email': 'erick61@example.com', 'data_cadastro': '2024-03-31'}
# Recebido: {'nome': 'André', 'sobrenome': 'da Rosa', 'idade': 45, 'email': 'ofogaca@example.com', 'data_cadastro': '2024-04-13'}
# Recebido: {'nome': 'Luana', 'sobrenome': 'Porto', 'idade': 31, 'email': 'ana-liviamoura@example.org', 'data_cadastro': '2024-02-19'}
# Recebido: {'nome': 'Kaique', 'sobrenome': 'Ramos', 'idade': 65, 'email': 'lda-costa@example.com', 'data_cadastro': '2024-04-20'}
# Recebido: {'nome': 'Gustavo', 'sobrenome': 'da Luz', 'idade': 43, 'email': 'spires@example.org', 'data_cadastro': '2024-07-25'}
# Recebido: {'nome': 'Camila', 'sobrenome': 'Ferreira', 'idade': 59, 'email': 'da-costabenicio@example.net', 'data_cadastro': '2024-01-29'}
# Recebido: {'nome': 'Maria Alice', 'sobrenome': 'Duarte', 'idade': 44, 'email': 'helenanogueira@example.org', 'data_cadastro': '2024-06-12'}
# Recebido: {'nome': 'Nicolas', 'sobrenome': 'Viana', 'idade': 60, 'email': 'manuela53@example.net', 'data_cadastro': '2024-05-08'}
# Recebido: {'nome': 'Sofia', 'sobrenome': 'Campos', 'idade': 59, 'email': 'yrezende@example.org', 'data_cadastro': '2024-06-23'}
# Recebido: {'nome': 'Emanuella', 'sobrenome': 'Araújo', 'idade': 44, 'email': 'naraujo@example.org', 'data_cadastro': '2024-05-01'}
# Recebido: {'nome': 'Pedro Lucas', 'sobrenome': 'Gonçalves', 'idade': 64, 'email': 'silveiravinicius@example.org', 'data_cadastro': '2024-05-14'}
# Recebido: {'nome': 'Erick', 'sobrenome': 'Sales', 'idade': 22, 'email': 'leonardomartins@example.net', 'data_cadastro': '2024-03-13'}
# Recebido: {'nome': 'Heloísa', 'sobrenome': 'Cardoso', 'idade': 48, 'email': 'eloahlima@example.com', 'data_cadastro': '2024-02-02'}
# Recebido: {'nome': 'Maitê', 'sobrenome': 'Gonçalves', 'idade': 64, 'email': 'da-rochasabrina@example.org', 'data_cadastro': '2024-01-07'}
# Recebido: {'nome': 'Ana Beatriz', 'sobrenome': 'da Mata', 'idade': 58, 'email': 'souzadiogo@example.org', 'data_cadastro': '2024-06-20'}
# Recebido: {'nome': 'Ana Vitória', 'sobrenome': 'Nunes', 'idade': 64, 'email': 'hsilva@example.org', 'data_cadastro': '2024-02-05'}
# Recebido: {'nome': 'Rodrigo', 'sobrenome': 'Jesus', 'idade': 46, 'email': 'laisdias@example.net', 'data_cadastro': '2024-06-28'}
# Recebido: {'nome': 'Vitória', 'sobrenome': 'das Neves', 'idade': 67, 'email': 'freitasolivia@example.net', 'data_cadastro': '2024-02-08'}
# Recebido: {'nome': 'Luana', 'sobrenome': 'Gonçalves', 'idade': 46, 'email': 'marianesantos@example.net', 'data_cadastro': '2024-04-10'}
# Recebido: {'nome': 'Maria Sophia', 'sobrenome': 'Freitas', 'idade': 37, 'email': 'isadorarodrigues@example.org', 'data_cadastro': '2024-07-24'}
# Recebido: {'nome': 'Nathan', 'sobrenome': 'Azevedo', 'idade': 29, 'email': 'maria-clarasales@example.com', 'data_cadastro': '2024-01-03'}
# Recebido: {'nome': 'Laura', 'sobrenome': 'Teixeira', 'idade': 61, 'email': 'pereiralorena@example.org', 'data_cadastro': '2024-07-05'}
# Recebido: {'nome': 'Carolina', 'sobrenome': 'Carvalho', 'idade': 27, 'email': 'eduarda93@example.com', 'data_cadastro': '2024-06-13'}
# Recebido: {'nome': 'Leandro', 'sobrenome': 'Santos', 'idade': 26, 'email': 'kaiquecostela@example.net', 'data_cadastro': '2024-05-21'}
# Recebido: {'nome': 'Lívia', 'sobrenome': 'Vieira', 'idade': 59, 'email': 'kmoraes@example.net', 'data_cadastro': '2024-07-23'}
# Recebido: {'nome': 'Yuri', 'sobrenome': 'Ferreira', 'idade': 50, 'email': 'costaisadora@example.org', 'data_cadastro': '2024-04-08'}
# Recebido: {'nome': 'Ana Vitória', 'sobrenome': 'Duarte', 'idade': 24, 'email': 'nataliacunha@example.org', 'data_cadastro': '2024-07-14'}
# Recebido: {'nome': 'Yasmin', 'sobrenome': 'Almeida', 'idade': 51, 'email': 'henrique29@example.net', 'data_cadastro': '2024-07-19'}
# Recebido: {'nome': 'Alana', 'sobrenome': 'Almeida', 'idade': 33, 'email': 'da-cunhabianca@example.com', 'data_cadastro': '2024-02-22'}
# Recebido: {'nome': 'Thomas', 'sobrenome': 'da Paz', 'idade': 36, 'email': 'pereiraisabella@example.org', 'data_cadastro': '2024-04-10'}
# Recebido: {'nome': 'Emilly', 'sobrenome': 'Ramos', 'idade': 26, 'email': 'vitoria02@example.com', 'data_cadastro': '2024-03-09'}
# Recebido: {'nome': 'Elisa', 'sobrenome': 'Pereira', 'idade': 63, 'email': 'olivia84@example.org', 'data_cadastro': '2024-07-15'}
# Recebido: {'nome': 'Yasmin', 'sobrenome': 'Mendes', 'idade': 32, 'email': 'diascaua@example.org', 'data_cadastro': '2024-01-21'}
# Recebido: {'nome': 'Ana Beatriz', 'sobrenome': 'da Cunha', 'idade': 63, 'email': 'rgoncalves@example.org', 'data_cadastro': '2024-02-02'}
# Recebido: {'nome': 'Luiz Felipe', 'sobrenome': 'Sales', 'idade': 58, 'email': 'antonio86@example.com', 'data_cadastro': '2024-06-09'}
# Recebido: {'nome': 'Rafael', 'sobrenome': 'Fernandes', 'idade': 43, 'email': 'lais09@example.net', 'data_cadastro': '2024-05-14'}
# Recebido: {'nome': 'Laura', 'sobrenome': 'Moraes', 'idade': 59, 'email': 'yuriteixeira@example.net', 'data_cadastro': '2024-04-18'}
# Recebido: {'nome': 'Rafael', 'sobrenome': 'das Neves', 'idade': 59, 'email': 'joao-guilhermenascimento@example.net', 'data_cadastro': '2024-06-27'}
# Recebido: {'nome': 'Raquel', 'sobrenome': 'Ferreira', 'idade': 38, 'email': 'carlos-eduardocardoso@example.com', 'data_cadastro': '2024-05-28'}
# Recebido: {'nome': 'Gabriel', 'sobrenome': 'da Costa', 'idade': 25, 'email': 'joao-lucasda-mata@example.net', 'data_cadastro': '2024-01-14'}
# Recebido: {'nome': 'Ana Beatriz', 'sobrenome': 'Porto', 'idade': 21, 'email': 'mda-costa@example.org', 'data_cadastro': '2024-05-14'}
# Recebido: {'nome': 'Enzo Gabriel', 'sobrenome': 'Vieira', 'idade': 21, 'email': 'valentinasilva@example.net', 'data_cadastro': '2024-06-11'}
# Recebido: {'nome': 'Camila', 'sobrenome': 'Moraes', 'idade': 22, 'email': 'brenda88@example.com', 'data_cadastro': '2024-06-18'}
# Recebido: {'nome': 'Thales', 'sobrenome': 'Araújo', 'idade': 56, 'email': 'cardosogustavo@example.net', 'data_cadastro': '2024-02-17'}
# Recebido: {'nome': 'Fernando', 'sobrenome': 'Correia', 'idade': 32, 'email': 'galmeida@example.net', 'data_cadastro': '2024-05-10'}
# Recebido: {'nome': 'Elisa', 'sobrenome': 'Viana', 'idade': 70, 'email': 'pietro16@example.net', 'data_cadastro': '2024-05-17'}
# Recebido: {'nome': 'Emilly', 'sobrenome': 'Moura', 'idade': 41, 'email': 'heloisa03@example.com', 'data_cadastro': '2024-03-19'}
# Recebido: {'nome': 'Ana', 'sobrenome': 'Castro', 'idade': 59, 'email': 'pauloda-rocha@example.org', 'data_cadastro': '2024-05-17'}
# Recebido: {'nome': 'Joaquim', 'sobrenome': 'Costa', 'idade': 67, 'email': 'helena73@example.com', 'data_cadastro': '2024-01-05'}
# Recebido: {'nome': 'Amanda', 'sobrenome': 'Cardoso', 'idade': 31, 'email': 'barrosantonio@example.org', 'data_cadastro': '2024-07-01'}
# Recebido: {'nome': 'Henrique', 'sobrenome': 'Porto', 'idade': 38, 'email': 'fernandesthales@example.com', 'data_cadastro': '2024-01-23'}
# Recebido: {'nome': 'Noah', 'sobrenome': 'Aragão', 'idade': 70, 'email': 'bernardoda-cruz@example.com', 'data_cadastro': '2024-08-01'}
# Recebido: {'nome': 'Eduarda', 'sobrenome': 'da Conceição', 'idade': 67, 'email': 'ana-beatrizgoncalves@example.net', 'data_cadastro': '2024-05-09'}
# Recebido: {'nome': 'Thales', 'sobrenome': 'Duarte', 'idade': 43, 'email': 'laisazevedo@example.org', 'data_cadastro': '2024-02-06'}
# Recebido: {'nome': 'Marcos Vinicius', 'sobrenome': 'Sales', 'idade': 41, 'email': 'maria-luizamonteiro@example.net', 'data_cadastro': '2024-05-07'}
# Recebido: {'nome': 'Ana Luiza', 'sobrenome': 'Almeida', 'idade': 59, 'email': 'alvesesther@example.net', 'data_cadastro': '2024-02-02'}
# Recebido: {'nome': 'Marcela', 'sobrenome': 'das Neves', 'idade': 19, 'email': 'emelo@example.com', 'data_cadastro': '2024-02-03'}
# Recebido: {'nome': 'Yuri', 'sobrenome': 'Monteiro', 'idade': 55, 'email': 'yfernandes@example.org', 'data_cadastro': '2024-03-22'}
# Recebido: {'nome': 'Esther', 'sobrenome': 'da Mota', 'idade': 62, 'email': 'thales95@example.com', 'data_cadastro': '2024-06-27'}
# Recebido: {'nome': 'Camila', 'sobrenome': 'Costela', 'idade': 58, 'email': 'yfogaca@example.com', 'data_cadastro': '2024-04-29'}
# Recebido: {'nome': 'Valentina', 'sobrenome': 'Moura', 'idade': 51, 'email': 'barbosaemanuella@example.net', 'data_cadastro': '2024-02-10'}
# Recebido: {'nome': 'Sofia', 'sobrenome': 'Silva', 'idade': 66, 'email': 'dgomes@example.com', 'data_cadastro': '2024-06-14'}
# Recebido: {'nome': 'Augusto', 'sobrenome': 'Farias', 'idade': 35, 'email': 'castrobreno@example.com', 'data_cadastro': '2024-06-08'}
# Recebido: {'nome': 'Fernando', 'sobrenome': 'Nogueira', 'idade': 46, 'email': 'nicoleduarte@example.net', 'data_cadastro': '2024-04-07'}
# Recebido: {'nome': 'Emanuella', 'sobrenome': 'Lima', 'idade': 37, 'email': 'dfernandes@example.org', 'data_cadastro': '2024-06-28'}
# Recebido: {'nome': 'Otávio', 'sobrenome': 'da Costa', 'idade': 67, 'email': 'nascimentolivia@example.net', 'data_cadastro': '2024-07-05'}
# Recebido: {'nome': 'Theo', 'sobrenome': 'Azevedo', 'idade': 62, 'email': 'alexandre42@example.net', 'data_cadastro': '2024-02-18'}
# Recebido: {'nome': 'Arthur', 'sobrenome': 'Alves', 'idade': 59, 'email': 'salesjuan@example.net', 'data_cadastro': '2024-06-02'}
# Recebido: {'nome': 'João Guilherme', 'sobrenome': 'Araújo', 'idade': 40, 'email': 'grocha@example.net', 'data_cadastro': '2024-05-05'}
# Recebido: {'nome': 'Vicente', 'sobrenome': 'Dias', 'idade': 69, 'email': 'milenada-rocha@example.org', 'data_cadastro': '2024-04-03'}
# Recebido: {'nome': 'Kaique', 'sobrenome': 'Costa', 'idade': 64, 'email': 'mduarte@example.org', 'data_cadastro': '2024-04-15'}
# Recebido: {'nome': 'Marcos Vinicius', 'sobrenome': 'da Conceição', 'idade': 18, 'email': 'helena64@example.net', 'data_cadastro': '2024-01-06'}
# Recebido: {'nome': 'Mirella', 'sobrenome': 'Ramos', 'idade': 50, 'email': 'ana-julia45@example.org', 'data_cadastro': '2024-04-18'}
# Recebido: {'nome': 'Noah', 'sobrenome': 'Duarte', 'idade': 46, 'email': 'dnogueira@example.org', 'data_cadastro': '2024-04-24'}
# Recebido: {'nome': 'Marcos Vinicius', 'sobrenome': 'Duarte', 'idade': 20, 'email': 'laura22@example.net', 'data_cadastro': '2024-05-23'}
# Recebido: {'nome': 'Maria Vitória', 'sobrenome': 'Moraes', 'idade': 49, 'email': 'qalmeida@example.org', 'data_cadastro': '2024-01-13'}
# Recebido: {'nome': 'Cauê', 'sobrenome': 'Vieira', 'idade': 35, 'email': 'freitasrebeca@example.org', 'data_cadastro': '2024-07-11'}
# name 'bucket_name' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 106
#     104     message_list.append(json.loads(message.value))
# --> 106 insert_bronze(message.value)
#     107 topic_controll.insert_offset(message.offset)
#
# Cell In[16], line 74, in insert_bronze(data)
#      67     client.put_object(
#      68         BUCKET_NAME,
#      69         object_name,
#    (...)
#      72         content_type="application/json"
#      73     )
# ---> 74     print(f'JSON {object_name} enviado para o bucket {bucket_name} com sucesso!')
#      75 except S3Error as e:
#
# NameError: name 'bucket_name' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[16], line 111
#     109 except Exception as e:
#     110     print(e)
# --> 111     raise Exception(e)
#     112     #create_log(status = 'failure', message = e)
#
# Exception: name 'bucket_name' is not defined

# %%
from datetime import datetime

# %%
# !pip install clickhouse_driver
# Out:
# Collecting clickhouse_driver
#   Downloading clickhouse_driver-0.2.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.11/site-packages (from clickhouse_driver) (2023.3.post1)
# Collecting tzlocal (from clickhouse_driver)
#   Downloading tzlocal-5.2-py3-none-any.whl.metadata (7.8 kB)
# Downloading clickhouse_driver-0.2.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 3.0 MB/s eta 0:00:00a 0:00:01
# Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Installing collected packages: tzlocal, clickhouse_driver
# Successfully installed clickhouse_driver-0.2.8 tzlocal-5.2

# %%
from datetime import datetime
from kafka import KafkaConsumer, TopicPartition

from minio import Minio
from minio.error import S3Error
import json
from io import BytesIO
import os

from kafka import KafkaConsumer
TOPIC = 'clients_kafka'
BOOTSTRAP = 'kafka:9092'
ACCESS_KEY = 'minioadmin'
SECRET_KEY = 'minioadmin'


file_path = 'KAFKA/topic=clients_kafka/year=2024/month=8/day=11/2024-08-11 01:34:25.json'
from minio import Minio
BUCKET_NAME = 'bronze-layer'
client = Minio("minio:9000",
    access_key=ACCESS_KEY,
    secret_key=SECRET_KEY,
    secure = False
)

data = client.get_object(BUCKET_NAME, file_path)
content = json.load(data)
print(f"Conteúdo do arquivo {file_path}:")
print(content)
# Out:
# Conteúdo do arquivo KAFKA/topic=clients_kafka/year=2024/month=8/day=11/2024-08-11 01:34:25.json:
# [{'nome': 'Daniel', 'sobrenome': 'Viana', 'idade': 52, 'email': 'ramoscecilia@example.com', 'data_cadastro': '2024-02-04'}, {'nome': 'Luiz Otávio', 'sobrenome': 'Nunes', 'idade': 34, 'email': 'theo80@example.net', 'data_cadastro': '2024-01-20'}, {'nome': 'Murilo', 'sobrenome': 'Barbosa', 'idade': 56, 'email': 'davicavalcanti@example.com', 'data_cadastro': '2024-04-30'}, {'nome': 'Vitor Hugo', 'sobrenome': 'Lopes', 'idade': 38, 'email': 'isabel02@example.net', 'data_cadastro': '2024-03-27'}, {'nome': 'Luiz Henrique', 'sobrenome': 'Fernandes', 'idade': 28, 'email': 'brenopeixoto@example.com', 'data_cadastro': '2024-04-08'}, {'nome': 'Rebeca', 'sobrenome': 'Novaes', 'idade': 32, 'email': 'enzo-gabriel24@example.net', 'data_cadastro': '2024-04-21'}, {'nome': 'Luna', 'sobrenome': 'Pereira', 'idade': 21, 'email': 'marcelosilva@example.net', 'data_cadastro': '2024-06-01'}, {'nome': 'Ana Clara', 'sobrenome': 'da Mata', 'idade': 51, 'email': 'isaac44@example.org', 'data_cadastro': '2024-07-26'}, {'nome': 'Benjamin', 'sobrenome': 'Carvalho', 'idade': 27, 'email': 'luanasilva@example.net', 'data_cadastro': '2024-07-05'}, {'nome': 'Lucca', 'sobrenome': 'das Neves', 'idade': 18, 'email': 'renan56@example.org', 'data_cadastro': '2024-03-07'}, {'nome': 'Benjamin', 'sobrenome': 'Costa', 'idade': 44, 'email': 'correiaclara@example.net', 'data_cadastro': '2024-08-10'}, {'nome': 'Ana Sophia', 'sobrenome': 'Rocha', 'idade': 27, 'email': 'thiago71@example.com', 'data_cadastro': '2024-07-16'}, {'nome': 'Calebe', 'sobrenome': 'Cunha', 'idade': 24, 'email': 'pirescaio@example.net', 'data_cadastro': '2024-03-17'}, {'nome': 'Emilly', 'sobrenome': 'Barbosa', 'idade': 70, 'email': 'stella90@example.com', 'data_cadastro': '2024-04-21'}, {'nome': 'Kevin', 'sobrenome': 'Farias', 'idade': 50, 'email': 'luiza63@example.org', 'data_cadastro': '2024-02-28'}, {'nome': 'Noah', 'sobrenome': 'Melo', 'idade': 55, 'email': 'zoliveira@example.com', 'data_cadastro': '2024-03-23'}, {'nome': 'Julia', 'sobrenome': 'Oliveira', 'idade': 37, 'email': 'martinsmaria-sophia@example.net', 'data_cadastro': '2024-07-31'}, {'nome': 'Gabrielly', 'sobrenome': 'Moura', 'idade': 49, 'email': 'hferreira@example.net', 'data_cadastro': '2024-05-30'}, {'nome': 'Anthony', 'sobrenome': 'Moreira', 'idade': 35, 'email': 'barrosmaria-eduarda@example.com', 'data_cadastro': '2024-06-08'}, {'nome': 'Natália', 'sobrenome': 'Ferreira', 'idade': 66, 'email': 'francisco46@example.com', 'data_cadastro': '2024-02-27'}, {'nome': 'João', 'sobrenome': 'da Cruz', 'idade': 51, 'email': 'benjaminlopes@example.net', 'data_cadastro': '2024-08-06'}, {'nome': 'Raul', 'sobrenome': 'Gonçalves', 'idade': 44, 'email': 'bmendes@example.net', 'data_cadastro': '2024-07-03'}, {'nome': 'Luna', 'sobrenome': 'Araújo', 'idade': 33, 'email': 'tpereira@example.org', 'data_cadastro': '2024-05-15'}, {'nome': 'Ana Beatriz', 'sobrenome': 'Nunes', 'idade': 58, 'email': 'vda-luz@example.com', 'data_cadastro': '2024-02-11'}, {'nome': 'Heloísa', 'sobrenome': 'Duarte', 'idade': 58, 'email': 'mpereira@example.com', 'data_cadastro': '2024-01-01'}, {'nome': 'Ana Julia', 'sobrenome': 'Correia', 'idade': 52, 'email': 'joana70@example.org', 'data_cadastro': '2024-02-19'}, {'nome': 'Pietra', 'sobrenome': 'Azevedo', 'idade': 40, 'email': 'ribeirojoao-vitor@example.net', 'data_cadastro': '2024-06-15'}, {'nome': 'Catarina', 'sobrenome': 'Rezende', 'idade': 53, 'email': 'ianfreitas@example.net', 'data_cadastro': '2024-02-09'}, {'nome': 'Olivia', 'sobrenome': 'da Rosa', 'idade': 47, 'email': 'cardosoana-beatriz@example.com', 'data_cadastro': '2024-02-27'}, {'nome': 'Francisco', 'sobrenome': 'Mendes', 'idade': 18, 'email': 'vianavitoria@example.org', 'data_cadastro': '2024-06-16'}, {'nome': 'Bianca', 'sobrenome': 'da Cunha', 'idade': 19, 'email': 'tcaldeira@example.com', 'data_cadastro': '2024-02-21'}, {'nome': 'Emanuel', 'sobrenome': 'Dias', 'idade': 50, 'email': 'gustavo63@example.com', 'data_cadastro': '2024-01-09'}, {'nome': 'Ana', 'sobrenome': ...

# %%
# !pip install polars
# Out:
# Requirement already satisfied: polars in /opt/conda/lib/python3.11/site-packages (1.4.1)

# %%
import polars as pl
from datetime import date
content
df_insert = pl.DataFrame(content)
df_insert = df_insert.with_columns(
    pl.col("data_cadastro").str.strptime(pl.Date, format="%Y-%m-%d").alias("data_cadastro")
).with_columns(pl.lit(date(2023, 12, 31)).alias("effective_date"))\
.with_columns(pl.lit(date(2999, 12, 31)).alias("end_date"))\
.with_columns(pl.lit(1).alias("is_current"))
# Exibir o DataFrame
print(df_insert)
# Out:
# shape: (245, 8)
# ┌─────────────┬───────────┬───────┬────────────┬────────────┬────────────┬────────────┬────────────┐
# │ nome        ┆ sobrenome ┆ idade ┆ email      ┆ data_cadas ┆ effective_ ┆ end_date   ┆ is_current │
# │ ---         ┆ ---       ┆ ---   ┆ ---        ┆ tro        ┆ date       ┆ ---        ┆ ---        │
# │ str         ┆ str       ┆ i64   ┆ str        ┆ ---        ┆ ---        ┆ date       ┆ i32        │
# │             ┆           ┆       ┆            ┆ date       ┆ date       ┆            ┆            │
# ╞═════════════╪═══════════╪═══════╪════════════╪════════════╪════════════╪════════════╪════════════╡
# │ Daniel      ┆ Viana     ┆ 52    ┆ ramoscecil ┆ 2024-02-04 ┆ 2023-12-31 ┆ 2999-12-31 ┆ 1          │
# │             ┆           ┆       ┆ ia@example ┆            ┆            ┆            ┆            │
# │             ┆           ┆       ┆ .com       ┆            ┆            ┆            ┆            │
# │ Luiz Otávio ┆ Nunes     ┆ 34    ┆ theo80@exa ┆ 2024-01-20 ┆ 2023-12-31 ┆ 2999-12-31 ┆ 1          │
# │             ┆           ┆       ┆ mple.net   ┆            ┆            ┆            ┆            │
# │ Murilo      ┆ Barbosa   ┆ 56    ┆ davicavalc ┆ 2024-04-30 ┆ 2023-12-31 ┆ 2999-12-31 ┆ 1          │
# │             ┆           ┆       ┆ anti@examp ┆            ┆            ┆            ┆            │
# │             ┆           ┆       ┆ le.com     ┆            ┆            ┆            ┆            │
# │ Vitor Hugo  ┆ Lopes     ┆ 38    ┆ isabel02@e ┆ 2024-03-27 ┆ 2023-12-31 ┆ 2999-12-31 ┆ 1          │
# │             ┆           ┆       ┆ xample.net ┆            ┆            ┆            ┆            │
# │ Luiz        ┆ Fernandes ┆ 28    ┆ brenopeixo ┆ 2024-04-08 ┆ 2023-12-31 ┆ 2999-12-31 ┆ 1          │
# │ Henrique    ┆           ┆       ┆ to@example ┆            ┆            ┆            ┆            │
# │             ┆           ┆       ┆ .com       ┆            ┆            ┆            ┆            │
# │ …           ┆ …         ┆ …     ┆ …          ┆ …          ┆ …          ┆ …          ┆ …          │
# │ Vitória     ┆ Araújo    ┆ 18    ┆ maria-edua ┆ 2024-06-09 ┆ 2023-12-31 ┆ 2999-12-31 ┆ 1          │
# │             ┆           ┆       ┆ rda34@exam ┆            ┆            ┆            ┆            │
# │             ┆           ┆       ┆ ple.org    ┆            ┆            ┆            ┆            │
# │ Milena      ┆ Rezende   ┆ 29    ┆ juliada-pa ┆ 2024-03-14 ┆ 2023-12-31 ┆ 2999-12-31 ┆ 1          │
# │             ┆           ┆       ┆ z@example. ┆            ┆            ┆            ┆            │
# │             ┆           ┆       ┆ org        ┆            ┆            ┆            ┆            │
# │ Ian         ┆ Cunha     ┆ 46    ┆ qmoraes@ex ┆ 2024-02-28 ┆ 2023-12-31 ┆ 2999-12-31 ┆ 1          │
# │             ┆           ┆       ┆ ample.org  ┆            ┆            ┆            ┆            │
# │ Diogo       ┆ Caldeira  ┆ 47    ┆ teixeirama ┆ 2024-07-05 ┆ 2023-12-31 ┆ 2999-12-31 ┆ 1          │
# │             ┆           ┆       ┆ ria-cecili ┆            ┆            ┆            ┆            │
# │             ┆           ┆       ┆ a@example. ┆            ┆            ┆            ┆            │
# │             ┆           ┆       ┆ …          ┆            ┆            ┆            ┆            │
# │ Larissa     ┆ Pires     ┆ 19    ┆ alvesenric ┆ 2024-01-12 ┆ 2023-12-31 ┆ 2999-12-31 ┆ 1          │
# │             ┆           ┆       ┆ o@example. ┆            ┆            ┆            ┆            │
# │             ┆           ┆       ┆ com        ┆            ┆            ┆            ┆            │
# └─────────────┴───────────┴───────┴────────────┴────────────┴────────────┴────────────┴────────────┘

# %%
from clickhouse_driver import Client

# Conexão ao servidor ClickHouse
client_ch = Client(
    host='clickhouse',       # Endereço do servidor ClickHouse
    port=9000,              # Porta padrão para conexões TCP
    user='default',         # Usuário (padrão é 'default')
    password='',            # Senha (por padrão, vazio)
    database='default',     # Nome do banco de dados (por padrão, 'default')
)

# %%
client_ch.execute('''
CREATE OR REPLACE TABLE dim_clients (
    nome String,
    sobrenome String,
    idade Int32,
    email String,
    data_cadastro Date,
    effective_date Date,
    end_date Date,
    is_current UInt8
) ENGINE = MergeTree()
ORDER BY (nome, sobrenome, effective_date)
''')
# Out:
# []

# %%
# Converta o DataFrame para um formato que pode ser enviado ao ClickHouse
data = df_insert.to_dicts()

# Inserir os dados no ClickHouse
client_ch.execute(
    'INSERT INTO usuarios (nome, sobrenome, idade, email, data_cadastro, effective_date, end_date, is_current) VALUES',
    [(row['nome'], row['sobrenome'], row['idade'], row['email'], row['data_cadastro'], row['effective_date'], row['end_date'], row['is_current']) for row in data]
)
# Out:
# 245

# %%
# Definir os nomes das colunas conforme a tabela do ClickHouse
result = client_ch.execute(f"SELECT * FROM usuarios where is_current = 1")
columns = ['nome', 'sobrenome', 'idade', 'email', 'data_cadastro',  'effective_date', 'end_date', 'is_current']

# Criar o DataFrame Polars a partir dos resultados
df_table = pl.DataFrame(result, schema=columns)
# Out:
# /tmp/ipykernel_423/3037111310.py:5: DataOrientationWarning: Row orientation inferred during DataFrame construction. Explicitly specify the orientation by passing `orient="row"` to silence this warning.
#   df_table = pl.DataFrame(result, schema=columns)

# %%
import polars as pl
from datetime import date

for i in range(5):
    content[i]['data_cadastro'] = '2025-02-04'
    if i == 3:
        content[i]['data_cadastro'] = '2023-02-04'
        
df_insert = pl.DataFrame(content[0:5])

df_insert = df_insert.with_columns(
    pl.col("data_cadastro").str.strptime(pl.Date, format="%Y-%m-%d").alias("data_cadastro")
).with_columns(pl.lit(date.today()).alias("effective_date")).with_columns(pl.lit(date(2999, 12, 31)).alias("end_date")).with_columns(pl.lit(1).alias("is_current"))
# Exibir o DataFrame
print(df_insert)
# Out:
# shape: (5, 8)
# ┌─────────────┬───────────┬───────┬────────────┬────────────┬────────────┬────────────┬────────────┐
# │ nome        ┆ sobrenome ┆ idade ┆ email      ┆ data_cadas ┆ effective_ ┆ end_date   ┆ is_current │
# │ ---         ┆ ---       ┆ ---   ┆ ---        ┆ tro        ┆ date       ┆ ---        ┆ ---        │
# │ str         ┆ str       ┆ i64   ┆ str        ┆ ---        ┆ ---        ┆ date       ┆ i32        │
# │             ┆           ┆       ┆            ┆ date       ┆ date       ┆            ┆            │
# ╞═════════════╪═══════════╪═══════╪════════════╪════════════╪════════════╪════════════╪════════════╡
# │ Daniel      ┆ Viana     ┆ 52    ┆ ramoscecil ┆ 2025-02-04 ┆ 2024-08-11 ┆ 2999-12-31 ┆ 1          │
# │             ┆           ┆       ┆ ia@example ┆            ┆            ┆            ┆            │
# │             ┆           ┆       ┆ .com       ┆            ┆            ┆            ┆            │
# │ Luiz Otávio ┆ Nunes     ┆ 34    ┆ theo80@exa ┆ 2025-02-04 ┆ 2024-08-11 ┆ 2999-12-31 ┆ 1          │
# │             ┆           ┆       ┆ mple.net   ┆            ┆            ┆            ┆            │
# │ Murilo      ┆ Barbosa   ┆ 56    ┆ davicavalc ┆ 2025-02-04 ┆ 2024-08-11 ┆ 2999-12-31 ┆ 1          │
# │             ┆           ┆       ┆ anti@examp ┆            ┆            ┆            ┆            │
# │             ┆           ┆       ┆ le.com     ┆            ┆            ┆            ┆            │
# │ Vitor Hugo  ┆ Lopes     ┆ 38    ┆ isabel02@e ┆ 2023-02-04 ┆ 2024-08-11 ┆ 2999-12-31 ┆ 1          │
# │             ┆           ┆       ┆ xample.net ┆            ┆            ┆            ┆            │
# │ Luiz        ┆ Fernandes ┆ 28    ┆ brenopeixo ┆ 2025-02-04 ┆ 2024-08-11 ┆ 2999-12-31 ┆ 1          │
# │ Henrique    ┆           ┆       ┆ to@example ┆            ┆            ┆            ┆            │
# │             ┆           ┆       ┆ .com       ┆            ┆            ┆            ┆            │
# └─────────────┴───────────┴───────┴────────────┴────────────┴────────────┴────────────┴────────────┘

# %%
"""
Nesse caso, eu utilizo o email como chave primaria (poderia ser id, cpf, etc...), faço o join com a tabela para ver os emails repetidos
que estão sendo inseridos e filtro pela data de cadastro para garantir que os dados repetidos que estamos inserindo
sao o cadastro mais atualizado.

"""
df_joined = df_insert.join(
    df_table, 
    on="email", 
    how="inner"
).filter(
    pl.col("data_cadastro").cast(pl.Date) > pl.col("data_cadastro_right").cast(pl.Date)
)

# Selecionar as colunas e renomear conforme necessário
df_update_inactive = df_joined.select([
    pl.col("nome"),
    pl.col("sobrenome"),
    pl.col("idade"),
    pl.col("email"),
    pl.col("data_cadastro_right").alias("data_cadastro"),
    pl.col("effective_date_right").alias("effective_date"),
    pl.col("effective_date").alias("end_date"),
    pl.lit(0).alias("is_current")
])

# %%
df_update_inactive
# Out:
# shape: (4, 8)
# ┌─────────────┬───────────┬───────┬────────────┬────────────┬────────────┬────────────┬────────────┐
# │ nome        ┆ sobrenome ┆ idade ┆ email      ┆ data_cadas ┆ effective_ ┆ end_date   ┆ is_current │
# │ ---         ┆ ---       ┆ ---   ┆ ---        ┆ tro        ┆ date       ┆ ---        ┆ ---        │
# │ str         ┆ str       ┆ i64   ┆ str        ┆ ---        ┆ ---        ┆ date       ┆ i32        │
# │             ┆           ┆       ┆            ┆ date       ┆ date       ┆            ┆            │
# ╞═════════════╪═══════════╪═══════╪════════════╪════════════╪════════════╪════════════╪════════════╡
# │ Daniel      ┆ Viana     ┆ 52    ┆ ramoscecil ┆ 2024-02-04 ┆ 2023-12-31 ┆ 2024-08-11 ┆ 0          │
# │             ┆           ┆       ┆ ia@example ┆            ┆            ┆            ┆            │
# │             ┆           ┆       ┆ .com       ┆            ┆            ┆            ┆            │
# │ Luiz        ┆ Fernandes ┆ 28    ┆ brenopeixo ┆ 2024-04-08 ┆ 2023-12-31 ┆ 2024-08-11 ┆ 0          │
# │ Henrique    ┆           ┆       ┆ to@example ┆            ┆            ┆            ┆            │
# │             ┆           ┆       ┆ .com       ┆            ┆            ┆            ┆            │
# │ Luiz Otávio ┆ Nunes     ┆ 34    ┆ theo80@exa ┆ 2024-01-20 ┆ 2023-12-31 ┆ 2024-08-11 ┆ 0          │
# │             ┆           ┆       ┆ mple.net   ┆            ┆            ┆            ┆            │
# │ Murilo      ┆ Barbosa   ┆ 56    ┆ davicavalc ┆ 2024-04-30 ┆ 2023-12-31 ┆ 2024-08-11 ┆ 0          │
# │             ┆           ┆       ┆ anti@examp ┆            ┆            ┆            ┆            │
# │             ┆           ┆       ┆ le.com     ┆            ┆            ┆            ┆            │
# └─────────────┴───────────┴───────┴────────────┴────────────┴────────────┴────────────┴────────────┘

# %%
# Converta o DataFrame para um formato que pode ser enviado ao ClickHouse
for row in df_update_inactive.to_dicts():
    client_ch.execute(
        """
        ALTER TABLE usuarios
        UPDATE end_date = %(end_date)s,
               is_current = %(is_current)s
        WHERE email = %(email)s
        """,
        {'end_date': row['end_date'], 'is_current': row['is_current'], 'email': row['email']}
    )

# %%
 client_ch.execute("SELECT * from usuarios where is_current = 1")
# Out:
# [('Alexandre',
#   'Rezende',
#   21,
#   'goncalvesluiz-otavio@example.net',
#   datetime.date(2024, 3, 28),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Alexia',
#   'Gonçalves',
#   45,
#   'ribeiromaria-clara@example.com',
#   datetime.date(2024, 3, 12),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Alícia',
#   'da Rocha',
#   24,
#   'pedro-henrique88@example.org',
#   datetime.date(2024, 1, 19),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Amanda',
#   'Moraes',
#   44,
#   'tda-conceicao@example.net',
#   datetime.date(2024, 2, 14),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Ana',
#   'da Cunha',
#   36,
#   'qrodrigues@example.org',
#   datetime.date(2024, 1, 22),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Ana',
#   'da Luz',
#   26,
#   'cecilia51@example.org',
#   datetime.date(2024, 4, 8),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Ana Beatriz',
#   'Nunes',
#   58,
#   'vda-luz@example.com',
#   datetime.date(2024, 2, 11),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Ana Beatriz',
#   'Ramos',
#   56,
#   'ada-cunha@example.net',
#   datetime.date(2024, 2, 18),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Ana Clara',
#   'da Luz',
#   60,
#   'vitor-hugoviana@example.net',
#   datetime.date(2024, 6, 11),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Ana Clara',
#   'da Mata',
#   51,
#   'isaac44@example.org',
#   datetime.date(2024, 7, 26),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Ana Julia',
#   'Correia',
#   52,
#   'joana70@example.org',
#   datetime.date(2024, 2, 19),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Ana Julia',
#   'Duarte',
#   59,
#   'ada-luz@example.org',
#   datetime.date(2024, 2, 22),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Ana Júlia',
#   'Barbosa',
#   51,
#   'monteirobernardo@example.com',
#   datetime.date(2024, 3, 30),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Ana Júlia',
#   'Costela',
#   66,
#   'joao-lucas24@example.org',
#   datetime.date(2024, 4, 1),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Ana Júlia',
#   'Mendes',
#   35,
#   'caroline31@example.net',
#   datetime.date(2024, 3, 3),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Ana Júlia',
#   'Ramos',
#   52,
#   'vitoriasales@example.org',
#   datetime.date(2024, 4, 30),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Ana Laura',
#   'Gomes',
#   60,
#   'mirella34@example.com',
#   datetime.date(2024, 3, 24),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Ana Lívia',
#   'Barbosa',
#   63,
#   'alice20@example.net',
#   datetime.date(2024, 7, 27),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Ana Lívia',
#   'Gonçalves',
#   38,
#   'salesmelissa@example.org',
#   datetime.date(2024, 3, 4),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Ana Sophia',
#   'Cunha',
#   56,
#   'osilva@example.net',
#   datetime.date(2024, 3, 5),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Ana Sophia',
#   'Monteiro',
#   26,
#   'yramos@example.com',
#   datetime.date(2024, 7, 15),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Ana Sophia',
#   'Rocha',
#   27,
#   'thiago71@example.com',
#   datetime.date(2024, 7, 16),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('André',
#   'Rezende',
#   43,
#   'cardosocaue@example.org',
#   datetime.date(2024, 6, 15),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Anthony',
#   'Cunha',
#   23,
#   'nogueirarafael@example.com',
#   datetime.date(2024, 2, 6),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Anthony',
#   'Moreira',
#   35,
#   'barrosmaria-eduarda@example.com',
#   datetime.date(2024, 6, 8),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Benjamin',
#   'Carvalho',
#   27,
#   'luanasilva@example.net',
#   datetime.date(2024, 7, 5),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Benjamin',
#   'Costa',
#   44,
#   'correiaclara@example.net',
#   datetime.date(2024, 8, 10),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Benício',
#   'Martins',
#   49,
#   'correiaanthony@example.net',
#   datetime.date(2024, 6, 1),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Bianca',
#   'Rodrigues',
#   20,
#   'carlos-eduardo88@example.com',
#   datetime.date(2024, 3, 23),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Bianca',
#   'da Cunha',
#   19,
#   'tcaldeira@example.com',
#   datetime.date(2024, 2, 21),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Breno',
#   'Azevedo',
#   69,
#   'bianca70@example.com',
#   datetime.date(2024, 5, 9),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Breno',
#   'Jesus',
#   41,
#   'isabella90@example.org',
#   datetime.date(2024, 6, 9),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Breno',
#   'Ribeiro',
#   42,
#   'ana-carolina43@example.com',
#   datetime.date(2024, 7, 13),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Bruna',
#   'Campos',
#   66,
#   'da-cunhacaio@example.org',
#   datetime.date(2024, 3, 1),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Bruno',
#   'Teixeira',
#   67,
#   'mariana47@example.com',
#   datetime.date(2024, 2, 21),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Bruno',
#   'Viana',
#   40,
#   'cardosoalexia@example.org',
#   datetime.date(2024, 5, 18),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Bruno',
#   'da Rocha',
#   29,
#   'clarice83@example.net',
#   datetime.date(2024, 4, 14),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Bryan',
#   'Moreira',
#   49,
#   'leandromartins@example.com',
#   datetime.date(2024, 1, 13),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Bárbara',
#   'Duarte',
#   53,
#   'nascimentoraul@example.org',
#   datetime.date(2024, 4, 1),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Bárbara',
#   'Fogaça',
#   22,
#   'ana-beatriz74@example.org',
#   datetime.date(2024, 1, 9),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Bárbara',
#   'Vieira',
#   26,
#   'enzofarias@example.net',
#   datetime.date(2024, 4, 22),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Caio',
#   'Araújo',
#   36,
#   'pedronogueira@example.net',
#   datetime.date(2024, 7, 14),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Caio',
#   'Pereira',
#   56,
#   'vrocha@example.com',
#   datetime.date(2024, 6, 15),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Calebe',
#   'Azevedo',
#   47,
#   'laragao@example.com',
#   datetime.date(2024, 7, 4),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Calebe',
#   'Cunha',
#   24,
#   'pirescaio@example.net',
#   datetime.date(2024, 3, 17),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Calebe',
#   'Ribeiro',
#   27,
#   'pcardoso@example.net',
#   datetime.date(2024, 6, 21),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Carolina',
#   'Monteiro',
#   53,
#   'nicole84@example.net',
#   datetime.date(2024, 7, 23),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Carolina',
#   'Silveira',
#   44,
#   'fmelo@example.net',
#   datetime.date(2024, 3, 25),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Catarina',
#   'Rezende',
#   53,
#   'ianfreitas@example.net',
#   datetime.date(2024, 2, 9),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Catarina',
#   'da Conceição',
#   32,
#   'gfogaca@example.org',
#   datetime.date(2024, 2, 13),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Cauã',
#   'Viana',
#   31,
#   'yda-costa@example.com',
#   datetime.date(2024, 1, 18),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Cauê',
#   'Silva',
#   68,
#   'ecarvalho@example.com',
#   datetime.date(2024, 4, 18),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Cauê',
#   'das Neves',
#   63,
#   'alananascimento@example.com',
#   datetime.date(2024, 3, 13),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Cecília',
#   'das Neves',
#   32,
#   'davi-luccanovaes@example.org',
#   datetime.date(2024, 5, 24),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Clarice',
#   'Dias',
#   69,
#   'melissa87@example.com',
#   datetime.date(2024, 6, 16),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Daniel',
#   'Cunha',
#   47,
#   'stella34@example.com',
#   datetime.date(2024, 1, 10),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Daniela',
#   'Duarte',
#   43,
#   'maria-eduarda45@example.org',
#   datetime.date(2024, 6, 25),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Daniela',
#   'Ferreira',
#   68,
#   'leonardoviana@example.com',
#   datetime.date(2024, 3, 23),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Danilo',
#   'Oliveira',
#   57,
#   'brunonovaes@example.net',
#   datetime.date(2024, 5, 4),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Davi',
#   'Moura',
#   31,
#   'yasminfernandes@example.org',
#   datetime.date(2024, 6, 26),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Davi',
#   'Sales',
#   57,
#   'diegoalves@example.net',
#   datetime.date(2024, 4, 11),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Davi Lucas',
#   'Cavalcanti',
#   33,
#   'azevedojoao-felipe@example.net',
#   datetime.date(2024, 4, 26),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Davi Luiz',
#   'Pinto',
#   20,
#   'carolinadias@example.org',
#   datetime.date(2024, 4, 9),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Diogo',
#   'Caldeira',
#   47,
#   'teixeiramaria-cecilia@example.com',
#   datetime.date(2024, 7, 5),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Diogo',
#   'Peixoto',
#   43,
#   'ncastro@example.org',
#   datetime.date(2024, 1, 16),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Diogo',
#   'Rodrigues',
#   48,
#   'vitor37@example.net',
#   datetime.date(2024, 2, 16),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Eduarda',
#   'da Paz',
#   54,
#   'ana-sophia54@example.com',
#   datetime.date(2024, 3, 6),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Eduardo',
#   'Cardoso',
#   48,
#   'sofia69@example.net',
#   datetime.date(2024, 6, 4),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Eduardo',
#   'Cardoso',
#   20,
#   'nalves@example.org',
#   datetime.date(2024, 4, 25),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Eloah',
#   'Nogueira',
#   44,
#   'sribeiro@example.org',
#   datetime.date(2024, 7, 31),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Emanuel',
#   'Dias',
#   50,
#   'gustavo63@example.com',
#   datetime.date(2024, 1, 9),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Emanuel',
#   'Gonçalves',
#   44,
#   'bernardo22@example.net',
#   datetime.date(2024, 4, 1),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Emanuella',
#   'Azevedo',
#   44,
#   'da-costanathan@example.net',
#   datetime.date(2024, 7, 22),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Emanuella',
#   'da Mata',
#   63,
#   'enricoda-costa@example.net',
#   datetime.date(2024, 1, 16),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Emanuelly',
#   'Mendes',
#   49,
#   'eloahcaldeira@example.net',
#   datetime.date(2024, 2, 5),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Emilly',
#   'Alves',
#   55,
#   'moraesclara@example.org',
#   datetime.date(2024, 4, 25),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Emilly',
#   'Barbosa',
#   70,
#   'stella90@example.com',
#   datetime.date(2024, 4, 21),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Enrico',
#   'Souza',
#   27,
#   'knunes@example.org',
#   datetime.date(2024, 2, 16),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Erick',
#   'da Rocha',
#   42,
#   'gabriellycardoso@example.org',
#   datetime.date(2024, 4, 21),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Francisco',
#   'Mendes',
#   18,
#   'vianavitoria@example.org',
#   datetime.date(2024, 6, 16),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Gabriel',
#   'da Cunha',
#   40,
#   'laura11@example.net',
#   datetime.date(2024, 6, 24),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Gabriela',
#   'Campos',
#   29,
#   'matheusferreira@example.com',
#   datetime.date(2024, 8, 4),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Gabrielly',
#   'Cunha',
#   62,
#   'pedro-henrique59@example.net',
#   datetime.date(2024, 1, 2),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Gabrielly',
#   'Moura',
#   49,
#   'hferreira@example.net',
#   datetime.date(2024, 5, 30),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Giovanna',
#   'Martins',
#   49,
#   'jda-cruz@example.org',
#   datetime.date(2024, 4, 9),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Guilherme',
#   'Oliveira',
#   70,
#   'cauefogaca@example.org',
#   datetime.date(2024, 7, 11),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Gustavo Henrique',
#   'Souza',
#   19,
#   'hcampos@example.net',
#   datetime.date(2024, 3, 11),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Gustavo Henrique',
#   'das Neves',
#   46,
#   'imendes@example.net',
#   datetime.date(2024, 1, 27),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Heitor',
#   'Pires',
#   58,
#   'alicedias@example.org',
#   datetime.date(2024, 6, 2),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Heitor',
#   'Teixeira',
#   47,
#   'vvieira@example.net',
#   datetime.date(2024, 8, 6),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Heloísa',
#   'Castro',
#   56,
#   'lucasmelo@example.net',
#   datetime.date(2024, 6, 7),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Heloísa',
#   'Dias',
#   27,
#   'carolinamoura@example.net',
#   datetime.date(2024, 1, 8),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Heloísa',
#   'Duarte',
#   58,
#   'mpereira@example.com',
#   datetime.date(2024, 1, 1),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Heloísa',
#   'da Mata',
#   48,
#   'xgomes@example.org',
#   datetime.date(2024, 5, 28),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Ian',
#   'Campos',
#   22,
#   'emanuelly32@example.net',
#   datetime.date(2024, 8, 2),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Ian',
#   'Cunha',
#   46,
#   'qmoraes@example.org',
#   datetime.date(2024, 2, 28),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Igor',
#   'Farias',
#   67,
#   'lorenzosantos@example.org',
#   datetime.date(2024, 4, 22),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Isabel',
#   'Viana',
#   19,
#   'catarinadias@example.com',
#   datetime.date(2024, 5, 14),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Isabella',
#   'Dias',
#   37,
#   'dda-cruz@example.net',
#   datetime.date(2024, 7, 19),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Isabelly',
#   'Moraes',
#   60,
#   'rferreira@example.com',
#   datetime.date(2024, 5, 20),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Isis',
#   'Jesus',
#   51,
#   'danilo20@example.org',
#   datetime.date(2024, 5, 20),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Isis',
#   'Vieira',
#   50,
#   'leonardoda-mota@example.net',
#   datetime.date(2024, 3, 8),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Joaquim',
#   'Aragão',
#   23,
#   'teixeiramarina@example.com',
#   datetime.date(2024, 8, 6),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('João',
#   'da Cruz',
#   51,
#   'benjaminlopes@example.net',
#   datetime.date(2024, 8, 6),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('João Felipe',
#   'Moraes',
#   28,
#   'eda-cunha@example.org',
#   datetime.date(2024, 5, 16),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('João Felipe',
#   'Silva',
#   22,
#   'miguel59@example.net',
#   datetime.date(2024, 6, 17),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('João Felipe',
#   'da Cruz',
#   19,
#   'vinicius65@example.net',
#   datetime.date(2024, 7, 27),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('João Guilherme',
#   'Cavalcanti',
#   20,
#   'caldeirajoao-gabriel@example.net',
#   datetime.date(2024, 3, 21),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('João Guilherme',
#   'Teixeira',
#   18,
#   'evelyngomes@example.org',
#   datetime.date(2024, 3, 25),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('João Miguel',
#   'Martins',
#   40,
#   'ceciliamelo@example.org',
#   datetime.date(2024, 2, 24),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('João Pedro',
#   'Lima',
#   61,
#   'maria-fernandamonteiro@example.com',
#   datetime.date(2024, 7, 18),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('João Pedro',
#   'Moreira',
#   47,
#   'fcorreia@example.com',
#   datetime.date(2024, 5, 7),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('João Vitor',
#   'Ferreira',
#   52,
#   'mendesalana@example.com',
#   datetime.date(2024, 7, 17),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Julia',
#   'Barbosa',
#   37,
#   'luiz-fernandocosta@example.org',
#   datetime.date(2024, 7, 7),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Julia',
#   'Oliveira',
#   37,
#   'martinsmaria-sophia@example.net',
#   datetime.date(2024, 7, 31),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Juliana',
#   'Lima',
#   53,
#   'ana-vitoria33@example.net',
#   datetime.date(2024, 6, 17),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Juliana',
#   'Mendes',
#   54,
#   'pporto@example.com',
#   datetime.date(2024, 6, 18),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Juliana',
#   'Moreira',
#   37,
#   'oliveiraandre@example.com',
#   datetime.date(2024, 2, 15),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Juliana',
#   'Rodrigues',
#   63,
#   'carvalhomaria-luiza@example.net',
#   datetime.date(2024, 4, 30),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Júlia',
#   'Fogaça',
#   36,
#   'viniciusda-cunha@example.com',
#   datetime.date(2024, 6, 9),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Júlia',
#   'Nascimento',
#   69,
#   'nataliajesus@example.com',
#   datetime.date(2024, 4, 18),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Kamilly',
#   'Correia',
#   44,
#   'kamilly93@example.net',
#   datetime.date(2024, 4, 20),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Kevin',
#   'Carvalho',
#   44,
#   'thiagomoraes@example.net',
#   datetime.date(2024, 4, 15),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Kevin',
#   'Farias',
#   50,
#   'luiza63@example.org',
#   datetime.date(2024, 2, 28),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Kevin',
#   'Pires',
#   22,
#   'barrosisabel@example.org',
#   datetime.date(2024, 7, 20),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Larissa',
#   'Aragão',
#   43,
#   'enzoda-mata@example.com',
#   datetime.date(2024, 4, 14),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Larissa',
#   'Barros',
#   25,
#   'fvieira@example.org',
#   datetime.date(2024, 3, 18),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Larissa',
#   'Moura',
#   51,
#   'ana-sophiaoliveira@example.net',
#   datetime.date(2024, 2, 16),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Larissa',
#   'Pires',
#   19,
#   'alvesenrico@example.com',
#   datetime.date(2024, 1, 12),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Lavínia',
#   'Moreira',
#   64,
#   'mendesana-sophia@example.net',
#   datetime.date(2024, 8, 6),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Lavínia',
#   'Oliveira',
#   21,
#   'camposvitoria@example.com',
#   datetime.date(2024, 3, 27),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Leonardo',
#   'Alves',
#   21,
#   'eduardo77@example.net',
#   datetime.date(2024, 2, 9),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Letícia',
#   'Pires',
#   28,
#   'dcampos@example.net',
#   datetime.date(2024, 6, 28),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Levi',
#   'Monteiro',
#   55,
#   'arthur21@example.com',
#   datetime.date(2024, 1, 20),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Levi',
#   'Nunes',
#   36,
#   'jalves@example.com',
#   datetime.date(2024, 6, 9),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Levi',
#   'Ramos',
#   39,
#   'stella94@example.net',
#   datetime.date(2024, 1, 17),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Luana',
#   'Novaes',
#   29,
#   'stellarodrigues@example.net',
#   datetime.date(2024, 7, 30),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Lucas Gabriel',
#   'da Paz',
#   28,
#   'souzagiovanna@example.org',
#   datetime.date(2024, 4, 9),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Lucca',
#   'das Neves',
#   18,
#   'renan56@example.org',
#   datetime.date(2024, 3, 7),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Luiz Gustavo',
#   'Gomes',
#   27,
#   'novaesian@example.org',
#   datetime.date(2024, 3, 30),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Luiz Henrique',
#   'Azevedo',
#   49,
#   'maria-ceciliafernandes@example.com',
#   datetime.date(2024, 3, 9),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Luiz Henrique',
#   'Barbosa',
#   31,
#   'fogacaheitor@example.org',
#   datetime.date(2024, 1, 23),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Luiz Otávio',
#   'Rezende',
#   65,
#   'goncalvesjoao-lucas@example.net',
#   datetime.date(2024, 4, 21),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Luiza',
#   'Caldeira',
#   36,
#   'pduarte@example.org',
#   datetime.date(2024, 2, 24),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Luna',
#   'Araújo',
#   33,
#   'tpereira@example.org',
#   datetime.date(2024, 5, 15),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Luna',
#   'Pereira',
#   21,
#   'marcelosilva@example.net',
#   datetime.date(2024, 6, 1),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Lívia',
#   'Moraes',
#   37,
#   'helenada-rocha@example.net',
#   datetime.date(2024, 7, 12),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Manuela',
#   'Novaes',
#   23,
#   'isisnascimento@example.com',
#   datetime.date(2024, 5, 15),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Marcela',
#   'Cavalcanti',
#   29,
#   'juliarocha@example.com',
#   datetime.date(2024, 6, 19),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Marcela',
#   'da Paz',
#   46,
#   'pintomaria@example.com',
#   datetime.date(2024, 3, 10),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Marcelo',
#   'Costa',
#   57,
#   'mmartins@example.com',
#   datetime.date(2024, 1, 16),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Marcelo',
#   'da Costa',
#   54,
#   'qdias@example.com',
#   datetime.date(2024, 4, 8),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Marcos Vinicius',
#   'Freitas',
#   64,
#   'ccavalcanti@example.com',
#   datetime.date(2024, 6, 24),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Maria',
#   'Gomes',
#   37,
#   'bianca48@example.com',
#   datetime.date(2024, 7, 9),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Maria',
#   'Monteiro',
#   39,
#   'spinto@example.net',
#   datetime.date(2024, 2, 24),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Maria Alice',
#   'da Mota',
#   21,
#   'caldeiraisis@example.net',
#   datetime.date(2024, 3, 15),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Maria Cecília',
#   'Oliveira',
#   30,
#   'pedro-miguelaragao@example.net',
#   datetime.date(2024, 6, 22),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Maria Cecília',
#   'Teixeira',
#   38,
#   'iancunha@example.org',
#   datetime.date(2024, 6, 23),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Maria Cecília',
#   'Teixeira',
#   31,
#   'cardosobeatriz@example.net',
#   datetime.date(2024, 2, 26),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Maria Clara',
#   'Costela',
#   68,
#   'monteiromaria-clara@example.com',
#   datetime.date(2024, 4, 3),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Maria Clara',
#   'Lima',
#   67,
#   'evelyn82@example.org',
#   datetime.date(2024, 6, 14),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Maria Clara',
#   'Rodrigues',
#   52,
#   'pda-conceicao@example.net',
#   datetime.date(2024, 3, 30),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Maria Eduarda',
#   'Fogaça',
#   26,
#   'ana-luiza10@example.com',
#   datetime.date(2024, 3, 4),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Maria Eduarda',
#   'Vieira',
#   41,
#   'lunaaragao@example.net',
#   datetime.date(2024, 4, 10),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Maria Eduarda',
#   'da Cruz',
#   45,
#   'maria-eduardamartins@example.org',
#   datetime.date(2024, 3, 29),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Maria Fernanda',
#   'Moura',
#   22,
#   'fernandesolivia@example.org',
#   datetime.date(2024, 7, 8),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Maria Fernanda',
#   'Pereira',
#   43,
#   'evelyn52@example.net',
#   datetime.date(2024, 7, 18),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Maria Fernanda',
#   'Ramos',
#   46,
#   'diego97@example.com',
#   datetime.date(2024, 3, 6),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Maria Julia',
#   'da Cruz',
#   56,
#   'maria-alice97@example.net',
#   datetime.date(2024, 6, 22),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Maria Luiza',
#   'Gomes',
#   39,
#   'jesuscaue@example.org',
#   datetime.date(2024, 4, 25),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Maria Sophia',
#   'Nogueira',
#   41,
#   'eduardocosta@example.com',
#   datetime.date(2024, 1, 23),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Maria Vitória',
#   'Lima',
#   56,
#   'maria-vitoria35@example.org',
#   datetime.date(2024, 3, 13),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Mariane',
#   'Farias',
#   62,
#   'francisco79@example.com',
#   datetime.date(2024, 6, 17),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Mariane',
#   'Mendes',
#   50,
#   'souzamirella@example.net',
#   datetime.date(2024, 6, 30),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Matheus',
#   'Aragão',
#   18,
#   'mendesana@example.com',
#   datetime.date(2024, 1, 12),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Matheus',
#   'Moura',
#   55,
#   'joao-gabrielda-rosa@example.com',
#   datetime.date(2024, 2, 3),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Maysa',
#   'Jesus',
#   19,
#   'ccavalcanti@example.org',
#   datetime.date(2024, 5, 16),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Melissa',
#   'Duarte',
#   40,
#   'danilo61@example.org',
#   datetime.date(2024, 1, 20),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Melissa',
#   'Teixeira',
#   65,
#   'ubarbosa@example.com',
#   datetime.date(2024, 5, 6),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Melissa',
#   'da Mata',
#   58,
#   'caldeiraluiz-fernando@example.net',
#   datetime.date(2024, 4, 14),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Melissa',
#   'da Mata',
#   28,
#   'laura37@example.com',
#   datetime.date(2024, 6, 27),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Milena',
#   'Azevedo',
#   53,
#   'da-cruzclarice@example.org',
#   datetime.date(2024, 4, 28),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Milena',
#   'Rezende',
#   29,
#   'juliada-paz@example.org',
#   datetime.date(2024, 3, 14),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Mirella',
#   'Gomes',
#   18,
#   'oda-mata@example.net',
#   datetime.date(2024, 2, 19),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Mirella',
#   'Ribeiro',
#   26,
#   'bianca66@example.net',
#   datetime.date(2024, 6, 23),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Mirella',
#   'Souza',
#   56,
#   'anthony66@example.net',
#   datetime.date(2024, 2, 24),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Natália',
#   'Ferreira',
#   66,
#   'francisco46@example.com',
#   datetime.date(2024, 2, 27),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Natália',
#   'Peixoto',
#   63,
#   'xaragao@example.com',
#   datetime.date(2024, 3, 21),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Natália',
#   'Silveira',
#   19,
#   'almeidathiago@example.org',
#   datetime.date(2024, 1, 18),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Nicolas',
#   'da Rocha',
#   56,
#   'opeixoto@example.com',
#   datetime.date(2024, 7, 2),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Nicole',
#   'Lima',
#   18,
#   'caio81@example.com',
#   datetime.date(2024, 4, 6),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Nina',
#   'da Cruz',
#   38,
#   'camposmirella@example.net',
#   datetime.date(2024, 5, 21),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Noah',
#   'Melo',
#   55,
#   'zoliveira@example.com',
#   datetime.date(2024, 3, 23),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Noah',
#   'Nunes',
#   32,
#   'ceciliacaldeira@example.com',
#   datetime.date(2024, 4, 19),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Noah',
#   'da Luz',
#   67,
#   'davi-luiz41@example.net',
#   datetime.date(2024, 6, 3),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Olivia',
#   'Pereira',
#   61,
#   'luiz-henriquesales@example.net',
#   datetime.date(2024, 5, 17),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Olivia',
#   'da Rosa',
#   47,
#   'cardosoana-beatriz@example.com',
#   datetime.date(2024, 2, 27),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Otávio',
#   'Moraes',
#   36,
#   'hduarte@example.org',
#   datetime.date(2024, 8, 1),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Otávio',
#   'da Paz',
#   54,
#   'cauacardoso@example.org',
#   datetime.date(2024, 3, 17),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Paulo',
#   'Mendes',
#   32,
#   'cardosojulia@example.com',
#   datetime.date(2024, 3, 24),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Pedro',
#   'Gomes',
#   45,
#   'ana-sophia84@example.net',
#   datetime.date(2024, 5, 25),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Pedro Henrique',
#   'Pires',
#   31,
#   'guilherme01@example.com',
#   datetime.date(2024, 3, 13),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Pedro Miguel',
#   'Costela',
#   39,
#   'silveiraalexia@example.org',
#   datetime.date(2024, 2, 13),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Pietra',
#   'Azevedo',
#   40,
#   'ribeirojoao-vitor@example.net',
#   datetime.date(2024, 6, 15),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Pietra',
#   'Cavalcanti',
#   54,
#   'rodriguesvitoria@example.com',
#   datetime.date(2024, 6, 9),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Pietra',
#   'Jesus',
#   19,
#   'helena05@example.net',
#   datetime.date(2024, 1, 1),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Pietra',
#   'Moreira',
#   59,
#   'emanuel88@example.com',
#   datetime.date(2024, 6, 22),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Pietro',
#   'Barbosa',
#   33,
#   'maria-ceciliada-mata@example.org',
#   datetime.date(2024, 5, 15),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Raquel',
#   'Costela',
#   65,
#   'levida-rosa@example.net',
#   datetime.date(2024, 7, 9),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Raquel',
#   'Freitas',
#   40,
#   'rochalucca@example.net',
#   datetime.date(2024, 1, 17),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Raquel',
#   'Monteiro',
#   51,
#   'bruno19@example.org',
#   datetime.date(2024, 2, 6),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Raquel',
#   'Rodrigues',
#   26,
#   'joaquim13@example.net',
#   datetime.date(2024, 4, 10),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Raul',
#   'Gonçalves',
#   44,
#   'bmendes@example.net',
#   datetime.date(2024, 7, 3),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Rebeca',
#   'Novaes',
#   32,
#   'enzo-gabriel24@example.net',
#   datetime.date(2024, 4, 21),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Rodrigo',
#   'Lima',
#   50,
#   'lda-conceicao@example.org',
#   datetime.date(2024, 1, 17),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Rodrigo',
#   'Viana',
#   22,
#   'julianascimento@example.org',
#   datetime.date(2024, 5, 13),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Rodrigo',
#   'da Cunha',
#   58,
#   'laisoliveira@example.net',
#   datetime.date(2024, 7, 28),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Ryan',
#   'Jesus',
#   58,
#   'larissacarvalho@example.com',
#   datetime.date(2024, 3, 28),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Sabrina',
#   'Barbosa',
#   40,
#   'peixotopietro@example.org',
#   datetime.date(2024, 3, 25),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Sabrina',
#   'Rocha',
#   48,
#   'marianemoraes@example.com',
#   datetime.date(2024, 1, 17),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Sarah',
#   'Cunha',
#   41,
#   'lucca32@example.com',
#   datetime.date(2024, 3, 30),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Sofia',
#   'Moraes',
#   22,
#   'vianacaue@example.net',
#   datetime.date(2024, 7, 19),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Sofia',
#   'Oliveira',
#   65,
#   'pedro-henrique81@example.org',
#   datetime.date(2024, 4, 23),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Sofia',
#   'Vieira',
#   48,
#   'lopesemanuelly@example.net',
#   datetime.date(2024, 1, 22),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Sophia',
#   'Fernandes',
#   38,
#   'lgomes@example.org',
#   datetime.date(2024, 3, 5),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Sophia',
#   'Gonçalves',
#   40,
#   'limamaria-julia@example.org',
#   datetime.date(2024, 4, 20),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Sophia',
#   'Nogueira',
#   41,
#   'alexiarodrigues@example.org',
#   datetime.date(2024, 2, 9),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Stella',
#   'Azevedo',
#   56,
#   'sarah84@example.net',
#   datetime.date(2024, 7, 30),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Stella',
#   'Fernandes',
#   20,
#   'franciscodias@example.com',
#   datetime.date(2024, 5, 16),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Valentina',
#   'Carvalho',
#   61,
#   'wporto@example.net',
#   datetime.date(2024, 7, 29),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Vicente',
#   'Nunes',
#   27,
#   'maria-eduarda20@example.net',
#   datetime.date(2024, 7, 4),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Vinicius',
#   'Gomes',
#   51,
#   'ianbarbosa@example.org',
#   datetime.date(2024, 6, 17),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Vitor',
#   'das Neves',
#   29,
#   'lorenzogoncalves@example.org',
#   datetime.date(2024, 3, 27),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Vitor Hugo',
#   'Lopes',
#   38,
#   'isabel02@example.net',
#   datetime.date(2024, 3, 27),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Vitor Hugo',
#   'Ribeiro',
#   42,
#   'cecilia10@example.org',
#   datetime.date(2024, 3, 20),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Vitor Hugo',
#   'Silveira',
#   36,
#   'faragao@example.org',
#   datetime.date(2024, 7, 3),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Vitória',
#   'Araújo',
#   18,
#   'maria-eduarda34@example.org',
#   datetime.date(2024, 6, 9),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Vitória',
#   'Dias',
#   30,
#   'maria-sophia83@example.org',
#   datetime.date(2024, 7, 3),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Yago',
#   'da Mota',
#   53,
#   'marina15@example.org',
#   datetime.date(2024, 6, 30),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Yasmin',
#   'Jesus',
#   42,
#   'mariapereira@example.net',
#   datetime.date(2024, 7, 25),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1),
#  ('Yuri',
#   'Farias',
#   35,
#   'alvesnicole@example.com',
#   datetime.date(2024, 2, 17),
#   datetime.date(2023, 12, 31),
#   datetime.date(1970, 1, 1),
#   1)]

# %%
""" 
caso onde o cliente inserido ja esta na base mas tem a data de cadastro menor do
que a já cadastrada, nesse caso, o dado é inserido mas o dado ja persistido
é mantido como o dado corrente porque tem a data de cadastro maior

"""
df_joined = df_insert.join(
    df_table, 
    on="email", 
    how="inner"
).filter(
    pl.col("data_cadastro").cast(pl.Date) < pl.col("data_cadastro_right").cast(pl.Date)
)

# Selecionar as colunas e renomear conforme necessário
df_update_inactive_new = df_joined.select([
    pl.col("nome"),
    pl.col("sobrenome"),
    pl.col("idade"),
    pl.col("email"),
    pl.col("data_cadastro"),
    pl.col("effective_date"),
    pl.col("effective_date").alias("end_date"),
    pl.lit(0).alias("is_current")
])

# %%
df_update_inactive_new
# Out:
# shape: (1, 8)
# ┌────────────┬───────────┬───────┬─────────────┬────────────┬────────────┬────────────┬────────────┐
# │ nome       ┆ sobrenome ┆ idade ┆ email       ┆ data_cadas ┆ effective_ ┆ end_date   ┆ is_current │
# │ ---        ┆ ---       ┆ ---   ┆ ---         ┆ tro        ┆ date       ┆ ---        ┆ ---        │
# │ str        ┆ str       ┆ i64   ┆ str         ┆ ---        ┆ ---        ┆ date       ┆ i32        │
# │            ┆           ┆       ┆             ┆ date       ┆ date       ┆            ┆            │
# ╞════════════╪═══════════╪═══════╪═════════════╪════════════╪════════════╪════════════╪════════════╡
# │ Vitor Hugo ┆ Lopes     ┆ 38    ┆ isabel02@ex ┆ 2023-02-04 ┆ 2024-08-11 ┆ 2024-08-11 ┆ 0          │
# │            ┆           ┆       ┆ ample.net   ┆            ┆            ┆            ┆            │
# └────────────┴───────────┴───────┴─────────────┴────────────┴────────────┴────────────┴────────────┘

# %%
df_insert = df_insert.join(
    df_update_inactive_new, 
    on="email", 
    how="left"
).select([
    pl.col("nome"),
    pl.col("sobrenome"),
    pl.col("idade"),
    pl.col("email"),
    pl.col("data_cadastro"),
    pl.when(pl.col("nome_right").is_not_null()).then(pl.col("effective_date_right")).otherwise(pl.col("effective_date")).alias("effective_date"),
    pl.when(pl.col("nome_right").is_not_null()).then(pl.col("end_date_right")).otherwise(pl.col("end_date")).alias("end_date"),
     pl.when(pl.col("nome_right").is_not_null()).then(pl.col("is_current_right")).otherwise(pl.col("is_current")).alias("is_current"),
])

# %%
df_insert
# Out:
# shape: (5, 8)
# ┌─────────────┬───────────┬───────┬────────────┬────────────┬────────────┬────────────┬────────────┐
# │ nome        ┆ sobrenome ┆ idade ┆ email      ┆ data_cadas ┆ effective_ ┆ end_date   ┆ is_current │
# │ ---         ┆ ---       ┆ ---   ┆ ---        ┆ tro        ┆ date       ┆ ---        ┆ ---        │
# │ str         ┆ str       ┆ i64   ┆ str        ┆ ---        ┆ ---        ┆ date       ┆ i32        │
# │             ┆           ┆       ┆            ┆ date       ┆ date       ┆            ┆            │
# ╞═════════════╪═══════════╪═══════╪════════════╪════════════╪════════════╪════════════╪════════════╡
# │ Daniel      ┆ Viana     ┆ 52    ┆ ramoscecil ┆ 2025-02-04 ┆ 2024-08-11 ┆ 2999-12-31 ┆ 1          │
# │             ┆           ┆       ┆ ia@example ┆            ┆            ┆            ┆            │
# │             ┆           ┆       ┆ .com       ┆            ┆            ┆            ┆            │
# │ Luiz Otávio ┆ Nunes     ┆ 34    ┆ theo80@exa ┆ 2025-02-04 ┆ 2024-08-11 ┆ 2999-12-31 ┆ 1          │
# │             ┆           ┆       ┆ mple.net   ┆            ┆            ┆            ┆            │
# │ Murilo      ┆ Barbosa   ┆ 56    ┆ davicavalc ┆ 2025-02-04 ┆ 2024-08-11 ┆ 2999-12-31 ┆ 1          │
# │             ┆           ┆       ┆ anti@examp ┆            ┆            ┆            ┆            │
# │             ┆           ┆       ┆ le.com     ┆            ┆            ┆            ┆            │
# │ Vitor Hugo  ┆ Lopes     ┆ 38    ┆ isabel02@e ┆ 2023-02-04 ┆ 2024-08-11 ┆ 2024-08-11 ┆ 0          │
# │             ┆           ┆       ┆ xample.net ┆            ┆            ┆            ┆            │
# │ Luiz        ┆ Fernandes ┆ 28    ┆ brenopeixo ┆ 2025-02-04 ┆ 2024-08-11 ┆ 2999-12-31 ┆ 1          │
# │ Henrique    ┆           ┆       ┆ to@example ┆            ┆            ┆            ┆            │
# │             ┆           ┆       ┆ .com       ┆            ┆            ┆            ┆            │
# └─────────────┴───────────┴───────┴────────────┴────────────┴────────────┴────────────┴────────────┘

# %%
# Converta o DataFrame para um formato que pode ser enviado ao ClickHouse
data = df_insert.to_dicts()

# Inserir os dados no ClickHouse
client_ch.execute(
    'INSERT INTO usuarios (nome, sobrenome, idade, email, data_cadastro, effective_date, end_date, is_current) VALUES',
    [(row['nome'], row['sobrenome'], row['idade'], row['email'], row['data_cadastro'], row['effective_date'], row['end_date'], row['is_current']) for row in data]
)
# Out:
# 5

# %%
clientes_existentes = client_ch.execute("SELECT nome, sobrenome, idade, email FROM usuarios")
clientes_existentes_dict = {cliente[3]: {"nome": cliente[0], "sobrenome": cliente[1], "idade": cliente[2]} for cliente in clientes_existentes}

# %%
clientes_existentes_dict
# Out:
# {'goncalvesluiz-otavio@example.net': {'nome': 'Alexandre',
#   'sobrenome': 'Rezende',
#   'idade': 21},
#  'ribeiromaria-clara@example.com': {'nome': 'Alexia',
#   'sobrenome': 'Gonçalves',
#   'idade': 45},
#  'pedro-henrique88@example.org': {'nome': 'Alícia',
#   'sobrenome': 'da Rocha',
#   'idade': 24},
#  'tda-conceicao@example.net': {'nome': 'Amanda',
#   'sobrenome': 'Moraes',
#   'idade': 44},
#  'qrodrigues@example.org': {'nome': 'Ana',
#   'sobrenome': 'da Cunha',
#   'idade': 36},
#  'cecilia51@example.org': {'nome': 'Ana', 'sobrenome': 'da Luz', 'idade': 26},
#  'vda-luz@example.com': {'nome': 'Ana Beatriz',
#   'sobrenome': 'Nunes',
#   'idade': 58},
#  'ada-cunha@example.net': {'nome': 'Ana Beatriz',
#   'sobrenome': 'Ramos',
#   'idade': 56},
#  'vitor-hugoviana@example.net': {'nome': 'Ana Clara',
#   'sobrenome': 'da Luz',
#   'idade': 60},
#  'isaac44@example.org': {'nome': 'Ana Clara',
#   'sobrenome': 'da Mata',
#   'idade': 51},
#  'joana70@example.org': {'nome': 'Ana Julia',
#   'sobrenome': 'Correia',
#   'idade': 52},
#  'ada-luz@example.org': {'nome': 'Ana Julia',
#   'sobrenome': 'Duarte',
#   'idade': 59},
#  'monteirobernardo@example.com': {'nome': 'Ana Júlia',
#   'sobrenome': 'Barbosa',
#   'idade': 51},
#  'joao-lucas24@example.org': {'nome': 'Ana Júlia',
#   'sobrenome': 'Costela',
#   'idade': 66},
#  'caroline31@example.net': {'nome': 'Ana Júlia',
#   'sobrenome': 'Mendes',
#   'idade': 35},
#  'vitoriasales@example.org': {'nome': 'Ana Júlia',
#   'sobrenome': 'Ramos',
#   'idade': 52},
#  'mirella34@example.com': {'nome': 'Ana Laura',
#   'sobrenome': 'Gomes',
#   'idade': 60},
#  'alice20@example.net': {'nome': 'Ana Lívia',
#   'sobrenome': 'Barbosa',
#   'idade': 63},
#  'salesmelissa@example.org': {'nome': 'Ana Lívia',
#   'sobrenome': 'Gonçalves',
#   'idade': 38},
#  'osilva@example.net': {'nome': 'Ana Sophia',
#   'sobrenome': 'Cunha',
#   'idade': 56},
#  'yramos@example.com': {'nome': 'Ana Sophia',
#   'sobrenome': 'Monteiro',
#   'idade': 26},
#  'thiago71@example.com': {'nome': 'Ana Sophia',
#   'sobrenome': 'Rocha',
#   'idade': 27},
#  'cardosocaue@example.org': {'nome': 'André',
#   'sobrenome': 'Rezende',
#   'idade': 43},
#  'nogueirarafael@example.com': {'nome': 'Anthony',
#   'sobrenome': 'Cunha',
#   'idade': 23},
#  'barrosmaria-eduarda@example.com': {'nome': 'Anthony',
#   'sobrenome': 'Moreira',
#   'idade': 35},
#  'luanasilva@example.net': {'nome': 'Benjamin',
#   'sobrenome': 'Carvalho',
#   'idade': 27},
#  'correiaclara@example.net': {'nome': 'Benjamin',
#   'sobrenome': 'Costa',
#   'idade': 44},
#  'correiaanthony@example.net': {'nome': 'Benício',
#   'sobrenome': 'Martins',
#   'idade': 49},
#  'carlos-eduardo88@example.com': {'nome': 'Bianca',
#   'sobrenome': 'Rodrigues',
#   'idade': 20},
#  'tcaldeira@example.com': {'nome': 'Bianca',
#   'sobrenome': 'da Cunha',
#   'idade': 19},
#  'bianca70@example.com': {'nome': 'Breno',
#   'sobrenome': 'Azevedo',
#   'idade': 69},
#  'isabella90@example.org': {'nome': 'Breno',
#   'sobrenome': 'Jesus',
#   'idade': 41},
#  'ana-carolina43@example.com': {'nome': 'Breno',
#   'sobrenome': 'Ribeiro',
#   'idade': 42},
#  'da-cunhacaio@example.org': {'nome': 'Bruna',
#   'sobrenome': 'Campos',
#   'idade': 66},
#  'mariana47@example.com': {'nome': 'Bruno',
#   'sobrenome': 'Teixeira',
#   'idade': 67},
#  'cardosoalexia@example.org': {'nome': 'Bruno',
#   'sobrenome': 'Viana',
#   'idade': 40},
#  'clarice83@example.net': {'nome': 'Bruno',
#   'sobrenome': 'da Rocha',
#   'idade': 29},
#  'leandromartins@example.com': {'nome': 'Bryan',
#   'sobrenome': 'Moreira',
#   'idade': 49},
#  'nascimentoraul@example.org': {'nome': 'Bárbara',
#   'sobrenome': 'Duarte',
#   'idade': 53},
#  'ana-beatriz74@example.org': {'nome': 'Bárbara',
#   'sobrenome': 'Fogaça',
#   'idade': 22},
#  'enzofarias@example.net': {'nome': 'Bárbara',
#   'sobrenome': 'Vieira',
#   'idade': 26},
#  'pedronogueira@example.net': {'nome': 'Caio',
#   'sobrenome': 'Araújo',
#   'idade': 36},
#  'vrocha@example.com': {'nome': 'Caio', 'sobrenome': 'Pereira', 'idade': 56},
#  'laragao@example.com': {'nome': 'Calebe',
#   'sobrenome': 'Azevedo',
#   'idade': 47},
#  'pirescaio@example.net': {'nome': 'Calebe',
#   'sobrenome': 'Cunha',
#   'idade': 24},
#  'pcardoso@example.net': {'nome': 'Calebe',
#   'sobrenome': 'Ribeiro',
#   'idade': 27},
#  'nicole84@example.net': {'nome': 'Carolina',
#   'sobrenome': 'Monteiro',
#   'idade': 53},
#  'fmelo@example.net': {'nome': 'Carolina',
#   'sobrenome': 'Silveira',
#   'idade': 44},
#  'ianfreitas@example.net': {'nome': 'Catarina',
#   'sobrenome': 'Rezende',
#   'idade': 53},
#  'gfogaca@example.org': {'nome': 'Catarina',
#   'sobrenome': 'da Conceição',
#   'idade': 32},
#  'yda-costa@example.com': {'nome': 'Cauã', 'sobrenome': 'Viana', 'idade': 31},
#  'ecarvalho@example.com': {'nome': 'Cauê', 'sobrenome': 'Silva', 'idade': 68},
#  'alananascimento@example.com': {'nome': 'Cauê',
#   'sobrenome': 'das Neves',
#   'idade': 63},
#  'davi-luccanovaes@example.org': {'nome': 'Cecília',
#   'sobrenome': 'das Neves',
#   'idade': 32},
#  'melissa87@example.com': {'nome': 'Clarice',
#   'sobrenome': 'Dias',
#   'idade': 69},
#  'stella34@example.com': {'nome': 'Daniel', 'sobrenome': 'Cunha', 'idade': 47},
#  'ramoscecilia@example.com': {'nome': 'Daniel',
#   'sobrenome': 'Viana',
#   'idade': 52},
#  'maria-eduarda45@example.org': {'nome': 'Daniela',
#   'sobrenome': 'Duarte',
#   'idade': 43},
#  'leonardoviana@example.com': {'nome': 'Daniela',
#   'sobrenome': 'Ferreira',
#   'idade': 68},
#  'brunonovaes@example.net': {'nome': 'Danilo',
#   'sobrenome': 'Oliveira',
#   'idade': 57},
#  'yasminfernandes@example.org': {'nome': 'Davi',
#   'sobrenome': 'Moura',
#   'idade': 31},
#  'diegoalves@example.net': {'nome': 'Davi', 'sobrenome': 'Sales', 'idade': 57},
#  'azevedojoao-felipe@example.net': {'nome': 'Davi Lucas',
#   'sobrenome': 'Cavalcanti',
#   'idade': 33},
#  'carolinadias@example.org': {'nome': 'Davi Luiz',
#   'sobrenome': 'Pinto',
#   'idade': 20},
#  'teixeiramaria-cecilia@example.com': {'nome': 'Diogo',
#   'sobrenome': 'Caldeira',
#   'idade': 47},
#  'ncastro@example.org': {'nome': 'Diogo', 'sobrenome': 'Peixoto', 'idade': 43},
#  'vitor37@example.net': {'nome': 'Diogo',
#   'sobrenome': 'Rodrigues',
#   'idade': 48},
#  'ana-sophia54@example.com': {'nome': 'Eduarda',
#   'sobrenome': 'da Paz',
#   'idade': 54},
#  'sofia69@example.net': {'nome': 'Eduardo',
#   'sobrenome': 'Cardoso',
#   'idade': 48},
#  'nalves@example.org': {'nome': 'Eduardo',
#   'sobrenome': 'Cardoso',
#   'idade': 20},
#  'sribeiro@example.org': {'nome': 'Eloah',
#   'sobrenome': 'Nogueira',
#   'idade': 44},
#  'gustavo63@example.com': {'nome': 'Emanuel',
#   'sobrenome': 'Dias',
#   'idade': 50},
#  'bernardo22@example.net': {'nome': 'Emanuel',
#   'sobrenome': 'Gonçalves',
#   'idade': 44},
#  'da-costanathan@example.net': {'nome': 'Emanuella',
#   'sobrenome': 'Azevedo',
#   'idade': 44},
#  'enricoda-costa@example.net': {'nome': 'Emanuella',
#   'sobrenome': 'da Mata',
#   'idade': 63},
#  'eloahcaldeira@example.net': {'nome': 'Emanuelly',
#   'sobrenome': 'Mendes',
#   'idade': 49},
#  'moraesclara@example.org': {'nome': 'Emilly',
#   'sobrenome': 'Alves',
#   'idade': 55},
#  'stella90@example.com': {'nome': 'Emilly',
#   'sobrenome': 'Barbosa',
#   'idade': 70},
#  'knunes@example.org': {'nome': 'Enrico', 'sobrenome': 'Souza', 'idade': 27},
#  'gabriellycardoso@example.org': {'nome': 'Erick',
#   'sobrenome': 'da Rocha',
#   'idade': 42},
#  'vianavitoria@example.org': {'nome': 'Francisco',
#   'sobrenome': 'Mendes',
#   'idade': 18},
#  'laura11@example.net': {'nome': 'Gabriel',
#   'sobrenome': 'da Cunha',
#   'idade': 40},
#  'matheusferreira@example.com': {'nome': 'Gabriela',
#   'sobrenome': 'Campos',
#   'idade': 29},
#  'pedro-henrique59@example.net': {'nome': 'Gabrielly',
#   'sobrenome': 'Cunha',
#   'idade': 62},
#  'hferreira@example.net': {'nome': 'Gabrielly',
#   'sobrenome': 'Moura',
#   'idade': 49},
#  'jda-cruz@example.org': {'nome': 'Giovanna',
#   'sobrenome': 'Martins',
#   'idade': 49},
#  'cauefogaca@example.org': {'nome': 'Guilherme',
#   'sobrenome': 'Oliveira',
#   'idade': 70},
#  'hcampos@example.net': {'nome': 'Gustavo Henrique',
#   'sobrenome': 'Souza',
#   'idade': 19},
#  'imendes@example.net': {'nome': 'Gustavo Henrique',
#   'sobrenome': 'das Neves',
#   'idade': 46},
#  'alicedias@example.org': {'nome': 'Heitor',
#   'sobrenome': 'Pires',
#   'idade': 58},
#  'vvieira@example.net': {'nome': 'Heitor',
#   'sobrenome': 'Teixeira',
#   'idade': 47},
#  'lucasmelo@example.net': {'nome': 'Heloísa',
#   'sobrenome': 'Castro',
#   'idade': 56},
#  'carolinamoura@example.net': {'nome': 'Heloísa',
#   'sobrenome': 'Dias',
#   'idade': 27},
#  'mpereira@example.com': {'nome': 'Heloísa',
#   'sobrenome': 'Duarte',
#   'idade': 58},
#  'xgomes@example.org': {'nome': 'Heloísa',
#   'sobrenome': 'da Mata',
#   'idade': 48},
#  'emanuelly32@example.net': {'nome': 'Ian',
#   'sobrenome': 'Campos',
#   'idade': 22},
#  'qmoraes@example.org': {'nome': 'Ian', 'sobrenome': 'Cunha', 'idade': 46},
#  'lorenzosantos@example.org': {'nome': 'Igor',
#   'sobrenome': 'Farias',
#   'idade': 67},
#  'catarinadias@example.com': {'nome': 'Isabel',
#   'sobrenome': 'Viana',
#   'idade': 19},
#  'dda-cruz@example.net': {'nome': 'Isabella',
#   'sobrenome': 'Dias',
#   'idade': 37},
#  'rferreira@example.com': {'nome': 'Isabelly',
#   'sobrenome': 'Moraes',
#   'idade': 60},
#  'danilo20@example.org': {'nome': 'Isis', 'sobrenome': 'Jesus', 'idade': 51},
#  'leonardoda-mota@example.net': {'nome': 'Isis',
#   'sobrenome': 'Vieira',
#   'idade': 50},
#  'teixeiramarina@example.com': {'nome': 'Joaquim',
#   'sobrenome': 'Aragão',
#   'idade': 23},
#  'benjaminlopes@example.net': {'nome': 'João',
#   'sobrenome': 'da Cruz',
#   'idade': 51},
#  'eda-cunha@example.org': {'nome': 'João Felipe',
#   'sobrenome': 'Moraes',
#   'idade': 28},
#  'miguel59@example.net': {'nome': 'João Felipe',
#   'sobrenome': 'Silva',
#   'idade': 22},
#  'vinicius65@example.net': {'nome': 'João Felipe',
#   'sobrenome': 'da Cruz',
#   'idade': 19},
#  'caldeirajoao-gabriel@example.net': {'nome': 'João Guilherme',
#   'sobrenome': 'Cavalcanti',
#   'idade': 20},
#  'evelyngomes@example.org': {'nome': 'João Guilherme',
#   'sobrenome': 'Teixeira',
#   'idade': 18},
#  'ceciliamelo@example.org': {'nome': 'João Miguel',
#   'sobrenome': 'Martins',
#   'idade': 40},
#  'maria-fernandamonteiro@example.com': {'nome': 'João Pedro',
#   'sobrenome': 'Lima',
#   'idade': 61},
#  'fcorreia@example.com': {'nome': 'João Pedro',
#   'sobrenome': 'Moreira',
#   'idade': 47},
#  'mendesalana@example.com': {'nome': 'João Vitor',
#   'sobrenome': 'Ferreira',
#   'idade': 52},
#  'luiz-fernandocosta@example.org': {'nome': 'Julia',
#   'sobrenome': 'Barbosa',
#   'idade': 37},
#  'martinsmaria-sophia@example.net': {'nome': 'Julia',
#   'sobrenome': 'Oliveira',
#   'idade': 37},
#  'ana-vitoria33@example.net': {'nome': 'Juliana',
#   'sobrenome': 'Lima',
#   'idade': 53},
#  'pporto@example.com': {'nome': 'Juliana', 'sobrenome': 'Mendes', 'idade': 54},
#  'oliveiraandre@example.com': {'nome': 'Juliana',
#   'sobrenome': 'Moreira',
#   'idade': 37},
#  'carvalhomaria-luiza@example.net': {'nome': 'Juliana',
#   'sobrenome': 'Rodrigues',
#   'idade': 63},
#  'viniciusda-cunha@example.com': {'nome': 'Júlia',
#   'sobrenome': 'Fogaça',
#   'idade': 36},
#  'nataliajesus@example.com': {'nome': 'Júlia',
#   'sobrenome': 'Nascimento',
#   'idade': 69},
#  'kamilly93@example.net': {'nome': 'Kamilly',
#   'sobrenome': 'Correia',
#   'idade': 44},
#  'thiagomoraes@example.net': {'nome': 'Kevin',
#   'sobrenome': 'Carvalho',
#   'idade': 44},
#  'luiza63@example.org': {'nome': 'Kevin', 'sobrenome': 'Farias', 'idade': 50},
#  'barrosisabel@example.org': {'nome': 'Kevin',
#   'sobrenome': 'Pires',
#   'idade': 22},
#  'enzoda-mata@example.com': {'nome': 'Larissa',
#   'sobrenome': 'Aragão',
#   'idade': 43},
#  'fvieira@example.org': {'nome': 'Larissa',
#   'sobrenome': 'Barros',
#   'idade': 25},
#  'ana-sophiaoliveira@example.net': {'nome': 'Larissa',
#   'sobrenome': 'Moura',
#   'idade': 51},
#  'alvesenrico@example.com': {'nome': 'Larissa',
#   'sobrenome': 'Pires',
#   'idade': 19},
#  'mendesana-sophia@example.net': {'nome': 'Lavínia',
#   'sobrenome': 'Moreira',
#   'idade': 64},
#  'camposvitoria@example.com': {'nome': 'Lavínia',
#   'sobrenome': 'Oliveira',
#   'idade': 21},
#  'eduardo77@example.net': {'nome': 'Leonardo',
#   'sobrenome': 'Alves',
#   'idade': 21},
#  'dcampos@example.net': {'nome': 'Letícia', 'sobrenome': 'Pires', 'idade': 28},
#  'arthur21@example.com': {'nome': 'Levi',
#   'sobrenome': 'Monteiro',
#   'idade': 55},
#  'jalves@example.com': {'nome': 'Levi', 'sobrenome': 'Nunes', 'idade': 36},
#  'stella94@example.net': {'nome': 'Levi', 'sobrenome': 'Ramos', 'idade': 39},
#  'stellarodrigues@example.net': {'nome': 'Luana',
#   'sobrenome': 'Novaes',
#   'idade': 29},
#  'souzagiovanna@example.org': {'nome': 'Lucas Gabriel',
#   'sobrenome': 'da Paz',
#   'idade': 28},
#  'renan56@example.org': {'nome': 'Lucca',
#   'sobrenome': 'das Neves',
#   'idade': 18},
#  'novaesian@example.org': {'nome': 'Luiz Gustavo',
#   'sobrenome': 'Gomes',
#   'idade': 27},
#  'maria-ceciliafernandes@example.com': {'nome': 'Luiz Henrique',
#   'sobrenome': 'Azevedo',
#   'idade': 49},
#  'fogacaheitor@example.org': {'nome': 'Luiz Henrique',
#   'sobrenome': 'Barbosa',
#   'idade': 31},
#  'brenopeixoto@example.com': {'nome': 'Luiz Henrique',
#   'sobrenome': 'Fernandes',
#   'idade': 28},
#  'theo80@example.net': {'nome': 'Luiz Otávio',
#   'sobrenome': 'Nunes',
#   'idade': 34},
#  'goncalvesjoao-lucas@example.net': {'nome': 'Luiz Otávio',
#   'sobrenome': 'Rezende',
#   'idade': 65},
#  'pduarte@example.org': {'nome': 'Luiza',
#   'sobrenome': 'Caldeira',
#   'idade': 36},
#  'tpereira@example.org': {'nome': 'Luna', 'sobrenome': 'Araújo', 'idade': 33},
#  'marcelosilva@example.net': {'nome': 'Luna',
#   'sobrenome': 'Pereira',
#   'idade': 21},
#  'helenada-rocha@example.net': {'nome': 'Lívia',
#   'sobrenome': 'Moraes',
#   'idade': 37},
#  'isisnascimento@example.com': {'nome': 'Manuela',
#   'sobrenome': 'Novaes',
#   'idade': 23},
#  'juliarocha@example.com': {'nome': 'Marcela',
#   'sobrenome': 'Cavalcanti',
#   'idade': 29},
#  'pintomaria@example.com': {'nome': 'Marcela',
#   'sobrenome': 'da Paz',
#   'idade': 46},
#  'mmartins@example.com': {'nome': 'Marcelo',
#   'sobrenome': 'Costa',
#   'idade': 57},
#  'qdias@example.com': {'nome': 'Marcelo',
#   'sobrenome': 'da Costa',
#   'idade': 54},
#  'ccavalcanti@example.com': {'nome': 'Marcos Vinicius',
#   'sobrenome': 'Freitas',
#   'idade': 64},
#  'bianca48@example.com': {'nome': 'Maria', 'sobrenome': 'Gomes', 'idade': 37},
#  'spinto@example.net': {'nome': 'Maria', 'sobrenome': 'Monteiro', 'idade': 39},
#  'caldeiraisis@example.net': {'nome': 'Maria Alice',
#   'sobrenome': 'da Mota',
#   'idade': 21},
#  'pedro-miguelaragao@example.net': {'nome': 'Maria Cecília',
#   'sobrenome': 'Oliveira',
#   'idade': 30},
#  'iancunha@example.org': {'nome': 'Maria Cecília',
#   'sobrenome': 'Teixeira',
#   'idade': 38},
#  'cardosobeatriz@example.net': {'nome': 'Maria Cecília',
#   'sobrenome': 'Teixeira',
#   'idade': 31},
#  'monteiromaria-clara@example.com': {'nome': 'Maria Clara',
#   'sobrenome': 'Costela',
#   'idade': 68},
#  'evelyn82@example.org': {'nome': 'Maria Clara',
#   'sobrenome': 'Lima',
#   'idade': 67},
#  'pda-conceicao@example.net': {'nome': 'Maria Clara',
#   'sobrenome': 'Rodrigues',
#   'idade': 52},
#  'ana-luiza10@example.com': {'nome': 'Maria Eduarda',
#   'sobrenome': 'Fogaça',
#   'idade': 26},
#  'lunaaragao@example.net': {'nome': 'Maria Eduarda',
#   'sobrenome': 'Vieira',
#   'idade': 41},
#  'maria-eduardamartins@example.org': {'nome': 'Maria Eduarda',
#   'sobrenome': 'da Cruz',
#   'idade': 45},
#  'fernandesolivia@example.org': {'nome': 'Maria Fernanda',
#   'sobrenome': 'Moura',
#   'idade': 22},
#  'evelyn52@example.net': {'nome': 'Maria Fernanda',
#   'sobrenome': 'Pereira',
#   'idade': 43},
#  'diego97@example.com': {'nome': 'Maria Fernanda',
#   'sobrenome': 'Ramos',
#   'idade': 46},
#  'maria-alice97@example.net': {'nome': 'Maria Julia',
#   'sobrenome': 'da Cruz',
#   'idade': 56},
#  'jesuscaue@example.org': {'nome': 'Maria Luiza',
#   'sobrenome': 'Gomes',
#   'idade': 39},
#  'eduardocosta@example.com': {'nome': 'Maria Sophia',
#   'sobrenome': 'Nogueira',
#   'idade': 41},
#  'maria-vitoria35@example.org': {'nome': 'Maria Vitória',
#   'sobrenome': 'Lima',
#   'idade': 56},
#  'francisco79@example.com': {'nome': 'Mariane',
#   'sobrenome': 'Farias',
#   'idade': 62},
#  'souzamirella@example.net': {'nome': 'Mariane',
#   'sobrenome': 'Mendes',
#   'idade': 50},
#  'mendesana@example.com': {'nome': 'Matheus',
#   'sobrenome': 'Aragão',
#   'idade': 18},
#  'joao-gabrielda-rosa@example.com': {'nome': 'Matheus',
#   'sobrenome': 'Moura',
#   'idade': 55},
#  'ccavalcanti@example.org': {'nome': 'Maysa',
#   'sobrenome': 'Jesus',
#   'idade': 19},
#  'danilo61@example.org': {'nome': 'Melissa',
#   'sobrenome': 'Duarte',
#   'idade': 40},
#  'ubarbosa@example.com': {'nome': 'Melissa',
#   'sobrenome': 'Teixeira',
#   'idade': 65},
#  'caldeiraluiz-fernando@example.net': {'nome': 'Melissa',
#   'sobrenome': 'da Mata',
#   'idade': 58},
#  'laura37@example.com': {'nome': 'Melissa',
#   'sobrenome': 'da Mata',
#   'idade': 28},
#  'da-cruzclarice@example.org': {'nome': 'Milena',
#   'sobrenome': 'Azevedo',
#   'idade': 53},
#  'juliada-paz@example.org': {'nome': 'Milena',
#   'sobrenome': 'Rezende',
#   'idade': 29},
#  'oda-mata@example.net': {'nome': 'Mirella',
#   'sobrenome': 'Gomes',
#   'idade': 18},
#  'bianca66@example.net': {'nome': 'Mirella',
#   'sobrenome': 'Ribeiro',
#   'idade': 26},
#  'anthony66@example.net': {'nome': 'Mirella',
#   'sobrenome': 'Souza',
#   'idade': 56},
#  'davicavalcanti@example.com': {'nome': 'Murilo',
#   'sobrenome': 'Barbosa',
#   'idade': 56},
#  'francisco46@example.com': {'nome': 'Natália',
#   'sobrenome': 'Ferreira',
#   'idade': 66},
#  'xaragao@example.com': {'nome': 'Natália',
#   'sobrenome': 'Peixoto',
#   'idade': 63},
#  'almeidathiago@example.org': {'nome': 'Natália',
#   'sobrenome': 'Silveira',
#   'idade': 19},
#  'opeixoto@example.com': {'nome': 'Nicolas',
#   'sobrenome': 'da Rocha',
#   'idade': 56},
#  'caio81@example.com': {'nome': 'Nicole', 'sobrenome': 'Lima', 'idade': 18},
#  'camposmirella@example.net': {'nome': 'Nina',
#   'sobrenome': 'da Cruz',
#   'idade': 38},
#  'zoliveira@example.com': {'nome': 'Noah', 'sobrenome': 'Melo', 'idade': 55},
#  'ceciliacaldeira@example.com': {'nome': 'Noah',
#   'sobrenome': 'Nunes',
#   'idade': 32},
#  'davi-luiz41@example.net': {'nome': 'Noah',
#   'sobrenome': 'da Luz',
#   'idade': 67},
#  'luiz-henriquesales@example.net': {'nome': 'Olivia',
#   'sobrenome': 'Pereira',
#   'idade': 61},
#  'cardosoana-beatriz@example.com': {'nome': 'Olivia',
#   'sobrenome': 'da Rosa',
#   'idade': 47},
#  'hduarte@example.org': {'nome': 'Otávio', 'sobrenome': 'Moraes', 'idade': 36},
#  'cauacardoso@example.org': {'nome': 'Otávio',
#   'sobrenome': 'da Paz',
#   'idade': 54},
#  'cardosojulia@example.com': {'nome': 'Paulo',
#   'sobrenome': 'Mendes',
#   'idade': 32},
#  'ana-sophia84@example.net': {'nome': 'Pedro',
#   'sobrenome': 'Gomes',
#   'idade': 45},
#  'guilherme01@example.com': {'nome': 'Pedro Henrique',
#   'sobrenome': 'Pires',
#   'idade': 31},
#  'silveiraalexia@example.org': {'nome': 'Pedro Miguel',
#   'sobrenome': 'Costela',
#   'idade': 39},
#  'ribeirojoao-vitor@example.net': {'nome': 'Pietra',
#   'sobrenome': 'Azevedo',
#   'idade': 40},
#  'rodriguesvitoria@example.com': {'nome': 'Pietra',
#   'sobrenome': 'Cavalcanti',
#   'idade': 54},
#  'helena05@example.net': {'nome': 'Pietra', 'sobrenome': 'Jesus', 'idade': 19},
#  'emanuel88@example.com': {'nome': 'Pietra',
#   'sobrenome': 'Moreira',
#   'idade': 59},
#  'maria-ceciliada-mata@example.org': {'nome': 'Pietro',
#   'sobrenome': 'Barbosa',
#   'idade': 33},
#  'levida-rosa@example.net': {'nome': 'Raquel',
#   'sobrenome': 'Costela',
#   'idade': 65},
#  'rochalucca@example.net': {'nome': 'Raquel',
#   'sobrenome': 'Freitas',
#   'idade': 40},
#  'bruno19@example.org': {'nome': 'Raquel',
#   'sobrenome': 'Monteiro',
#   'idade': 51},
#  'joaquim13@example.net': {'nome': 'Raquel',
#   'sobrenome': 'Rodrigues',
#   'idade': 26},
#  'bmendes@example.net': {'nome': 'Raul',
#   'sobrenome': 'Gonçalves',
#   'idade': 44},
#  'enzo-gabriel24@example.net': {'nome': 'Rebeca',
#   'sobrenome': 'Novaes',
#   'idade': 32},
#  'lda-conceicao@example.org': {'nome': 'Rodrigo',
#   'sobrenome': 'Lima',
#   'idade': 50},
#  'julianascimento@example.org': {'nome': 'Rodrigo',
#   'sobrenome': 'Viana',
#   'idade': 22},
#  'laisoliveira@example.net': {'nome': 'Rodrigo',
#   'sobrenome': 'da Cunha',
#   'idade': 58},
#  'larissacarvalho@example.com': {'nome': 'Ryan',
#   'sobrenome': 'Jesus',
#   'idade': 58},
#  'peixotopietro@example.org': {'nome': 'Sabrina',
#   'sobrenome': 'Barbosa',
#   'idade': 40},
#  'marianemoraes@example.com': {'nome': 'Sabrina',
#   'sobrenome': 'Rocha',
#   'idade': 48},
#  'lucca32@example.com': {'nome': 'Sarah', 'sobrenome': 'Cunha', 'idade': 41},
#  'vianacaue@example.net': {'nome': 'Sofia',
#   'sobrenome': 'Moraes',
#   'idade': 22},
#  'pedro-henrique81@example.org': {'nome': 'Sofia',
#   'sobrenome': 'Oliveira',
#   'idade': 65},
#  'lopesemanuelly@example.net': {'nome': 'Sofia',
#   'sobrenome': 'Vieira',
#   'idade': 48},
#  'lgomes@example.org': {'nome': 'Sophia',
#   'sobrenome': 'Fernandes',
#   'idade': 38},
#  'limamaria-julia@example.org': {'nome': 'Sophia',
#   'sobrenome': 'Gonçalves',
#   'idade': 40},
#  'alexiarodrigues@example.org': {'nome': 'Sophia',
#   'sobrenome': 'Nogueira',
#   'idade': 41},
#  'sarah84@example.net': {'nome': 'Stella',
#   'sobrenome': 'Azevedo',
#   'idade': 56},
#  'franciscodias@example.com': {'nome': 'Stella',
#   'sobrenome': 'Fernandes',
#   'idade': 20},
#  'wporto@example.net': {'nome': 'Valentina',
#   'sobrenome': 'Carvalho',
#   'idade': 61},
#  'maria-eduarda20@example.net': {'nome': 'Vicente',
#   'sobrenome': 'Nunes',
#   'idade': 27},
#  'ianbarbosa@example.org': {'nome': 'Vinicius',
#   'sobrenome': 'Gomes',
#   'idade': 51},
#  'lorenzogoncalves@example.org': {'nome': 'Vitor',
#   'sobrenome': 'das Neves',
#   'idade': 29},
#  'isabel02@example.net': {'nome': 'Vitor Hugo',
#   'sobrenome': 'Lopes',
#   'idade': 38},
#  'cecilia10@example.org': {'nome': 'Vitor Hugo',
#   'sobrenome': 'Ribeiro',
#   'idade': 42},
#  'faragao@example.org': {'nome': 'Vitor Hugo',
#   'sobrenome': 'Silveira',
#   'idade': 36},
#  'maria-eduarda34@example.org': {'nome': 'Vitória',
#   'sobrenome': 'Araújo',
#   'idade': 18},
#  'maria-sophia83@example.org': {'nome': 'Vitória',
#   'sobrenome': 'Dias',
#   'idade': 30},
#  'marina15@example.org': {'nome': 'Yago', 'sobrenome': 'da Mota', 'idade': 53},
#  'mariapereira@example.net': {'nome': 'Yasmin',
#   'sobrenome': 'Jesus',
#   'idade': 42},
#  'alvesnicole@example.com': {'nome': 'Yuri',
#   'sobrenome': 'Farias',
#   'idade': 35}}

# %%
read_table().is_empty()
# Out:
# True

# %%
import polars as pl
from datetime import date

def read_table():
    client_ch.execute('''
    CREATE TABLE IF NOT EXISTS dim_clients (
        nome String,
        sobrenome String,
        idade Int32,
        email String,
        data_cadastro Date,
        effective_date Date,
        end_date Date,
        is_current UInt8
    ) ENGINE = MergeTree()
    ORDER BY (nome, sobrenome, effective_date)
    ''')
    result = client_ch.execute(f"SELECT * FROM dim_clients where is_current = 1")
    columns = ['nome', 'sobrenome', 'idade', 'email', 'data_cadastro',  'effective_date', 'end_date', 'is_current']
    # Criar o DataFrame Polars a partir dos resultados
    df_table = pl.DataFrame(result, schema=columns) 
    return df_table

def insert_dim_clients(content):
    #Criando dataframe polars com os dados a serem inseridos
    df_insert = pl.DataFrame(content)
    df_insert = df_insert.with_columns(
        pl.col("data_cadastro").str.strptime(pl.Date, format="%Y-%m-%d").alias("data_cadastro")
    ).with_columns(pl.lit(date(2023, 12, 31)).alias("effective_date"))\
    .with_columns(pl.lit(date(2149, 6, 6)).alias("end_date"))\
    .with_columns(pl.lit(1).alias("is_current"))
    
    #lendo a tabela para fazer o scd2
    df_table = read_table()
    if df_table.is_empty():
        data = df_insert.to_dicts()
        
        # Inserir os dados no ClickHouse
        client_ch.execute(
            'INSERT INTO dim_clients (nome, sobrenome, idade, email, data_cadastro, effective_date, end_date, is_current) VALUES',
            [(row['nome'], row['sobrenome'], row['idade'], row['email'], row['data_cadastro'], row['effective_date'], row['end_date'], row['is_current']) for row in data]
        )
        print("Dados inseridos com sucesso")
    else:  
        """
        Nesse caso, eu utilizo o email como chave primaria (poderia ser id, cpf, etc...), faço o join com a tabela para ver os emails repetidos
        que estão sendo inseridos e filtro pela data de cadastro para garantir que os dados repetidos que estamos inserindo
        sao o cadastro mais atualizado.
        
        """
        df_joined = df_insert.join(
            df_table, 
            on="email", 
            how="inner"
        ).filter(
            pl.col("data_cadastro").cast(pl.Date) > pl.col("data_cadastro_right").cast(pl.Date)
        )
        
        # Linhas a serem inativadas com is_current = 0 e fechamento do end date
        df_update_inactive = df_joined.select([
            pl.col("nome"),
            pl.col("sobrenome"),
            pl.col("idade"),
            pl.col("email"),
            pl.col("data_cadastro_right").alias("data_cadastro"),
            pl.col("effective_date_right").alias("effective_date"),
            pl.col("effective_date").alias("end_date"),
            pl.lit(0).alias("is_current")
        ])
        for row in df_update_inactive.to_dicts():
            client_ch.execute(
                """
                ALTER TABLE dim_clients
                UPDATE end_date = %(end_date)s,
                       is_current = %(is_current)s
                WHERE email = %(email)s
                """,
                {'end_date': row['end_date'], 'is_current': row['is_current'], 'email': row['email']}
            )
        
        """ 
        caso onde o cliente a ser inserido ja esta na base mas tem a data de cadastro menor do
        que a já cadastrada, nesse caso, o dado é inserido mas o dado ja persistido
        é mantido como o dado corrente porque tem a data de cadastro maior
        
        """
        df_joined = df_insert.join(
            df_table, 
            on="email", 
            how="inner"
        ).filter(
            pl.col("data_cadastro").cast(pl.Date) < pl.col("data_cadastro_right").cast(pl.Date)
        )
        # Selecionar as colunas e renomear conforme necessário
        df_update_inactive_new = df_joined.select([
            pl.col("nome"),
            pl.col("sobrenome"),
            pl.col("idade"),
            pl.col("email"),
            pl.col("data_cadastro"),
            pl.col("effective_date"),
            pl.col("effective_date").alias("end_date"),
            pl.lit(0).alias("is_current")
        ])
        df_insert = df_insert.join(
            df_update_inactive_new, 
            on="email", 
            how="left"
        ).select([
            pl.col("nome"),
            pl.col("sobrenome"),
            pl.col("idade"),
            pl.col("email"),
            pl.col("data_cadastro"),
            pl.when(pl.col("nome_right").is_not_null()).then(pl.col("effective_date_right")).otherwise(pl.col("effective_date")).alias("effective_date"),
            pl.when(pl.col("nome_right").is_not_null()).then(pl.col("end_date_right")).otherwise(pl.col("end_date")).alias("end_date"),
             pl.when(pl.col("nome_right").is_not_null()).then(pl.col("is_current_right")).otherwise(pl.col("is_current")).alias("is_current"),
        ])
        # Converta o DataFrame para um formato que pode ser enviado ao ClickHouse
        data = df_insert.to_dicts()
        
        # Inserir os dados no ClickHouse
        client_ch.execute(
            'INSERT INTO dim_clients (nome, sobrenome, idade, email, data_cadastro, effective_date, end_date, is_current) VALUES',
            [(row['nome'], row['sobrenome'], row['idade'], row['email'], row['data_cadastro'], row['effective_date'], row['end_date'], row['is_current']) for row in data]
        )

# %%
for i in range(40):
    content[i]['data_cadastro'] = '2025-12-12'

# %%
insert_dim_clients(content)
# Out:
# /tmp/ipykernel_423/3696115533.py:21: DataOrientationWarning: Row orientation inferred during DataFrame construction. Explicitly specify the orientation by passing `orient="row"` to silence this warning.
#   df_table = pl.DataFrame(result, schema=columns)
